# %%
import json
import chemparse
with open('run15000chars.json') as f:
    model_output = json.load(f)
with open('database.json') as f:
    database = json.load(f)

model_output = {key:model_output[key][:2] for key in model_output.keys()}

# %%
model_output
# Out:
# {'physrevb.10.4572': ['Ga1', ' 6.07 K'],
#  'physrevb.100.014503': ['Eu1Fe2As2', ' 27 K'],
#  'physrevb.100.014507': ['Pd1S2', ' 8.0 K'],
#  'physrevb.100.041109': ['Rb1', ' 2 K'],
#  'physrevb.100.060103': ['Au2Pb1', ' 4 K'],
#  'physrevb.100.094511': ['Rb1Cr3As3', ' 7.17 K'],
#  'physrevb.100.094522': ['W3Al2C1', ' 7.6 K'],
#  'physrevb.100.134503': ['Ta1Os1Si1', ' 5.8 K'],
#  'physrevb.23.2219': ['K0.18W1O3', ' 1.2 K'],
#  'physrevb.26.6315': ['K1Hg1C4', ' 1.7 K'],
#  'physrevb.28.1389': ['La1Ir2Si2', ' 1.58 K'],
#  'physrevb.30.1182': ['Ce1Cu2Si2', ' 2 K'],
#  'physrevb.30.1583': ['Pt3U1', ' 0.54 K'],
#  'physrevb.30.2986': ['Pt3U1', ' 0.49 K'],
#  'physrevb.30.444': ['Ce1Ru3Si2', ' 1 K'],
#  'physrevb.30.5135': ['Co35.38Zr64.62', ' 2.67 K'],
#  'physrevb.31.1654': ['Pt3U1', ' 17.6 K'],
#  'physrevb.32.135': ['Pd2Yb1Sn1', ' 2.46 K'],
#  'physrevb.34.4590': ['Lu5Ir4Si10', ' 79 K'],
#  'physrevb.34.4920': ['Ga1', ' 0.7 K'],
#  'physrevb.36.3906': ['La1.8Sr0.2Cu1O4', ' 39 K'],
#  'physrevb.36.3910': ['Y1.2Ba0.8Cu1O4', ' 34 K'],
#  'physrevb.36.3920': ['Y1Ba2Cu3O7+Y', ' 92 K'],
#  'physrevb.36.4003': ['La1.85Sr0.15Cu1O4', ' 36 K'],
#  'physrevb.36.4014': ['Y1Ba2Cu3O7', ' 93 K'],
#  'physrevb.36.4018': ['Gd1Ba2Cu2.82Fe0.18O9-Z', ' 31 K'],
#  'physrevb.36.8329': ['Y1Ba2Cu3O7-Z', ' 92.4 K'],
#  'physrevb.36.8660': ['La1Fe4P12', ' 4 K'],
#  'physrevb.36.8791': ['Er1Ba2Cu3O7-Z', ' 0.87 K'],
#  'physrevb.38.11955': ['Bi2Sr2Ca1Cu2O8', ' 90 K'],
#  'physrevb.38.225': ['Tl2Ba2Cu1O6', ' 90 K'],
#  'physrevb.38.2455': ['Ho1Ba2Cu3O6.9', ' 91.5 K'],
#  'physrevb.39.11445': ['La2Cu1O4+Z', ' 37 K'],
#  'physrevb.39.6571': ['Y1Ba2Cu3O7', ' 92 K'],
#  'physrevb.39.7339': ['Ba0.6K0.4Bi1O3-Z', ' 30 K'],
#  'physrevb.39.9074': ['La1Ba1Ca1Cu3O6.98', ' 78.5 K'],
#  'physrevb.40.2690': ['Ba0.6Rb0.4Bi1O3', ' 29 K'],
#  'physrevb.40.841': ['Bi2Sr2Ca1Cu2O8', ' 84 K'],
#  'physrevb.41.2520': ['La1.96Sr0.04Cu1O4', ' 9.5 K'],
#  'physrevb.41.9551': ['Bi2Sr2Ca1Cu2O8+z', ' 30 K'],
#  'physrevb.45.4803': ['Si2Ta1', ' 0.353 K'],
#  'physrevb.45.5628': ['Tl2Ba2Ca1Cu2O8', ' 102 K'],
#  'physrevb.48.16869': ['Y1Ba2Cu4O8', ' 120 K'],
#  'physrevb.49.12322': ['Hg0.66Pb0.33Ba2Ca2Cu3Oy', ' 133 K'],
#  'physrevb.49.13075': ['Hg1Ba2Cu1O4+d', ' 94 K'],
#  'physrevb.49.13184': ['Bi2Sr2Ca1Cu2O8+y', ' 110 K'],
#  'physrevb.49.1492': ['Bi0.5Sr1.5Y1.15Ce0.85Cu2O8-z', ' 34 K'],
#  'physrevb.49.1495': ['Bi2Sr2Ca2Cu3O10', ' 110.3 K'],
#  'physrevb.49.15416': ['Hg1Ba2Ca2Cu3O8+d', ' 132 K'],
#  'physrevb.49.15959': ['Bi2Sr2Ca1Cu2O8', ' 3 K'],
#  'physrevb.49.3502': ['Ba0.64K0.36Bi1O3', ' 32 K'],
#  'physrevb.49.3683': ['Hg1Ba2Cu1O4+d', ' 97 K'],
#  'physrevb.49.6392': ['Nd1.85Ce0.15Cu1O4', ' 16 K'],
#  'physrevb.49.8931': ['Tl2Mo6Se6', ' 6.5 K'],
#  'physrevb.49.9073': ['Bi2Sr2Ca1Cu2O8', ' 38 K'],
#  'physrevb.49.9097': ['La1.925Sr0.075Cu1O4+d', ' 23 K'],
#  'physrevb.49.9218': ['Bi2Sr2Ca1Cu2O8+d', ' 90.7 K'],
#  'physrevb.49.9885': ['I1Bi2.2Sr1.8Ca1Cu2O8+y', ' 73.6 K'],
#  'physrevb.49.9924': ['Y1Ba2Cu3O7-d', ' 90 K'],
#  'physrevb.50.13890': ['Ba6C60', ' 7 K'],
#  'physrevb.50.15875': ['La1.85Sr0.15Cu1O4', ' 36 K'],
#  'physrevb.50.16125': ['Y1Ba2Cu3Oy', ' 91.5 K'],
#  'physrevb.50.351': ['Sc1Ni2B2C1', ' 14.6 K'],
#  'physrevb.50.426': ['Y2Ba4Cu7O15.1', ' 15.1 K'],
#  'physrevb.50.496': ['Bi2Sr1.9Cu2.1Ox', ' 7.5 K'],
#  'physrevb.50.6523': ['La1Ni1Si1', ' 1.23 K'],
#  'physrevb.51.12644': ['Ho1Ni2B2C1', ' 8.4 K'],
#  'physrevb.51.12747': ['Tl1.89Ba2Cu1.11O6.18', ' 49 K'],
#  'physrevb.51.1286': ['La2Cu1O4.035', ' 222 K'],
#  'physrevb.51.1393': ['Pb0.17Hg1.22Ba2Ca1.44Cu2.79Ox', ' 133.6 K'],
#  'physrevb.51.1397': ['Bi1.8Pb0.4Sr2Ca2Cu3O10+d', ' 104 K'],
#  'physrevb.51.15478': ['Y2Ba4Cu7O14.97', ' 93.1 K'],
#  'physrevb.51.3316': ['Y1Ba2Cu3O7-d', ' 92.5 K'],
#  'physrevb.52.10569': ['Y1Ba2Cu3O6.95', ' 92 K'],
#  'physrevb.52.1181': ['Ho1Ni2B2C1', ' 5.2 K'],
#  'physrevb.52.15534': ['C60Sm3', ' 2 K'],
#  'physrevb.52.3071': ['Nd1.85Ce0.15Cu1O4-d', ' 24 K'],
#  'physrevb.52.4432': ['Rb1Cs2C60', ' 33 K'],
#  'physrevb.52.483': ['K3N1H3C60', ' 28 K'],
#  'physrevb.52.7647': ['Bi2Sr2Ca1Cu2O8+y', ' 92 K'],
#  'physrevb.52.r3844': ['Dy1Ni2B2C1', ' 6.2 K'],
#  'physrevb.53.12299': ['Rh1Zr2', ' 11 K'],
#  'physrevb.53.12389': ['Tm2Fe3Si5', ' 1.15 K'],
#  'physrevb.53.5170': ['Ba2Ca3Cu5O11-y', ' 115.9 K'],
#  'physrevb.53.8238': ['La1', ' 520 K'],
#  'physrevb.53.8241': ['Ce1Rh2Si2', ' 0.35 K'],
#  'physrevb.54.6133': ['BaKBi1O3', ' 31.8 K'],
#  'physrevb.54.r3772': ['Lu1Ni2B2C1', ' 16 K'],
#  'physrevb.54.r6885': ['Bi2Sr1.8Ca1.2Cu2O8', ' 79.5 K'],
#  'physrevb.55.11789': ['Y1Ba2Cu3O6.95', ' 93.2 K'],
#  'physrevb.55.15300': ['Y1Ba2Cu3O6.92', ' 90 K'],
#  'physrevb.55.8529': ['Bi2Sr2Ca1Cu2O8+y', ' 115 K'],
#  'physrevb.55.9125': ['Bi2Sr2Ca1Cu2O8+y', ' 90 K'],
#  'physrevb.55.r6145': ['Pr1.85Ce0.15Cu1O4-z', ' 21 K'],
#  'physrevb.55.r8674': ['Hg1Ba2Ca2Cu3O8+y', ' 110.4 K'],
#  'physrevb.56.5631': ['Tb1Sr2Cu2.69Mo0.31O7', ' 32 K'],
#  'physrevb.56.7890': ['Sr2Ru1O4', ' 1 K'],
#  'physrevb.56.8346': ['Ca3Rh4Sn13', ' 8.2 K'],
#  'physrevb.57.613': ['Sr0.4Ca13.6Cu24O41+z', ' 13 K'],
#  'physrevb.57.r14084': ['Y1Ba2Cu3O7-d', ' 84 K'],
#  'physrevb.58.497': ['La1Ni1C2', ' 2.7 K'],
#  'physrevb.58.r603': ['Pt3U1', ' 563+5 mK'],
#  'physrevb.59.11179': ['Bi2Sr2Ca1Cu2O8+X', ' 79 K'],
#  'physrevb.59.11563': ['Nd1Ba2Cu3O7-Z', ' 95.65 K'],
#  'physrevb.59.13639': ['Y0.5Yb0.5Ba2Sr0Cu3O7-Z', ' 89 K'],
#  'physrevb.59.14099': ['Ru1Sr2Gd1Cu2O8', ' 16 K'],
#  'physrevb.59.14753': ['La1.905Ba0.095Cu1O4', ' 31 K'],
#  'physrevb.59.3827': ['La1.85Sr0.15Cu1O4', ' 43.7 K'],
#  'physrevb.59.7266': ['Lu5Ir4Si10', ' 83 K'],
#  'physrevb.59.8962': ['I1Bi1.9Pb0.1Sr2Ca1Cu2O8+Z', ' 80 K'],
#  'physrevb.59.r11668': ['Y1Ba2Cu4O8', ' 82 K'],
#  'physrevb.59.r11679': ['Ru1Sr2Gd1Cu2O8', ' 46 K'],
#  'physrevb.60.3064': ['Ba8Ga16Ge30', ' 7.5 K'],
#  'physrevb.60.7512': ['Ru1Sr2Gd1Cu2O8', ' 0.46 K'],
#  'physrevb.61.11317': ['Hg1Ba2Ca2Cu3O8+Z', ' 131 K'],
#  'physrevb.61.1500': ['Ca5.84Sr4.02Bi0.14Cu15.84O29', ' 75 K'],
#  'physrevb.61.1584': ['Y1Ba2Cu3O7-z', ' 74 K'],
#  'physrevb.61.6303': ['Eu1.5Ce0.5Sr2Cu1Ti1O10', ' 22 K'],
#  'physrevb.61.778': ['Sr2.3Ca0.7Cu2Cl1.3O4+z', ' 80 K'],
#  'physrevb.61.r3823': ['V1', ' 5.3 K'],
#  'physrevb.61.r9269': ['Bi1.6Pb0.6Sr1.8Ca1Cu2OZ', ' 65 K'],
#  'physrevb.63.134519': ['Lu1Ni2B2C1', ' 16 K'],
#  'physrevb.63.144519': ['Ge2U1', ' 0.8 K'],
#  'physrevb.63.172407': ['Y2Pd1Ge3', ' 3 K'],
#  'physrevb.63.220503': ['B2Mg1', ' 39.2 K'],
#  'physrevb.63.220504': ['B2Mg1', ' 39 K'],
#  'physrevb.63.220505': ['B2Mg1', ' 40 K'],
#  'physrevb.63.220507': ['Ce1Rh1In5', ' 2.2 K'],
#  'physrevb.63.220508': ['B2Mg1', ' 39 K'],
#  'physrevb.63.224510': ['U1', ' 0.78 K'],
#  'physrevb.64.012507': ['B2Mg1', ' 39 K'],
#  'physrevb.64.060506': ['B2Mg1', ' 39 K'],
#  'physrevb.64.064508': ['Ru1Sr2Eu1Cu2O8', ' 32 K'],
#  'physrevb.64.064514': ['La2Rh3Si5', ' 4.4 K'],
#  'physrevb.64.094514': ['B2Mg1', ' 39 K'],
#  'physrevb.64.094520': ['Dy1Mo6S8', ' 1.6 K'],
#  'physrevb.64.094522': ['B2Mg1', ' 40 K'],
#  'physrevb.64.100505': ['Lu1Ni2B2C1', ' 15 K'],
#  'physrevb.64.132505': ['Mg1C1Ni3', ' 8 K'],
#  'physrevb.64.132509': ['B2Mg1', ' 39 K'],
#  'physrevb.64.144524': ['La1.89Ba0.11Cu1O4', ' 10.2 K'],
#  'physrevb.64.172501': ['B2Mg1', ' 40 K'],
#  'physrevb.64.172504': ['Ba8Si46', ' 8 K'],
#  'physrevb.64.180501': ['B2Mg1', ' 39.4 K'],
#  'physrevb.64.224420': ['La3Rh2Ge2', ' 3.5 K'],
#  'physrevb.65.064504': ['S1', ' 10 K'],
#  'physrevb.65.100506': ['Pr1Os4Sb12', ' 1.85 K'],
#  'physrevb.65.100510': ['B2Mg1', ' 38 K'],
#  'physrevb.65.134508': ['B2Mg1', ' 39 K'],
#  'physrevb.65.140501': ['B2Mg1', ' 38.5 K'],
#  'physrevb.65.180504': ['Ce1Co1In5', ' 2.3 K'],
#  'physrevb.65.180505': ['B2Mg1', ' 40 K'],
#  'physrevb.65.184514': ['Mg0.99Al0.01B2', ' 39 K'],
#  'physrevb.65.214518': ['Mg1Cu1Ni3', ' 7.2 K'],
#  'physrevb.65.224509': ['Ce1Rh1In5', ' 2 K'],
#  'physrevb.65.224520': ['Sr0.9La0.1Cu1O2', ' 43 K'],
#  'physrevb.66.012510': ['Y2Cu2I2', ' 10 K'],
#  'physrevb.66.144503': ['Ru1Gd1.4Ce0.6Sr2Cu2O10+z', ' 42 K'],
#  'physrevb.66.180502': ['B2Mg1', ' 39 K'],
#  'physrevb.66.220504': ['La1Os4Sb12', ' 3 K'],
#  'physrevb.67.020506': ['Ce2Rh1In8', ' 2 K'],
#  'physrevb.67.024505': ['Ba0.61K0.39Bi1O3', ' 2 K'],
#  'physrevb.67.024519': ['N0.72H2.16Na1K3C60', ' 12 K'],
#  'physrevb.67.052501': ['Mg1C1Ni3', ' 7 K'],
#  'physrevb.67.094501': ['Ge5La1', ' 7.0 K'],
#  'physrevb.67.094502': ['Mg1C1Ni3', ' 7.6 K'],
#  'physrevb.67.094504': ['B2Mg1', ' 39 K'],
#  'physrevb.67.100509': ['Li0.48M0.3Hf1N1Cl1', ' 25.5 K'],
#  'physrevb.67.172502': ['Ru0.9Sr2Y1Cu2.1O7.9', ' 30 K'],
#  'physrevb.67.172508': ['B0.67Mg0.33', ' 4.4 K'],
#  'physrevb.67.180508': ['Pr1Os4Sb12', ' 1.85 K'],
#  'physrevb.67.212504': ['Ce1Te1.82', ' 2.7 K'],
#  'physrevb.68.024523': ['Mg1C0.977Ni3', ' 7 K'],
#  'physrevb.68.134503': ['Ca1Al1Si1', ' 6.0 K'],
#  'physrevb.68.144510': ['Mg1C1Ni3', ' 7 K'],
#  'physrevb.68.180502': ['Mg1C1Ni3', ' 7.2 K'],
#  'physrevb.68.214517': ['Na0.31Co1D2.5O3.25', ' 4.5 K'],
#  'physrevb.68.214518': ['Er1Ni1.96Fe0.04B2C0.99', ' 7.3 K'],
#  'physrevb.69.054505': ['Ho1Ni2B2C1', ' 5.5 K'],
#  'physrevb.69.060504': ['Pr1Os4Sb12', ' 1.85 K'],
#  'physrevb.69.100506': ['Ca1Al1Si1', ' 7.7 K'],
#  'physrevb.69.144514': ['B2Mg1', ' 39 K'],
#  'physrevb.69.180509': ['Pr1Ru4Sb12', ' 1.25 K'],
#  'physrevb.69.212508': ['B12Zr1', ' 6.06 K'],
#  'physrevb.7.4290': ['Mo0.18U0.82', ' 15.6 K'],
#  'physrevb.70.052511': ['Ge2Lu1', ' 2.6 K'],
#  'physrevb.70.054519': ['Li1Ti2O4', ' 11.4 K'],
#  'physrevb.70.064519': ['Ta2S2C2', ' 3.61 K'],
#  'physrevb.70.174503': ['Mg1C1.6Ni3', ' 8 K'],
#  'physrevb.70.174514': ['Hg0.7W0.3Sr2Ce1.74Eu1.26Cu2O11+z', ' 33 K'],
#  'physrevb.71.020501': ['Mg1B1.88C0.12', ' 32.9 K'],
#  'physrevb.71.045109': ['Lu2Ir3Si5', ' 3.5 K'],
#  'physrevb.71.060502': ['C1', ' 4 K'],
#  'physrevb.71.064505': ['Cu1.3K0.2Co1.5S4', ' 4.4 K'],
#  'physrevb.71.104516': ['La1.48Nd0.4Sr0.12Cu1O4', ' 41 K'],
#  'physrevb.71.132508': ['Te3Zr1', ' 2 K'],
#  'physrevb.72.014534': ['Na0.1Ta1S2', ' 4.4 K'],
#  'physrevb.72.020501': ['Zr1N1Cl0.7', ' 12.8 K'],
#  'physrevb.72.024547': ['B12Zr1', ' 6 K'],
#  'physrevb.72.054520': ['Sr2Ca12Cu24O41', ' 5 K'],
#  'physrevb.72.064520': ['C3La2', ' 13 K'],
#  'physrevb.72.144504': ['Ba24Si100', ' 1.4 K'],
#  'physrevb.72.174508': ['Ru1Sr2Gd1Cu2O8', ' 30 K'],
#  'physrevb.72.184503': ['Pr1Ru4Sb12', ' 0.97 K'],
#  'physrevb.72.214523': ['Zn2Zr1', ' 0.6 K'],
#  'physrevb.72.220505': ['B2Mg1', ' 38.7 K'],
#  'physrevb.73.024512': ['B6Y1', ' 7.2 K'],
#  'physrevb.73.052504': ['Mo1N1', ' 4.2 K'],
#  'physrevb.73.094510': ['B12Zr1', ' 6.0 K'],
#  'physrevb.73.094522': ['Y1', ' 3 K'],
#  'physrevb.73.144510': ['Y0.54Pr0.46Ba2Cu3O7-z', ' 38 K'],
#  'physrevb.73.184521': ['Li1Ti2O4', ' 12 K'],
#  'physrevb.74.012504': ['Li0.68Nb1O2', ' 5.0 K'],
#  'physrevb.74.134513': ['Pr1Pt2B2C1', ' 6 K'],
#  'physrevb.74.174501': ['Nb2As1C1', ' 2 K'],
#  'physrevb.75.054513': ['Ba8Si40Ga6', ' 3.3 K'],
#  'physrevb.75.064517': ['Nb2Se3', ' 2.0 K'],
#  'physrevb.75.174502': ['Pb1', ' 7.0 K'],
#  'physrevb.76.012505': ['Sc1', ' 8.2 K'],
#  'physrevb.76.014528': ['Al3Mg2', ' 0.87 K'],
#  'physrevb.76.100506': ['Na0.3Co1H2.6O3.3', ' 4.8 K'],
#  'physrevb.77.092505': ['Ca24Al28O66', ' 0.2 K'],
#  'physrevb.77.174503': ['La1Fe1As1F0.11O0.89', ' 28.2 K'],
#  'physrevb.77.180504': ['Th1Pt4Ge12', ' 4.62 K'],
#  'physrevb.77.180510': ['Sm1Fe1As1F0.15O0.85', ' 3.7 K'],
#  'physrevb.77.184512': ['Sr0.9La0.1Cu1O2', ' 1.6 K'],
#  'physrevb.77.193106': ['Li0.9Mo6O17', ' 1.92 K'],
#  'physrevb.78.012507': ['La1Fe1As1F0.1O0.9', ' 23.7 K'],
#  'physrevb.78.014502': ['Mo3Sb7', ' 2.1 K'],
#  'physrevb.78.014507': ['Ba0.55K0.45Fe2As2', ' 30 K'],
#  'physrevb.78.024509': ['Bi2Pd3Se2', ' 0.96 K'],
#  'physrevb.78.024514': ['Lu2Fe3Si5', ' 6 K'],
#  'physrevb.78.060506': ['C6Ca1', ' 3 K'],
#  'physrevb.78.064510': ['Pr1Os4Sb12', ' 1.55 K'],
#  'physrevb.78.064516': ['Th1Pt4Ge12', ' 4.75 K'],
#  'physrevb.78.092406': ['Eu0.5K0.5Fe2As2', ' 32 K'],
#  'physrevb.78.092503': ['La0.85Sr0.15Fe1As1O1-z', ' 26 K'],
#  'physrevb.78.100503': ['Y1Ba2Cu4O8', ' 108 K'],
#  'physrevb.78.100507': ['La1Fe1As1F0.1O0.9', ' 55 K'],
#  'physrevb.78.104527': ['Ba0.55K0.45Fe2As2', ' 38 K'],
#  'physrevb.78.134504': ['B12Lu1', ' 0.44 K'],
#  'physrevb.78.134508': ['Nd1Fe1As1F0.18O0.82', ' 50 K'],
#  'physrevb.78.172504': ['Sr1Ni2As2', ' 0.62 K'],
#  'physrevb.78.172505': ['Mo3Sb7', ' 2 K'],
#  'physrevb.78.174523': ['Nd1Fe1As1F0.3O0.7', ' 47 K'],
#  'physrevb.78.184512': ['Sm1Fe1P1O1', ' 3 K'],
#  'physrevb.78.220505': ['Ba0.55K0.45Fe2As2', ' 32 K'],
#  'physrevb.79.014514': ['Ba0.64K0.36Fe2As2', ' 26.2 K'],
#  'physrevb.79.014519': ['Fe1Se0.72', ' 8 K'],
#  'physrevb.79.020508': ['Nd1Fe1As1F0.2O0.8', ' 35 K'],
#  'physrevb.79.024514': ['Bi2Sr1.6La0.4Cu1O6+z', ' 32 K'],
#  'physrevb.79.054517': ['Ba0.6K0.4Fe2As2', ' 32 K'],
#  'physrevb.79.054520': ['Th1Pt4Ge12', ' 4.62 K'],
#  'physrevb.79.094505': ['Ba0.6K0.4Fe2As2', ' 34.6 K'],
#  'physrevb.79.094507': ['Ba1Fe1.852Co0.148As2', ' 23 K'],
#  'physrevb.79.094508': ['Ba1Ni2As2', ' 0.69 K'],
#  'physrevb.79.104501': ['Pr0.75Sr0.25Fe1As1O1', ' 16.3 K'],
#  'physrevb.79.132506': ['Ba1Ni2P2', ' 2.51 K'],
#  'physrevb.79.134507': ['Sr1Ni2P2', ' 1.4 K'],
#  'physrevb.79.140505': ['B105', ' 1.5 K'],
#  'physrevb.79.140509': ['Fe1.03Te0.7Se0.3', ' 65 K'],
#  'physrevb.79.144509': ['B3Ru7', ' 3.3 K'],
#  'physrevb.79.172506': ['Ba1Fe2As2', ' 35 K'],
#  'physrevb.79.172507': ['Ce1Pt1Si2', ' 0.14 K'],
#  'physrevb.79.174501': ['Ba0.6K0.4Fe2As2', ' 36.5 K'],
#  'physrevb.79.174505': ['La1Fe0.96Ni0.04As1O1', ' 6.5 K'],
#  'physrevb.79.174511': ['Pr1Os4Sb12', ' 1.85 K'],
#  'physrevb.79.224522': ['Sr1Pd2Ge2', ' 3.04 K'],
#  'physrevb.80.024518': ['Fe1Se1', ' 8.8 K'],
#  'physrevb.80.024519': ['Ca1Fe2As2', ' 11.5 K'],
#  'physrevb.80.052501': ['Sr1Fe2As2', ' 25 K'],
#  'physrevb.80.064504': ['Ba1Pt1Si3', ' 2.25 K'],
#  'physrevb.80.064506': ['Fe1Se1', ' 8 K'],
#  'physrevb.80.094501': ['Ba1Fe1.852Co0.148As2', ' 22.5 K'],
#  'physrevb.80.100503': ['Sr2Ca12Cu24O41', ' 3 K'],
#  'physrevb.80.134523': ['Fe1.06Te0.5Se0.5', ' 14 K'],
#  'physrevb.80.140513': ['Ce1Cu2Si2', ' 0.46 K'],
#  'physrevb.80.144524': ['Ca1Fe1.94Ni0.06As2', ' 15 K'],
#  'physrevb.80.172501': ['U1Ru2Si2', ' 17 K'],
#  'physrevb.80.180507': ['Fe1Se0.25Te0.75', ' 14 K'],
#  'physrevb.80.220509': ['La1Fe1P1O1', ' 7.4 K'],
#  'physrevb.80.224522': ['Ho1Ni2B2C', ' 8.5 K'],
#  'physrevb.81.020509': ['Fe1.11Te0.6Se0.4', ' 14 K'],
#  'physrevb.81.020510': ['Ca1Fe1.92Co0.08As2', ' 20.4 K'],
#  'physrevb.81.060501': ['Ba1Fe1.85Co0.15As2', ' 21.4 K'],
#  'physrevb.81.060509': ['Ba1Fe1.8Co0.2As2', ' 20 K'],
#  'physrevb.81.092506': ['Fe1.08Te1Ox', ' 8 K'],
#  'physrevb.81.092507': ['Cu0.06Ti1Se2', ' 2.5 K'],
#  'physrevb.81.094520': ['Ba1Fe1.73Co0.27As2', ' 8.1 K'],
#  'physrevb.81.104522': ['Ba8Si46', ' 2.3 K'],
#  'physrevb.81.140507': ['Ce1Ir1Ge3', ' 1.5 K'],
#  'physrevb.81.144414': ['Eu1Pt1Si3', ' 16 K'],
#  'physrevb.81.180507': ['Ce1Pt2In7', ' 2.1 K'],
#  'physrevb.81.184509': ['Bi1.98Sr2.06Y0.68Cu2O8+z', ' 8-10 K'],
#  'physrevb.81.184522': ['Fe1.14Te0.91S0.09', ' 28 K'],
#  'physrevb.81.205119': ['Fe1Se0.99', ' 30 K'],
#  'physrevb.81.220501': ['Ba1Fe2As1.34P0.66', ' 30 K'],
#  'physrevb.81.224511': ['Ba1Fe2As2', ' 3 K'],
#  'physrevb.82.014518': ['Nb1S2', ' 6.05 K'],
#  'physrevb.82.024503': ['Pb1.16Ti2Se5.16', ' 2.3 K'],
#  'physrevb.82.064511': ['Al2C1Mo3', ' 9 K'],
#  'physrevb.82.064512': ['Al2C1Mo3', ' 9.2 K'],
#  'physrevb.82.094502': ['Ba1Fe2As1.3P0.7', ' 30.5 K'],
#  'physrevb.82.094506': ['B1I3', ' 23 K'],
#  'physrevb.82.094517': ['Sn3Y1', ' 7 K'],
#  'physrevb.82.140507': ['Sr2V1Fe1As1O3', ' 33 K'],
#  'physrevb.82.144118': ['Ba1Fe2As2', ' 10 K'],
#  'physrevb.82.144518': ['Sr1Fe1.84Pt0.16As2', ' 16 K'],
#  'physrevb.82.144527': ['Rb1Fe2As2', ' 2.52 K'],
#  'physrevb.82.144532': ['B2Os1', ' 2.10 K'],
#  'physrevb.82.174509': ['Ba1Fe1.85Co0.15As2', ' 25 K'],
#  'physrevb.82.180512': ['Sr0.6La0.4Fe2As2', ' 26 K'],
#  'physrevb.83.054509': ['Bi2Sr1.6La0.4Cu1O6+z', ' 28 K'],
#  'physrevb.83.060502': ['Li1Fe1As1', ' 5 K'],
#  'physrevb.83.060512': ['Rb0.88Fe1.81Se2', ' 32.1 K'],
#  'physrevb.83.064504': ['Ce2Pd1In8', ' 0.7 K'],
#  'physrevb.83.064522': ['La1Rh1Si3', ' 2.16 K'],
#  'physrevb.83.100501': ['Eu1Fe2As2', ' 30 K'],
#  'physrevb.83.100502': ['Li1Fe1As1', ' 18 K'],
#  'physrevb.83.100503': ['Eu1Fe1As1.64P0.36', ' 28 K'],
#  'physrevb.83.100513': ['Sm1Fe1As1F0.15O0.85', ' 49.5 K'],
#  'physrevb.83.100514': ['K0.8Fe1.76Se2', ' 32 K'],
#  'physrevb.83.104508': ['K0.8Fe2Se2', ' 33 K'],
#  'physrevb.83.115131': ['La3Ni2B2N2.7', ' 13 K'],
#  'physrevb.83.134521': ['Fe1Te0.57Se0.43', ' 3.92 K'],
#  'physrevb.83.140501': ['Bi3Ni1', ' 4.06 K'],
#  'physrevb.83.140504': ['Bi2Te3', ' 3 K'],
#  'physrevb.83.144510': ['Ce1Co1In5', ' 3 K'],
#  'physrevb.83.144511': ['K0.8Fe2Se2', ' 32 K'],
#  'physrevb.83.144525': ['Nb0.18Re0.82', ' 8.75 K'],
#  'physrevb.83.174503': ['K0.65Fe1.41Se2', ' 31.8 K'],
#  'physrevb.83.174506': ['Li1Fe1As1', ' 18 K'],
#  'physrevb.83.174510': ['Tl0.47Rb0.34Fe1.63Se2', ' 32 K'],
#  'physrevb.83.174520': ['La1Sb2', ' 2.5 K'],
#  'physrevb.83.214513': ['Eu1Fe2As2', ' 30 K'],
#  'physrevb.83.220512': ['Ca1', ' 3 K'],
#  'physrevb.83.224512': ['Li1Fe1As1', ' 14.7 K'],
#  'physrevb.84.024502': ['Eu1Fe2As2', ' 20 K'],
#  'physrevb.84.024509': ['Ba1Fe1.922Rh0.078As2', ' 14 K'],
#  'physrevb.84.054507': ['Li1Fe1As1', ' 18 K'],
#  'physrevb.84.054531': ['Nb1S2', ' 6.05 K'],
#  'physrevb.84.054541': ['Lu2Fe3Si5', ' 6.0 K'],
#  'physrevb.84.064518': ['Bi1Pd1', ' 3.8 K'],
#  'physrevb.84.064525': ['Ba0.65Na0.35Fe2As2', ' 29.4 K'],
#  'physrevb.84.104502': ['Li1Fe1As1', ' 18 K'],
#  'physrevb.84.140507': ['Ce2Pd1In8', ' 0.68 K'],
#  'physrevb.84.174502': ['Fe1Se0.42Te0.58', ' 14.8 K'],
#  'physrevb.84.214527': ['La1Ru3Si2', ' 7.8 K'],
#  'physrevb.84.220504': ['Y1Pt1Bi1', ' 0.77 K'],
#  'physrevb.85.014520': ['Sr1Pd2Ge2', ' 2.7 K'],
#  'physrevb.85.024526': ['U1Co1Ge1', ' 2.8 K'],
#  'physrevb.85.024538': ['Sr1Ni2Ge2', ' 0.92 K'],
#  'physrevb.85.054507': ['K0.8Fe1.7S1Se1', ' 26.3 K'],
#  'physrevb.85.054517': ['La1Ni2P2', ' 0.70 K'],
#  'physrevb.85.064504': ['Fe1.08Te0.55Se0.45Ox', ' 14.5 K'],
#  'physrevb.85.064513': ['Tl0.58Rb0.42Fe1.72Se2', ' 33.5 K'],
#  'physrevb.85.180504': ['Ca10Pt3.97Fe9.03As18', ' 11 K'],
#  'physrevb.85.180505': ['Li1Fe1As1', ' 15 K'],
#  'physrevb.85.184501': ['Ca0.67Sr0.33Fe2As2', ' 22.2 K'],
#  'physrevb.85.184513': ['Te3Zr1', ' 2 K'],
#  'physrevb.85.205105': ['Ce1Cu2Si2', ' 4.5 K'],
#  'physrevb.85.214526': ['Yb1Sb2', ' 1.3 K'],
#  'physrevb.85.224504': ['Ba0.55K0.45Fe1.95Co0.05As2', ' 32.5 K'],
#  'physrevb.86.020501': ['Ce1Fe1As0.7P0.3O1', ' 4 K'],
#  'physrevb.86.054502': ['Rh3Bi14', ' 2.94 K'],
#  'physrevb.86.064504': ['Ca3Ir4Sn13', ' 7 K'],
#  'physrevb.86.064516': ['Li1Fe1As1', ' 18 K'],
#  'physrevb.86.144525': ['Sr1Fe2As1.4P0.6', ' 25 K'],
#  'physrevb.86.220509': ['Fe1Te0.6Se0.4', ' 12 K'],
#  'physrevb.86.220510': ['Bi4S3O4', ' 8.6 K'],
#  'physrevb.86.224514': ['K1Fe2As2', ' 3.8 K'],
#  'physrevb.87.020504': ['Sr0.5La0.5F1Bi1S2', ' 2.8 K'],
#  'physrevb.87.024508': ['Te3Zr1', ' 4 K'],
#  'physrevb.87.045124': ['K1Ni2S2', ' 0.46 K'],
#  'physrevb.87.054504': ['Li1Fe1P1', ' 4.86 K'],
#  'physrevb.87.060510': ['Ba1Ti2Sb2O1', ' 0.95 K'],
#  'physrevb.87.064502': ['Pr1Pt4Ge12', ' 8 K'],
#  'physrevb.87.094515': ['Sr1Pd2Ge2', ' 2.7 K'],
#  'physrevb.87.104515': ['Mo3Sb7', ' 2.35 K'],
#  'physrevb.87.134512': ['Fe1Se1', ' 8 K'],
#  'physrevb.87.134513': ['K1Fe2As2', ' 3.8 K'],
#  'physrevb.87.140507': ['Sn0.6In0.4Te1', ' 3.50 K'],
#  'physrevb.87.144502': ['Cs1Fe2As2', ' 1.81 K'],
#  'physrevb.87.174510': ['Ir3Te8', ' 1.8 K'],
#  'physrevb.87.180508': ['Pr4Fe2As2Te0.88O4', ' 25 K'],
#  'physrevb.87.184504': ['Lu1Pt1Bi1', ' 1.0 K'],
#  'physrevb.87.214504': ['La1Sb2', ' 1.2 K'],
#  'physrevb.87.214509': ['Cs1Fe2As2', ' 1.8 K'],
#  'physrevb.87.224507': ['Sr1Pt2As2', ' 5 K'],
#  'physrevb.88.014517': ['K1Fe2As2', ' 3.4 K'],
#  'physrevb.88.024423': ['La3Pd4Si4', ' 2 K'],
#  'physrevb.88.140501': ['Ba0.75Na0.25Ti2Sb2O1', ' 58 K'],
#  'physrevb.88.144511': ['La1Pd0.85Bi2', ' 2.1 K'],
#  'physrevb.88.180509': ['La0.5Bi1S2F0.5O0.5', ' 10 K'],
#  'physrevb.88.184508': ['Bi3Ni1', ' 4 K'],
#  'physrevb.88.224510': ['Eu1Fe2As2', ' 26 K'],
#  'physrevb.88.224515': ['Bi4S3O4', ' 4.5 K'],
#  'physrevb.89.020505': ['Pb1Ta1Se2', ' 3.72 K'],
#  'physrevb.89.020507': ['Li1Fe3Se2O2', ' 43 K'],
#  'physrevb.89.024518': ['Sm4Fe2As2Te0.72F1.2O2.8', ' 45 K'],
#  'physrevb.89.054512': ['Ca10Bi9.88', ' 2.2 K'],
#  'physrevb.89.094520': ['Sr3Ir4Sn13', ' 5 K'],
#  'physrevb.89.100501': ['Ir0.95Pd0.05Te2', ' 3 K'],
#  'physrevb.89.140504': ['Sr1Pt1As1', ' 2.40 K'],
#  'physrevb.89.174515': ['La1F0.5Bi1S2O0.5', ' 11 K'],
#  'physrevb.89.205136': ['Ca10Pt0.78Fe9.22As18', ' 10 K'],
#  'physrevb.89.224504': ['Ca3Ir4Ge4', ' 1.8 K'],
#  'physrevb.90.014513': ['La1Ir1Si3', ' 0.72 K'],
#  'physrevb.90.020502': ['K0.5Na0.24Fe1.52Se2', ' 20 K'],
#  'physrevb.90.035115': ['Sr3Ir4Sn13', ' 5 K'],
#  'physrevb.90.064518': ['Eu1Bi1S2F1', ' 0.3 K'],
#  'physrevb.90.144508': ['Ba2Ti2Fe2As4O1', ' 21.5 K'],
#  'physrevb.90.220504': ['C1.36Pb5Bi12Se23', ' 2.9 K'],
#  'physrevb.90.220508': ['La1Ni1C2', ' 3 K'],
#  'physrevb.90.220510': ['Eu3Bi2S4F4', ' 1.5 K'],
#  'physrevb.90.224410': ['Ce1Bi1S2F0.7O0.3', ' 4.5 K'],
#  'physrevb.90.224513': ['Ca10Ir4Fe10As18', ' 16 K'],
#  'physrevb.91.014513': ['Ba1Pt2Sb2', ' 1.82 K'],
#  'physrevb.91.020507': ['K2Cr3As3', ' 6.1 K'],
#  'physrevb.91.024509': ['Pd2Hf1Al1', ' 3.53 K'],
#  'physrevb.91.060508': ['K1Fe2As2', ' 3 K'],
#  'physrevb.91.060510': ['Sr1Pt2As2', ' 5.2 K'],
#  'physrevb.91.064509': ['La1Fe1As1H0.44O0.56', ' 49 K'],
#  'physrevb.91.094427': ['Eu1Fe1.72Ir0.28As2', ' 22.5 K'],
#  'physrevb.91.100504': ['Nb2Pd1S5', ' 6.6 K'],
#  'physrevb.91.104506': ['Ta4Pd3Te16', ' 4.3 K'],
#  'physrevb.91.104511': ['Bi3S3O2', ' 4.03 K'],
#  'physrevb.91.125107': ['Li0.8Fe1.2H1Se1', ' 34 K'],
#  'physrevb.91.134508': ['Nb0.18Re0.82', ' 8.8 K'],
#  'physrevb.91.174513': ['Bi2Rh3.5S2', ' 1.7 K'],
#  'physrevb.91.214517': ['Au2Pb1', ' 100 K'],
#  'physrevb.91.220505': ['K2Cr3As3', ' 6.1 K'],
#  'physrevb.92.020506': ['Sr0.1Bi2Se3', ' 2.9 K'],
#  'physrevb.92.024511': ['Th1Pt3B1', ' 0.75 K'],
#  'physrevb.92.134517': ['Sr0.3M1Fe2Se2', ' 36.3 K'],
#  'physrevb.92.161114': ['Ce3Pt1In11', ' 0.32 K'],
#  'physrevb.93.054508': ['Li1Fe1As1', ' 18 K'],
#  'physrevb.93.054520': ['Pb1Ta1Se2', ' 3.8 K'],
#  'physrevb.93.060506': ['Pb1Ta1Se2', ' 3.7 K'],
#  'physrevb.93.064504': ['Sr1Pt1As1', ' 2.45 K'],
#  'physrevb.93.094511': ['Bi2Te1', ' 8.6 K'],
#  'physrevb.93.104508': ['M0.37Cs0.268Fe1Se1', ' 33 K'],
#  'physrevb.93.104516': ['Ba0.85K0.15Fe2As2', ' 13.5 K'],
#  'physrevb.93.115119': ['Ba1Fe2As1.34P0.66', ' 29 K'],
#  'physrevb.93.144502': ['Bi2Pd1', ' 5 K'],
#  'physrevb.93.214503': ['Rb1Eu1Fe4As4', ' 36.5 K'],
#  'physrevb.93.220504': ['Bi2Pd1', ' 4.84 K'],
#  'physrevb.93.224512': ['Li1.84H1Fe1.14Se1O1', ' 40 K'],
#  'physrevb.93.224516': ['Cs1Fe2As2', ' 13 K'],
#  'physrevb.93.241112': ['La3Co4Sn13', ' 152 K'],
#  'physrevb.94.024518': ['Hf1Re6', ' 6.2 K'],
#  'physrevb.94.035130': ['Y1Pt1Bi1', ' 0.97 K'],
#  'physrevb.94.054514': ['Ce1Cu2Si2', ' 0.6 K'],
#  'physrevb.94.054515': ['Hf1Re6', ' 5.96 K'],
#  'physrevb.94.054517': ['Hf1Te5', ' 4.8 K'],
#  'physrevb.94.054523': ['La1Pt4Ge12', ' 8.3 K'],
#  'physrevb.94.064501': ['Ca1K1Fe4As4', ' 35.0 K'],
#  'physrevb.94.104507': ['Ba8Si46', ' 8.5-9 K'],
#  'physrevb.94.144515': ['Re6Zr1', ' 6.7 K'],
#  'physrevb.94.180509': ['Y1Sr2Mo0.25Cu2.75O7.54', ' 84 K'],
#  'physrevb.95.014502': ['K2Cr3As3', ' 6.2 K'],
#  'physrevb.95.024510': ['Bi1', ' 3.92 K'],
#  'physrevb.95.035148': ['Ir1Te2', ' 2.5 K'],
#  'physrevb.95.060505': ['Ba1Fe1.915Ni0.085As2', ' 3.25 K'],
#  'physrevb.95.064514': ['Ge1Sb2Te4', ' 6 K'],
#  'physrevb.95.094510': ['Ca8.5La1.5Pt3Fe10As18', ' 32.8 K'],
#  'physrevb.95.140505': ['Ca1K1Fe4As4', ' 31-36 K'],
#  'physrevb.95.174521': ['Ta1Ir2Ge2', ' 3.5 K'],
#  'physrevb.96.060509': ['Pd1Se2', ' 13.1 K'],
#  'physrevb.96.064512': ['Li0.36M1Fe2Se2', ' 44.56 K'],
#  'physrevb.96.064521': ['Re6Zr1', ' 6.75 K'],
#  'physrevb.96.064528': ['Pb1Ta1Se2', ' 3 K'],
#  'physrevb.96.094523': ['Ba1Fe1.864Rh0.136As2', ' 22.3 K'],
#  'physrevb.96.140501': ['Ca1K1Fe4As4', ' 35 K'],
#  'physrevb.96.144502': ['Th1As1Fe1N1', ' 30 K'],
#  'physrevb.96.165123': ['Se1Sn1', ' 3.2 K'],
#  'physrevb.96.224433': ['Sm0.04La0.96Ni1C2', ' 2.7 K'],
#  'physrevb.97.014501': ['Au1Be1', ' 3.3 K'],
#  'physrevb.97.014514': ['Tl1Ni2Se2', ' 3.05 K'],
#  'physrevb.97.014523': ['Pd1Te2', ' 0.38 K'],
#  'physrevb.97.020502': ['Re24Ti5', ' 6 K'],
#  'physrevb.97.020508': ['Li0.36M1Fe2As2', ' 55 K'],
#  'physrevb.97.024501': ['Sr1Au1Si3', ' 1.54 K'],
#  'physrevb.97.054506': ['B2Ru1', ' 1.5 K'],
#  'physrevb.97.054515': ['Pd1Te2', ' 1.7 K'],
#  'physrevb.97.060506': ['Cs1Ca2Fe4As4F2', ' 28.3 K'],
#  'physrevb.97.060509': ['K1Ca2Fe4As4F2', ' 33.36 K'],
#  'physrevb.97.064514': ['Ce1Rh1Ge3', ' 1.3 K'],
#  'physrevb.97.100504': ['La1Fe1Si1H1', ' 11 K'],
#  'physrevb.97.104509': ['La1Bi1S2F0.5O0.5', ' 3 K'],
#  'physrevb.97.134508': ['Ba1Pd2As2', ' 3.85 K'],
#  'physrevb.97.224506': ['Re6Zr1', ' 6.8 K'],
#  'physrevb.97.224511': ['Tb1Pd1Bi1', ' 1.7 K'],
#  'physrevb.98.014502': ['Ta1Rh2B2', ' 15.2 T'],
#  'physrevb.98.020503': ['Na1Sn2As2', ' 1.3 K'],
#  'physrevb.98.024520': ['As1Cr1', ' 2 K'],
#  'physrevb.98.094504': ['Nd1Fe1As1F0.1O0.9', ' 45.4 K'],
#  'physrevb.98.094519': ['Ir0.8Rh0.2Te2', ' 2.45 K'],
#  'physrevb.98.104503': ['Rb1Eu1Fe4As4', ' 36.8 K'],
#  'physrevb.98.104506': ['Re3Ta1', ' 4.68 K'],
#  'physrevb.98.134512': ['Cr0.8Ru0.2', ' 1.35 K'],
#  'physrevb.98.214505': ['La1Pt1Ge1', ' 3.05 K'],
#  'physrevb.98.224505': ['Ba1Fe1.9Pt0.1As2', ' 23 K'],
#  'physrevb.99.054503': ['Ga41Mo1', ' 10 K'],
#  'physrevb.99.100501': ['Ce1Ni1C2', ' 3.5 K'],
#  'physrevb.99.134509': ['Au1Be1', ' 3.2 K'],
#  'physrevb.99.144511': ['H1Pt1', ' 7 K'],
#  'physrevb.99.144519': ['Al6Re1', ' 0.74 K'],
#  'physrevb.99.174513': ['Zr1Ir1Si1', ' 1.7 K'],
#  'physrevb.99.184509': ['P1W1', ' 0.8 K'],
#  'physrevb.99.184513': ['Mo3P1', ' 5.5 K'],
#  'questions': ["What is the critical temperature at zero-field of {MATERIAL}? Just give a number and do not provide any explanation. Format the answer as CRITICAL TEMPERATURE: {Number} K. Do not write a sentence before the output. Here are some example outputs: 'CRITICAL TEMPERATURE: 3 K', 'CRITICAL TEMPERATURE: 15.6 K'"]}

# %%
def format_material_string(string, splitchar):
    string = string.replace('MATERIAL:', '')
    string_list = "".join(string.split()).split(splitchar)
    return string_list
    
def format_temperature_string(temp_list):
    temp_list = "".join(temp_list.replace('K', '').split()).split(',')
    temp_list = [temp_string[:-1] if temp_string[-1] == '.' else temp_string for temp_string in temp_list]
    temp_list_float = []
    for temp in temp_list:
        try:
            temp_list_float.append(float(temp))
        except ValueError:
            print(temp)
            temp_list_float.append(-100.0)
    return temp_list_float

def standard_chem_formula(dictionary):
    return ''.join(char for char in ''.join(key for key in sorted(dictionary.keys())) if char.isalpha() or char.isnumeric())

# %%
processed_model_output = {}
for key in model_output.keys():
    if key == 'questions': continue
    materials = format_material_string(model_output[key][0], '&')
    temperatures = format_temperature_string(model_output[key][1])
    if len(materials) - len(temperatures) != 0: continue
    materials = list(set(materials))
    indices = [materials.index(s) for s in materials]
    if len(materials) > len(temperatures):
        temperatures = temperatures + [-100.0] * (len(materials) - len(temperatures))
    temperatures = [temperatures[i] for i in indices]
    processed_model_output[key] = (materials, temperatures)
# Out:
# 563+5m
# 8-10
# 8.5-9
# 31-36
# 15.2T

# %%
processed_database_output = {}
for key in database.keys():
    materials = format_material_string(database[key][0], ',')
    temperatures = format_temperature_string(database[key][1].replace('CRITICAL TEMPERATURE:', ''))
    if len(materials) > len(temperatures):
        temperatures = temperatures + [-100.0] * (len(materials) - len(temperatures))
    processed_database_output[key] = (materials, temperatures)

# %%
shared_keys = list(sorted(processed_model_output.keys() & processed_database_output.keys()))
processed_model_output = {key:processed_model_output[key] for key in shared_keys}
processed_database_output = {key:processed_database_output[key] for key in shared_keys}

# %%
processed_model_output
# Out:
# {'physrevb.10.4572': (['Ga1'], [6.07]),
#  'physrevb.100.014503': (['Eu1Fe2As2'], [27.0]),
#  'physrevb.100.014507': (['Pd1S2'], [8.0]),
#  'physrevb.100.041109': (['Rb1'], [2.0]),
#  'physrevb.100.060103': (['Au2Pb1'], [4.0]),
#  'physrevb.100.094511': (['Rb1Cr3As3'], [7.17]),
#  'physrevb.100.094522': (['W3Al2C1'], [7.6]),
#  'physrevb.100.134503': (['Ta1Os1Si1'], [5.8]),
#  'physrevb.23.2219': (['K0.18W1O3'], [1.2]),
#  'physrevb.26.6315': (['K1Hg1C4'], [1.7]),
#  'physrevb.28.1389': (['La1Ir2Si2'], [1.58]),
#  'physrevb.30.1182': (['Ce1Cu2Si2'], [2.0]),
#  'physrevb.30.1583': (['Pt3U1'], [0.54]),
#  'physrevb.30.2986': (['Pt3U1'], [0.49]),
#  'physrevb.30.444': (['Ce1Ru3Si2'], [1.0]),
#  'physrevb.30.5135': (['Co35.38Zr64.62'], [2.67]),
#  'physrevb.31.1654': (['Pt3U1'], [17.6]),
#  'physrevb.32.135': (['Pd2Yb1Sn1'], [2.46]),
#  'physrevb.34.4590': (['Lu5Ir4Si10'], [79.0]),
#  'physrevb.34.4920': (['Ga1'], [0.7]),
#  'physrevb.36.3906': (['La1.8Sr0.2Cu1O4'], [39.0]),
#  'physrevb.36.3910': (['Y1.2Ba0.8Cu1O4'], [34.0]),
#  'physrevb.36.3920': (['Y1Ba2Cu3O7+Y'], [92.0]),
#  'physrevb.36.4003': (['La1.85Sr0.15Cu1O4'], [36.0]),
#  'physrevb.36.4014': (['Y1Ba2Cu3O7'], [93.0]),
#  'physrevb.36.4018': (['Gd1Ba2Cu2.82Fe0.18O9-Z'], [31.0]),
#  'physrevb.36.8329': (['Y1Ba2Cu3O7-Z'], [92.4]),
#  'physrevb.36.8660': (['La1Fe4P12'], [4.0]),
#  'physrevb.36.8791': (['Er1Ba2Cu3O7-Z'], [0.87]),
#  'physrevb.38.11955': (['Bi2Sr2Ca1Cu2O8'], [90.0]),
#  'physrevb.38.225': (['Tl2Ba2Cu1O6'], [90.0]),
#  'physrevb.38.2455': (['Ho1Ba2Cu3O6.9'], [91.5]),
#  'physrevb.39.11445': (['La2Cu1O4+Z'], [37.0]),
#  'physrevb.39.6571': (['Y1Ba2Cu3O7'], [92.0]),
#  'physrevb.39.7339': (['Ba0.6K0.4Bi1O3-Z'], [30.0]),
#  'physrevb.39.9074': (['La1Ba1Ca1Cu3O6.98'], [78.5]),
#  'physrevb.40.2690': (['Ba0.6Rb0.4Bi1O3'], [29.0]),
#  'physrevb.40.841': (['Bi2Sr2Ca1Cu2O8'], [84.0]),
#  'physrevb.41.2520': (['La1.96Sr0.04Cu1O4'], [9.5]),
#  'physrevb.41.9551': (['Bi2Sr2Ca1Cu2O8+z'], [30.0]),
#  'physrevb.45.4803': (['Si2Ta1'], [0.353]),
#  'physrevb.45.5628': (['Tl2Ba2Ca1Cu2O8'], [102.0]),
#  'physrevb.48.16869': (['Y1Ba2Cu4O8'], [120.0]),
#  'physrevb.49.12322': (['Hg0.66Pb0.33Ba2Ca2Cu3Oy'], [133.0]),
#  'physrevb.49.13075': (['Hg1Ba2Cu1O4+d'], [94.0]),
#  'physrevb.49.13184': (['Bi2Sr2Ca1Cu2O8+y'], [110.0]),
#  'physrevb.49.1492': (['Bi0.5Sr1.5Y1.15Ce0.85Cu2O8-z'], [34.0]),
#  'physrevb.49.1495': (['Bi2Sr2Ca2Cu3O10'], [110.3]),
#  'physrevb.49.15416': (['Hg1Ba2Ca2Cu3O8+d'], [132.0]),
#  'physrevb.49.15959': (['Bi2Sr2Ca1Cu2O8'], [3.0]),
#  'physrevb.49.3502': (['Ba0.64K0.36Bi1O3'], [32.0]),
#  'physrevb.49.3683': (['Hg1Ba2Cu1O4+d'], [97.0]),
#  'physrevb.49.6392': (['Nd1.85Ce0.15Cu1O4'], [16.0]),
#  'physrevb.49.8931': (['Tl2Mo6Se6'], [6.5]),
#  'physrevb.49.9073': (['Bi2Sr2Ca1Cu2O8'], [38.0]),
#  'physrevb.49.9097': (['La1.925Sr0.075Cu1O4+d'], [23.0]),
#  'physrevb.49.9218': (['Bi2Sr2Ca1Cu2O8+d'], [90.7]),
#  'physrevb.49.9885': (['I1Bi2.2Sr1.8Ca1Cu2O8+y'], [73.6]),
#  'physrevb.49.9924': (['Y1Ba2Cu3O7-d'], [90.0]),
#  'physrevb.50.13890': (['Ba6C60'], [7.0]),
#  'physrevb.50.15875': (['La1.85Sr0.15Cu1O4'], [36.0]),
#  'physrevb.50.16125': (['Y1Ba2Cu3Oy'], [91.5]),
#  'physrevb.50.351': (['Sc1Ni2B2C1'], [14.6]),
#  'physrevb.50.426': (['Y2Ba4Cu7O15.1'], [15.1]),
#  'physrevb.50.496': (['Bi2Sr1.9Cu2.1Ox'], [7.5]),
#  'physrevb.50.6523': (['La1Ni1Si1'], [1.23]),
#  'physrevb.51.12644': (['Ho1Ni2B2C1'], [8.4]),
#  'physrevb.51.12747': (['Tl1.89Ba2Cu1.11O6.18'], [49.0]),
#  'physrevb.51.1286': (['La2Cu1O4.035'], [222.0]),
#  'physrevb.51.1393': (['Pb0.17Hg1.22Ba2Ca1.44Cu2.79Ox'], [133.6]),
#  'physrevb.51.1397': (['Bi1.8Pb0.4Sr2Ca2Cu3O10+d'], [104.0]),
#  'physrevb.51.15478': (['Y2Ba4Cu7O14.97'], [93.1]),
#  'physrevb.51.3316': (['Y1Ba2Cu3O7-d'], [92.5]),
#  'physrevb.52.10569': (['Y1Ba2Cu3O6.95'], [92.0]),
#  'physrevb.52.1181': (['Ho1Ni2B2C1'], [5.2]),
#  'physrevb.52.15534': (['C60Sm3'], [2.0]),
#  'physrevb.52.3071': (['Nd1.85Ce0.15Cu1O4-d'], [24.0]),
#  'physrevb.52.4432': (['Rb1Cs2C60'], [33.0]),
#  'physrevb.52.483': (['K3N1H3C60'], [28.0]),
#  'physrevb.52.7647': (['Bi2Sr2Ca1Cu2O8+y'], [92.0]),
#  'physrevb.52.r3844': (['Dy1Ni2B2C1'], [6.2]),
#  'physrevb.53.12299': (['Rh1Zr2'], [11.0]),
#  'physrevb.53.12389': (['Tm2Fe3Si5'], [1.15]),
#  'physrevb.53.5170': (['Ba2Ca3Cu5O11-y'], [115.9]),
#  'physrevb.53.8238': (['La1'], [520.0]),
#  'physrevb.53.8241': (['Ce1Rh2Si2'], [0.35]),
#  'physrevb.54.6133': (['BaKBi1O3'], [31.8]),
#  'physrevb.54.r3772': (['Lu1Ni2B2C1'], [16.0]),
#  'physrevb.54.r6885': (['Bi2Sr1.8Ca1.2Cu2O8'], [79.5]),
#  'physrevb.55.11789': (['Y1Ba2Cu3O6.95'], [93.2]),
#  'physrevb.55.15300': (['Y1Ba2Cu3O6.92'], [90.0]),
#  'physrevb.55.8529': (['Bi2Sr2Ca1Cu2O8+y'], [115.0]),
#  'physrevb.55.9125': (['Bi2Sr2Ca1Cu2O8+y'], [90.0]),
#  'physrevb.55.r6145': (['Pr1.85Ce0.15Cu1O4-z'], [21.0]),
#  'physrevb.55.r8674': (['Hg1Ba2Ca2Cu3O8+y'], [110.4]),
#  'physrevb.56.5631': (['Tb1Sr2Cu2.69Mo0.31O7'], [32.0]),
#  'physrevb.56.7890': (['Sr2Ru1O4'], [1.0]),
#  'physrevb.56.8346': (['Ca3Rh4Sn13'], [8.2]),
#  'physrevb.57.613': (['Sr0.4Ca13.6Cu24O41+z'], [13.0]),
#  'physrevb.57.r14084': (['Y1Ba2Cu3O7-d'], [84.0]),
#  'physrevb.58.497': (['La1Ni1C2'], [2.7]),
#  'physrevb.58.r603': (['Pt3U1'], [-100.0]),
#  'physrevb.59.11179': (['Bi2Sr2Ca1Cu2O8+X'], [79.0]),
#  'physrevb.59.11563': (['Nd1Ba2Cu3O7-Z'], [95.65]),
#  'physrevb.59.13639': (['Y0.5Yb0.5Ba2Sr0Cu3O7-Z'], [89.0]),
#  'physrevb.59.14099': (['Ru1Sr2Gd1Cu2O8'], [16.0]),
#  'physrevb.59.14753': (['La1.905Ba0.095Cu1O4'], [31.0]),
#  'physrevb.59.3827': (['La1.85Sr0.15Cu1O4'], [43.7]),
#  'physrevb.59.7266': (['Lu5Ir4Si10'], [83.0]),
#  'physrevb.59.8962': (['I1Bi1.9Pb0.1Sr2Ca1Cu2O8+Z'], [80.0]),
#  'physrevb.59.r11668': (['Y1Ba2Cu4O8'], [82.0]),
#  'physrevb.59.r11679': (['Ru1Sr2Gd1Cu2O8'], [46.0]),
#  'physrevb.60.3064': (['Ba8Ga16Ge30'], [7.5]),
#  'physrevb.60.7512': (['Ru1Sr2Gd1Cu2O8'], [0.46]),
#  'physrevb.61.11317': (['Hg1Ba2Ca2Cu3O8+Z'], [131.0]),
#  'physrevb.61.1500': (['Ca5.84Sr4.02Bi0.14Cu15.84O29'], [75.0]),
#  'physrevb.61.1584': (['Y1Ba2Cu3O7-z'], [74.0]),
#  'physrevb.61.6303': (['Eu1.5Ce0.5Sr2Cu1Ti1O10'], [22.0]),
#  'physrevb.61.778': (['Sr2.3Ca0.7Cu2Cl1.3O4+z'], [80.0]),
#  'physrevb.61.r3823': (['V1'], [5.3]),
#  'physrevb.61.r9269': (['Bi1.6Pb0.6Sr1.8Ca1Cu2OZ'], [65.0]),
#  'physrevb.63.134519': (['Lu1Ni2B2C1'], [16.0]),
#  'physrevb.63.144519': (['Ge2U1'], [0.8]),
#  'physrevb.63.172407': (['Y2Pd1Ge3'], [3.0]),
#  'physrevb.63.220503': (['B2Mg1'], [39.2]),
#  'physrevb.63.220504': (['B2Mg1'], [39.0]),
#  'physrevb.63.220505': (['B2Mg1'], [40.0]),
#  'physrevb.63.220507': (['Ce1Rh1In5'], [2.2]),
#  'physrevb.63.220508': (['B2Mg1'], [39.0]),
#  'physrevb.63.224510': (['U1'], [0.78]),
#  'physrevb.64.012507': (['B2Mg1'], [39.0]),
#  'physrevb.64.060506': (['B2Mg1'], [39.0]),
#  'physrevb.64.064508': (['Ru1Sr2Eu1Cu2O8'], [32.0]),
#  'physrevb.64.064514': (['La2Rh3Si5'], [4.4]),
#  'physrevb.64.094514': (['B2Mg1'], [39.0]),
#  'physrevb.64.094520': (['Dy1Mo6S8'], [1.6]),
#  'physrevb.64.094522': (['B2Mg1'], [40.0]),
#  'physrevb.64.100505': (['Lu1Ni2B2C1'], [15.0]),
#  'physrevb.64.132505': (['Mg1C1Ni3'], [8.0]),
#  'physrevb.64.132509': (['B2Mg1'], [39.0]),
#  'physrevb.64.144524': (['La1.89Ba0.11Cu1O4'], [10.2]),
#  'physrevb.64.172501': (['B2Mg1'], [40.0]),
#  'physrevb.64.172504': (['Ba8Si46'], [8.0]),
#  'physrevb.64.180501': (['B2Mg1'], [39.4]),
#  'physrevb.64.224420': (['La3Rh2Ge2'], [3.5]),
#  'physrevb.65.064504': (['S1'], [10.0]),
#  'physrevb.65.100506': (['Pr1Os4Sb12'], [1.85]),
#  'physrevb.65.100510': (['B2Mg1'], [38.0]),
#  'physrevb.65.134508': (['B2Mg1'], [39.0]),
#  'physrevb.65.140501': (['B2Mg1'], [38.5]),
#  'physrevb.65.180504': (['Ce1Co1In5'], [2.3]),
#  'physrevb.65.180505': (['B2Mg1'], [40.0]),
#  'physrevb.65.184514': (['Mg0.99Al0.01B2'], [39.0]),
#  'physrevb.65.214518': (['Mg1Cu1Ni3'], [7.2]),
#  'physrevb.65.224509': (['Ce1Rh1In5'], [2.0]),
#  'physrevb.65.224520': (['Sr0.9La0.1Cu1O2'], [43.0]),
#  'physrevb.66.012510': (['Y2Cu2I2'], [10.0]),
#  'physrevb.66.144503': (['Ru1Gd1.4Ce0.6Sr2Cu2O10+z'], [42.0]),
#  'physrevb.66.180502': (['B2Mg1'], [39.0]),
#  'physrevb.66.220504': (['La1Os4Sb12'], [3.0]),
#  'physrevb.67.020506': (['Ce2Rh1In8'], [2.0]),
#  'physrevb.67.024505': (['Ba0.61K0.39Bi1O3'], [2.0]),
#  'physrevb.67.024519': (['N0.72H2.16Na1K3C60'], [12.0]),
#  'physrevb.67.052501': (['Mg1C1Ni3'], [7.0]),
#  'physrevb.67.094501': (['Ge5La1'], [7.0]),
#  'physrevb.67.094502': (['Mg1C1Ni3'], [7.6]),
#  'physrevb.67.094504': (['B2Mg1'], [39.0]),
#  'physrevb.67.100509': (['Li0.48M0.3Hf1N1Cl1'], [25.5]),
#  'physrevb.67.172502': (['Ru0.9Sr2Y1Cu2.1O7.9'], [30.0]),
#  'physrevb.67.172508': (['B0.67Mg0.33'], [4.4]),
#  'physrevb.67.180508': (['Pr1Os4Sb12'], [1.85]),
#  'physrevb.67.212504': (['Ce1Te1.82'], [2.7]),
#  'physrevb.68.024523': (['Mg1C0.977Ni3'], [7.0]),
#  'physrevb.68.134503': (['Ca1Al1Si1'], [6.0]),
#  'physrevb.68.144510': (['Mg1C1Ni3'], [7.0]),
#  'physrevb.68.180502': (['Mg1C1Ni3'], [7.2]),
#  'physrevb.68.214517': (['Na0.31Co1D2.5O3.25'], [4.5]),
#  'physrevb.68.214518': (['Er1Ni1.96Fe0.04B2C0.99'], [7.3]),
#  'physrevb.69.054505': (['Ho1Ni2B2C1'], [5.5]),
#  'physrevb.69.060504': (['Pr1Os4Sb12'], [1.85]),
#  'physrevb.69.100506': (['Ca1Al1Si1'], [7.7]),
#  'physrevb.69.144514': (['B2Mg1'], [39.0]),
#  'physrevb.69.180509': (['Pr1Ru4Sb12'], [1.25]),
#  'physrevb.69.212508': (['B12Zr1'], [6.06]),
#  'physrevb.7.4290': (['Mo0.18U0.82'], [15.6]),
#  'physrevb.70.052511': (['Ge2Lu1'], [2.6]),
#  'physrevb.70.054519': (['Li1Ti2O4'], [11.4]),
#  'physrevb.70.064519': (['Ta2S2C2'], [3.61]),
#  'physrevb.70.174503': (['Mg1C1.6Ni3'], [8.0]),
#  'physrevb.70.174514': (['Hg0.7W0.3Sr2Ce1.74Eu1.26Cu2O11+z'], [33.0]),
#  'physrevb.71.020501': (['Mg1B1.88C0.12'], [32.9]),
#  'physrevb.71.045109': (['Lu2Ir3Si5'], [3.5]),
#  'physrevb.71.060502': (['C1'], [4.0]),
#  'physrevb.71.064505': (['Cu1.3K0.2Co1.5S4'], [4.4]),
#  'physrevb.71.104516': (['La1.48Nd0.4Sr0.12Cu1O4'], [41.0]),
#  'physrevb.71.132508': (['Te3Zr1'], [2.0]),
#  'physrevb.72.014534': (['Na0.1Ta1S2'], [4.4]),
#  'physrevb.72.020501': (['Zr1N1Cl0.7'], [12.8]),
#  'physrevb.72.024547': (['B12Zr1'], [6.0]),
#  'physrevb.72.054520': (['Sr2Ca12Cu24O41'], [5.0]),
#  'physrevb.72.064520': (['C3La2'], [13.0]),
#  'physrevb.72.144504': (['Ba24Si100'], [1.4]),
#  'physrevb.72.174508': (['Ru1Sr2Gd1Cu2O8'], [30.0]),
#  'physrevb.72.184503': (['Pr1Ru4Sb12'], [0.97]),
#  'physrevb.72.214523': (['Zn2Zr1'], [0.6]),
#  'physrevb.72.220505': (['B2Mg1'], [38.7]),
#  'physrevb.73.024512': (['B6Y1'], [7.2]),
#  'physrevb.73.052504': (['Mo1N1'], [4.2]),
#  'physrevb.73.094510': (['B12Zr1'], [6.0]),
#  'physrevb.73.094522': (['Y1'], [3.0]),
#  'physrevb.73.144510': (['Y0.54Pr0.46Ba2Cu3O7-z'], [38.0]),
#  'physrevb.73.184521': (['Li1Ti2O4'], [12.0]),
#  'physrevb.74.012504': (['Li0.68Nb1O2'], [5.0]),
#  'physrevb.74.134513': (['Pr1Pt2B2C1'], [6.0]),
#  'physrevb.74.174501': (['Nb2As1C1'], [2.0]),
#  'physrevb.75.054513': (['Ba8Si40Ga6'], [3.3]),
#  'physrevb.75.064517': (['Nb2Se3'], [2.0]),
#  'physrevb.75.174502': (['Pb1'], [7.0]),
#  'physrevb.76.012505': (['Sc1'], [8.2]),
#  'physrevb.76.014528': (['Al3Mg2'], [0.87]),
#  'physrevb.76.100506': (['Na0.3Co1H2.6O3.3'], [4.8]),
#  'physrevb.77.092505': (['Ca24Al28O66'], [0.2]),
#  'physrevb.77.174503': (['La1Fe1As1F0.11O0.89'], [28.2]),
#  'physrevb.77.180504': (['Th1Pt4Ge12'], [4.62]),
#  'physrevb.77.180510': (['Sm1Fe1As1F0.15O0.85'], [3.7]),
#  'physrevb.77.184512': (['Sr0.9La0.1Cu1O2'], [1.6]),
#  'physrevb.77.193106': (['Li0.9Mo6O17'], [1.92]),
#  'physrevb.78.012507': (['La1Fe1As1F0.1O0.9'], [23.7]),
#  'physrevb.78.014502': (['Mo3Sb7'], [2.1]),
#  'physrevb.78.014507': (['Ba0.55K0.45Fe2As2'], [30.0]),
#  'physrevb.78.024509': (['Bi2Pd3Se2'], [0.96]),
#  'physrevb.78.024514': (['Lu2Fe3Si5'], [6.0]),
#  'physrevb.78.060506': (['C6Ca1'], [3.0]),
#  'physrevb.78.064510': (['Pr1Os4Sb12'], [1.55]),
#  'physrevb.78.064516': (['Th1Pt4Ge12'], [4.75]),
#  'physrevb.78.092406': (['Eu0.5K0.5Fe2As2'], [32.0]),
#  'physrevb.78.092503': (['La0.85Sr0.15Fe1As1O1-z'], [26.0]),
#  'physrevb.78.100503': (['Y1Ba2Cu4O8'], [108.0]),
#  'physrevb.78.100507': (['La1Fe1As1F0.1O0.9'], [55.0]),
#  'physrevb.78.104527': (['Ba0.55K0.45Fe2As2'], [38.0]),
#  'physrevb.78.134504': (['B12Lu1'], [0.44]),
#  'physrevb.78.134508': (['Nd1Fe1As1F0.18O0.82'], [50.0]),
#  'physrevb.78.172504': (['Sr1Ni2As2'], [0.62]),
#  'physrevb.78.172505': (['Mo3Sb7'], [2.0]),
#  'physrevb.78.174523': (['Nd1Fe1As1F0.3O0.7'], [47.0]),
#  'physrevb.78.184512': (['Sm1Fe1P1O1'], [3.0]),
#  'physrevb.78.220505': (['Ba0.55K0.45Fe2As2'], [32.0]),
#  'physrevb.79.014514': (['Ba0.64K0.36Fe2As2'], [26.2]),
#  'physrevb.79.014519': (['Fe1Se0.72'], [8.0]),
#  'physrevb.79.020508': (['Nd1Fe1As1F0.2O0.8'], [35.0]),
#  'physrevb.79.024514': (['Bi2Sr1.6La0.4Cu1O6+z'], [32.0]),
#  'physrevb.79.054517': (['Ba0.6K0.4Fe2As2'], [32.0]),
#  'physrevb.79.054520': (['Th1Pt4Ge12'], [4.62]),
#  'physrevb.79.094505': (['Ba0.6K0.4Fe2As2'], [34.6]),
#  'physrevb.79.094507': (['Ba1Fe1.852Co0.148As2'], [23.0]),
#  'physrevb.79.094508': (['Ba1Ni2As2'], [0.69]),
#  'physrevb.79.104501': (['Pr0.75Sr0.25Fe1As1O1'], [16.3]),
#  'physrevb.79.132506': (['Ba1Ni2P2'], [2.51]),
#  'physrevb.79.134507': (['Sr1Ni2P2'], [1.4]),
#  'physrevb.79.140505': (['B105'], [1.5]),
#  'physrevb.79.140509': (['Fe1.03Te0.7Se0.3'], [65.0]),
#  'physrevb.79.144509': (['B3Ru7'], [3.3]),
#  'physrevb.79.172506': (['Ba1Fe2As2'], [35.0]),
#  'physrevb.79.172507': (['Ce1Pt1Si2'], [0.14]),
#  'physrevb.79.174501': (['Ba0.6K0.4Fe2As2'], [36.5]),
#  'physrevb.79.174505': (['La1Fe0.96Ni0.04As1O1'], [6.5]),
#  'physrevb.79.174511': (['Pr1Os4Sb12'], [1.85]),
#  'physrevb.79.224522': (['Sr1Pd2Ge2'], [3.04]),
#  'physrevb.80.024518': (['Fe1Se1'], [8.8]),
#  'physrevb.80.024519': (['Ca1Fe2As2'], [11.5]),
#  'physrevb.80.052501': (['Sr1Fe2As2'], [25.0]),
#  'physrevb.80.064504': (['Ba1Pt1Si3'], [2.25]),
#  'physrevb.80.064506': (['Fe1Se1'], [8.0]),
#  'physrevb.80.094501': (['Ba1Fe1.852Co0.148As2'], [22.5]),
#  'physrevb.80.100503': (['Sr2Ca12Cu24O41'], [3.0]),
#  'physrevb.80.134523': (['Fe1.06Te0.5Se0.5'], [14.0]),
#  'physrevb.80.140513': (['Ce1Cu2Si2'], [0.46]),
#  'physrevb.80.144524': (['Ca1Fe1.94Ni0.06As2'], [15.0]),
#  'physrevb.80.172501': (['U1Ru2Si2'], [17.0]),
#  'physrevb.80.180507': (['Fe1Se0.25Te0.75'], [14.0]),
#  'physrevb.80.220509': (['La1Fe1P1O1'], [7.4]),
#  'physrevb.80.224522': (['Ho1Ni2B2C'], [8.5]),
#  'physrevb.81.020509': (['Fe1.11Te0.6Se0.4'], [14.0]),
#  'physrevb.81.020510': (['Ca1Fe1.92Co0.08As2'], [20.4]),
#  'physrevb.81.060501': (['Ba1Fe1.85Co0.15As2'], [21.4]),
#  'physrevb.81.060509': (['Ba1Fe1.8Co0.2As2'], [20.0]),
#  'physrevb.81.092506': (['Fe1.08Te1Ox'], [8.0]),
#  'physrevb.81.092507': (['Cu0.06Ti1Se2'], [2.5]),
#  'physrevb.81.094520': (['Ba1Fe1.73Co0.27As2'], [8.1]),
#  'physrevb.81.104522': (['Ba8Si46'], [2.3]),
#  'physrevb.81.140507': (['Ce1Ir1Ge3'], [1.5]),
#  'physrevb.81.144414': (['Eu1Pt1Si3'], [16.0]),
#  'physrevb.81.180507': (['Ce1Pt2In7'], [2.1]),
#  'physrevb.81.184509': (['Bi1.98Sr2.06Y0.68Cu2O8+z'], [-100.0]),
#  'physrevb.81.184522': (['Fe1.14Te0.91S0.09'], [28.0]),
#  'physrevb.81.205119': (['Fe1Se0.99'], [30.0]),
#  'physrevb.81.220501': (['Ba1Fe2As1.34P0.66'], [30.0]),
#  'physrevb.81.224511': (['Ba1Fe2As2'], [3.0]),
#  'physrevb.82.014518': (['Nb1S2'], [6.05]),
#  'physrevb.82.024503': (['Pb1.16Ti2Se5.16'], [2.3]),
#  'physrevb.82.064511': (['Al2C1Mo3'], [9.0]),
#  'physrevb.82.064512': (['Al2C1Mo3'], [9.2]),
#  'physrevb.82.094502': (['Ba1Fe2As1.3P0.7'], [30.5]),
#  'physrevb.82.094506': (['B1I3'], [23.0]),
#  'physrevb.82.094517': (['Sn3Y1'], [7.0]),
#  'physrevb.82.140507': (['Sr2V1Fe1As1O3'], [33.0]),
#  'physrevb.82.144118': (['Ba1Fe2As2'], [10.0]),
#  'physrevb.82.144518': (['Sr1Fe1.84Pt0.16As2'], [16.0]),
#  'physrevb.82.144527': (['Rb1Fe2As2'], [2.52]),
#  'physrevb.82.144532': (['B2Os1'], [2.1]),
#  'physrevb.82.174509': (['Ba1Fe1.85Co0.15As2'], [25.0]),
#  'physrevb.82.180512': (['Sr0.6La0.4Fe2As2'], [26.0]),
#  'physrevb.83.054509': (['Bi2Sr1.6La0.4Cu1O6+z'], [28.0]),
#  'physrevb.83.060502': (['Li1Fe1As1'], [5.0]),
#  'physrevb.83.060512': (['Rb0.88Fe1.81Se2'], [32.1]),
#  'physrevb.83.064504': (['Ce2Pd1In8'], [0.7]),
#  'physrevb.83.064522': (['La1Rh1Si3'], [2.16]),
#  'physrevb.83.100501': (['Eu1Fe2As2'], [30.0]),
#  'physrevb.83.100502': (['Li1Fe1As1'], [18.0]),
#  'physrevb.83.100503': (['Eu1Fe1As1.64P0.36'], [28.0]),
#  'physrevb.83.100513': (['Sm1Fe1As1F0.15O0.85'], [49.5]),
#  'physrevb.83.100514': (['K0.8Fe1.76Se2'], [32.0]),
#  'physrevb.83.104508': (['K0.8Fe2Se2'], [33.0]),
#  'physrevb.83.115131': (['La3Ni2B2N2.7'], [13.0]),
#  'physrevb.83.134521': (['Fe1Te0.57Se0.43'], [3.92]),
#  'physrevb.83.140501': (['Bi3Ni1'], [4.06]),
#  'physrevb.83.140504': (['Bi2Te3'], [3.0]),
#  'physrevb.83.144510': (['Ce1Co1In5'], [3.0]),
#  'physrevb.83.144511': (['K0.8Fe2Se2'], [32.0]),
#  'physrevb.83.144525': (['Nb0.18Re0.82'], [8.75]),
#  'physrevb.83.174503': (['K0.65Fe1.41Se2'], [31.8]),
#  'physrevb.83.174506': (['Li1Fe1As1'], [18.0]),
#  'physrevb.83.174510': (['Tl0.47Rb0.34Fe1.63Se2'], [32.0]),
#  'physrevb.83.174520': (['La1Sb2'], [2.5]),
#  'physrevb.83.214513': (['Eu1Fe2As2'], [30.0]),
#  'physrevb.83.220512': (['Ca1'], [3.0]),
#  'physrevb.83.224512': (['Li1Fe1As1'], [14.7]),
#  'physrevb.84.024502': (['Eu1Fe2As2'], [20.0]),
#  'physrevb.84.024509': (['Ba1Fe1.922Rh0.078As2'], [14.0]),
#  'physrevb.84.054507': (['Li1Fe1As1'], [18.0]),
#  'physrevb.84.054531': (['Nb1S2'], [6.05]),
#  'physrevb.84.054541': (['Lu2Fe3Si5'], [6.0]),
#  'physrevb.84.064518': (['Bi1Pd1'], [3.8]),
#  'physrevb.84.064525': (['Ba0.65Na0.35Fe2As2'], [29.4]),
#  'physrevb.84.104502': (['Li1Fe1As1'], [18.0]),
#  'physrevb.84.140507': (['Ce2Pd1In8'], [0.68]),
#  'physrevb.84.174502': (['Fe1Se0.42Te0.58'], [14.8]),
#  'physrevb.84.214527': (['La1Ru3Si2'], [7.8]),
#  'physrevb.84.220504': (['Y1Pt1Bi1'], [0.77]),
#  'physrevb.85.014520': (['Sr1Pd2Ge2'], [2.7]),
#  'physrevb.85.024526': (['U1Co1Ge1'], [2.8]),
#  'physrevb.85.024538': (['Sr1Ni2Ge2'], [0.92]),
#  'physrevb.85.054507': (['K0.8Fe1.7S1Se1'], [26.3]),
#  'physrevb.85.054517': (['La1Ni2P2'], [0.7]),
#  'physrevb.85.064504': (['Fe1.08Te0.55Se0.45Ox'], [14.5]),
#  'physrevb.85.064513': (['Tl0.58Rb0.42Fe1.72Se2'], [33.5]),
#  'physrevb.85.180504': (['Ca10Pt3.97Fe9.03As18'], [11.0]),
#  'physrevb.85.180505': (['Li1Fe1As1'], [15.0]),
#  'physrevb.85.184501': (['Ca0.67Sr0.33Fe2As2'], [22.2]),
#  'physrevb.85.184513': (['Te3Zr1'], [2.0]),
#  'physrevb.85.205105': (['Ce1Cu2Si2'], [4.5]),
#  'physrevb.85.214526': (['Yb1Sb2'], [1.3]),
#  'physrevb.85.224504': (['Ba0.55K0.45Fe1.95Co0.05As2'], [32.5]),
#  'physrevb.86.020501': (['Ce1Fe1As0.7P0.3O1'], [4.0]),
#  'physrevb.86.054502': (['Rh3Bi14'], [2.94]),
#  'physrevb.86.064504': (['Ca3Ir4Sn13'], [7.0]),
#  'physrevb.86.064516': (['Li1Fe1As1'], [18.0]),
#  'physrevb.86.144525': (['Sr1Fe2As1.4P0.6'], [25.0]),
#  'physrevb.86.220509': (['Fe1Te0.6Se0.4'], [12.0]),
#  'physrevb.86.220510': (['Bi4S3O4'], [8.6]),
#  'physrevb.86.224514': (['K1Fe2As2'], [3.8]),
#  'physrevb.87.020504': (['Sr0.5La0.5F1Bi1S2'], [2.8]),
#  'physrevb.87.024508': (['Te3Zr1'], [4.0]),
#  'physrevb.87.045124': (['K1Ni2S2'], [0.46]),
#  'physrevb.87.054504': (['Li1Fe1P1'], [4.86]),
#  'physrevb.87.060510': (['Ba1Ti2Sb2O1'], [0.95]),
#  'physrevb.87.064502': (['Pr1Pt4Ge12'], [8.0]),
#  'physrevb.87.094515': (['Sr1Pd2Ge2'], [2.7]),
#  'physrevb.87.104515': (['Mo3Sb7'], [2.35]),
#  'physrevb.87.134512': (['Fe1Se1'], [8.0]),
#  'physrevb.87.134513': (['K1Fe2As2'], [3.8]),
#  'physrevb.87.140507': (['Sn0.6In0.4Te1'], [3.5]),
#  'physrevb.87.144502': (['Cs1Fe2As2'], [1.81]),
#  'physrevb.87.174510': (['Ir3Te8'], [1.8]),
#  'physrevb.87.180508': (['Pr4Fe2As2Te0.88O4'], [25.0]),
#  'physrevb.87.184504': (['Lu1Pt1Bi1'], [1.0]),
#  'physrevb.87.214504': (['La1Sb2'], [1.2]),
#  'physrevb.87.214509': (['Cs1Fe2As2'], [1.8]),
#  'physrevb.87.224507': (['Sr1Pt2As2'], [5.0]),
#  'physrevb.88.014517': (['K1Fe2As2'], [3.4]),
#  'physrevb.88.024423': (['La3Pd4Si4'], [2.0]),
#  'physrevb.88.140501': (['Ba0.75Na0.25Ti2Sb2O1'], [58.0]),
#  'physrevb.88.144511': (['La1Pd0.85Bi2'], [2.1]),
#  'physrevb.88.180509': (['La0.5Bi1S2F0.5O0.5'], [10.0]),
#  'physrevb.88.184508': (['Bi3Ni1'], [4.0]),
#  'physrevb.88.224510': (['Eu1Fe2As2'], [26.0]),
#  'physrevb.88.224515': (['Bi4S3O4'], [4.5]),
#  'physrevb.89.020505': (['Pb1Ta1Se2'], [3.72]),
#  'physrevb.89.020507': (['Li1Fe3Se2O2'], [43.0]),
#  'physrevb.89.024518': (['Sm4Fe2As2Te0.72F1.2O2.8'], [45.0]),
#  'physrevb.89.054512': (['Ca10Bi9.88'], [2.2]),
#  'physrevb.89.094520': (['Sr3Ir4Sn13'], [5.0]),
#  'physrevb.89.100501': (['Ir0.95Pd0.05Te2'], [3.0]),
#  'physrevb.89.140504': (['Sr1Pt1As1'], [2.4]),
#  'physrevb.89.174515': (['La1F0.5Bi1S2O0.5'], [11.0]),
#  'physrevb.89.205136': (['Ca10Pt0.78Fe9.22As18'], [10.0]),
#  'physrevb.89.224504': (['Ca3Ir4Ge4'], [1.8]),
#  'physrevb.90.014513': (['La1Ir1Si3'], [0.72]),
#  'physrevb.90.020502': (['K0.5Na0.24Fe1.52Se2'], [20.0]),
#  'physrevb.90.035115': (['Sr3Ir4Sn13'], [5.0]),
#  'physrevb.90.064518': (['Eu1Bi1S2F1'], [0.3]),
#  'physrevb.90.144508': (['Ba2Ti2Fe2As4O1'], [21.5]),
#  'physrevb.90.220504': (['C1.36Pb5Bi12Se23'], [2.9]),
#  'physrevb.90.220508': (['La1Ni1C2'], [3.0]),
#  'physrevb.90.220510': (['Eu3Bi2S4F4'], [1.5]),
#  'physrevb.90.224410': (['Ce1Bi1S2F0.7O0.3'], [4.5]),
#  'physrevb.90.224513': (['Ca10Ir4Fe10As18'], [16.0]),
#  'physrevb.91.014513': (['Ba1Pt2Sb2'], [1.82]),
#  'physrevb.91.020507': (['K2Cr3As3'], [6.1]),
#  'physrevb.91.024509': (['Pd2Hf1Al1'], [3.53]),
#  'physrevb.91.060508': (['K1Fe2As2'], [3.0]),
#  'physrevb.91.060510': (['Sr1Pt2As2'], [5.2]),
#  'physrevb.91.064509': (['La1Fe1As1H0.44O0.56'], [49.0]),
#  'physrevb.91.094427': (['Eu1Fe1.72Ir0.28As2'], [22.5]),
#  'physrevb.91.100504': (['Nb2Pd1S5'], [6.6]),
#  'physrevb.91.104506': (['Ta4Pd3Te16'], [4.3]),
#  'physrevb.91.104511': (['Bi3S3O2'], [4.03]),
#  'physrevb.91.125107': (['Li0.8Fe1.2H1Se1'], [34.0]),
#  'physrevb.91.134508': (['Nb0.18Re0.82'], [8.8]),
#  'physrevb.91.174513': (['Bi2Rh3.5S2'], [1.7]),
#  'physrevb.91.214517': (['Au2Pb1'], [100.0]),
#  'physrevb.91.220505': (['K2Cr3As3'], [6.1]),
#  'physrevb.92.020506': (['Sr0.1Bi2Se3'], [2.9]),
#  'physrevb.92.024511': (['Th1Pt3B1'], [0.75]),
#  'physrevb.92.134517': (['Sr0.3M1Fe2Se2'], [36.3]),
#  'physrevb.92.161114': (['Ce3Pt1In11'], [0.32]),
#  'physrevb.93.054508': (['Li1Fe1As1'], [18.0]),
#  'physrevb.93.054520': (['Pb1Ta1Se2'], [3.8]),
#  'physrevb.93.060506': (['Pb1Ta1Se2'], [3.7]),
#  'physrevb.93.064504': (['Sr1Pt1As1'], [2.45]),
#  'physrevb.93.094511': (['Bi2Te1'], [8.6]),
#  'physrevb.93.104508': (['M0.37Cs0.268Fe1Se1'], [33.0]),
#  'physrevb.93.104516': (['Ba0.85K0.15Fe2As2'], [13.5]),
#  'physrevb.93.115119': (['Ba1Fe2As1.34P0.66'], [29.0]),
#  'physrevb.93.144502': (['Bi2Pd1'], [5.0]),
#  'physrevb.93.214503': (['Rb1Eu1Fe4As4'], [36.5]),
#  'physrevb.93.220504': (['Bi2Pd1'], [4.84]),
#  'physrevb.93.224512': (['Li1.84H1Fe1.14Se1O1'], [40.0]),
#  'physrevb.93.224516': (['Cs1Fe2As2'], [13.0]),
#  'physrevb.93.241112': (['La3Co4Sn13'], [152.0]),
#  'physrevb.94.024518': (['Hf1Re6'], [6.2]),
#  'physrevb.94.035130': (['Y1Pt1Bi1'], [0.97]),
#  'physrevb.94.054514': (['Ce1Cu2Si2'], [0.6]),
#  'physrevb.94.054515': (['Hf1Re6'], [5.96]),
#  'physrevb.94.054517': (['Hf1Te5'], [4.8]),
#  'physrevb.94.054523': (['La1Pt4Ge12'], [8.3]),
#  'physrevb.94.064501': (['Ca1K1Fe4As4'], [35.0]),
#  'physrevb.94.104507': (['Ba8Si46'], [-100.0]),
#  'physrevb.94.144515': (['Re6Zr1'], [6.7]),
#  'physrevb.94.180509': (['Y1Sr2Mo0.25Cu2.75O7.54'], [84.0]),
#  'physrevb.95.014502': (['K2Cr3As3'], [6.2]),
#  'physrevb.95.024510': (['Bi1'], [3.92]),
#  'physrevb.95.035148': (['Ir1Te2'], [2.5]),
#  'physrevb.95.060505': (['Ba1Fe1.915Ni0.085As2'], [3.25]),
#  'physrevb.95.064514': (['Ge1Sb2Te4'], [6.0]),
#  'physrevb.95.094510': (['Ca8.5La1.5Pt3Fe10As18'], [32.8]),
#  'physrevb.95.140505': (['Ca1K1Fe4As4'], [-100.0]),
#  'physrevb.95.174521': (['Ta1Ir2Ge2'], [3.5]),
#  'physrevb.96.060509': (['Pd1Se2'], [13.1]),
#  'physrevb.96.064512': (['Li0.36M1Fe2Se2'], [44.56]),
#  'physrevb.96.064521': (['Re6Zr1'], [6.75]),
#  'physrevb.96.064528': (['Pb1Ta1Se2'], [3.0]),
#  'physrevb.96.094523': (['Ba1Fe1.864Rh0.136As2'], [22.3]),
#  'physrevb.96.140501': (['Ca1K1Fe4As4'], [35.0]),
#  'physrevb.96.144502': (['Th1As1Fe1N1'], [30.0]),
#  'physrevb.96.165123': (['Se1Sn1'], [3.2]),
#  'physrevb.96.224433': (['Sm0.04La0.96Ni1C2'], [2.7]),
#  'physrevb.97.014501': (['Au1Be1'], [3.3]),
#  'physrevb.97.014514': (['Tl1Ni2Se2'], [3.05]),
#  'physrevb.97.014523': (['Pd1Te2'], [0.38]),
#  'physrevb.97.020502': (['Re24Ti5'], [6.0]),
#  'physrevb.97.020508': (['Li0.36M1Fe2As2'], [55.0]),
#  'physrevb.97.024501': (['Sr1Au1Si3'], [1.54]),
#  'physrevb.97.054506': (['B2Ru1'], [1.5]),
#  'physrevb.97.054515': (['Pd1Te2'], [1.7]),
#  'physrevb.97.060506': (['Cs1Ca2Fe4As4F2'], [28.3]),
#  'physrevb.97.060509': (['K1Ca2Fe4As4F2'], [33.36]),
#  'physrevb.97.064514': (['Ce1Rh1Ge3'], [1.3]),
#  'physrevb.97.100504': (['La1Fe1Si1H1'], [11.0]),
#  'physrevb.97.104509': (['La1Bi1S2F0.5O0.5'], [3.0]),
#  'physrevb.97.134508': (['Ba1Pd2As2'], [3.85]),
#  'physrevb.97.224506': (['Re6Zr1'], [6.8]),
#  'physrevb.97.224511': (['Tb1Pd1Bi1'], [1.7]),
#  'physrevb.98.014502': (['Ta1Rh2B2'], [-100.0]),
#  'physrevb.98.020503': (['Na1Sn2As2'], [1.3]),
#  'physrevb.98.024520': (['As1Cr1'], [2.0]),
#  'physrevb.98.094504': (['Nd1Fe1As1F0.1O0.9'], [45.4]),
#  'physrevb.98.094519': (['Ir0.8Rh0.2Te2'], [2.45]),
#  'physrevb.98.104503': (['Rb1Eu1Fe4As4'], [36.8]),
#  'physrevb.98.104506': (['Re3Ta1'], [4.68]),
#  'physrevb.98.134512': (['Cr0.8Ru0.2'], [1.35]),
#  'physrevb.98.214505': (['La1Pt1Ge1'], [3.05]),
#  'physrevb.98.224505': (['Ba1Fe1.9Pt0.1As2'], [23.0]),
#  'physrevb.99.054503': (['Ga41Mo1'], [10.0]),
#  'physrevb.99.100501': (['Ce1Ni1C2'], [3.5]),
#  'physrevb.99.134509': (['Au1Be1'], [3.2]),
#  'physrevb.99.144511': (['H1Pt1'], [7.0]),
#  'physrevb.99.144519': (['Al6Re1'], [0.74]),
#  'physrevb.99.174513': (['Zr1Ir1Si1'], [1.7]),
#  'physrevb.99.184509': (['P1W1'], [0.8]),
#  'physrevb.99.184513': (['Mo3P1'], [5.5])}

# %%
processed_database_output
# Out:
# {'physrevb.10.4572': (['Ga1'], [6.07]),
#  'physrevb.100.014503': (['Eu1Fe2As2'], [27.0]),
#  'physrevb.100.014507': (['Pd1S2'], [2.0]),
#  'physrevb.100.041109': (['Rb1'], [2.1]),
#  'physrevb.100.060103': (['Au2Pb1'], [3.61]),
#  'physrevb.100.094511': (['Rb1Cr3As3'], [7.17]),
#  'physrevb.100.094522': (['W3Al2C1'], [7.6]),
#  'physrevb.100.134503': (['Ta1Os1Si1'], [5.51]),
#  'physrevb.23.2219': (['K0.18W1O3'], [3.9]),
#  'physrevb.26.6315': (['K1Hg1C4'], [1.42]),
#  'physrevb.28.1389': (['La1Ir2Si2'], [1.58]),
#  'physrevb.30.1182': (['Ce1Cu2Si2'], [0.7]),
#  'physrevb.30.1583': (['Pt3U1'], [0.52]),
#  'physrevb.30.2986': (['Pt3U1'], [0.49]),
#  'physrevb.30.444': (['Ce1Ru3Si2'], [1.25]),
#  'physrevb.30.5135': (['Co35.38Zr64.62'], [2.67]),
#  'physrevb.31.1654': (['Pt3U1'], [0.48]),
#  'physrevb.32.135': (['Pd2Yb1Sn1'], [2.36]),
#  'physrevb.34.4590': (['Lu5Ir4Si10'], [3.77]),
#  'physrevb.34.4920': (['Ga1'], [8.2]),
#  'physrevb.36.3906': (['La1.8Sr0.2Cu1O4'], [35.7]),
#  'physrevb.36.3910': (['Y1.2Ba0.8Cu1O4'], [75.0]),
#  'physrevb.36.3920': (['Y1Ba2Cu3O7+Y'], [92.0]),
#  'physrevb.36.4003': (['La1.85Sr0.15Cu1O4'], [36.0]),
#  'physrevb.36.4014': (['Y1Ba2Cu3O7'], [93.0]),
#  'physrevb.36.4018': (['Gd1Ba2Cu2.82Fe0.18O9-Z'], [42.0]),
#  'physrevb.36.8329': (['Y1Ba2Cu3O7-Z'], [92.4]),
#  'physrevb.36.8660': (['La1Fe4P12'], [4.0]),
#  'physrevb.36.8791': (['Er1Ba2Cu3O7-Z'], [86.0]),
#  'physrevb.38.11955': (['Bi2Sr2Ca1Cu2O8'], [90.0]),
#  'physrevb.38.225': (['Tl2Ba2Cu1O6'], [90.0]),
#  'physrevb.38.2455': (['Ho1Ba2Cu3O6.9'], [91.5]),
#  'physrevb.39.11445': (['La2Cu1O4+Z'], [35.0]),
#  'physrevb.39.6571': (['Y1Ba2Cu3O7'], [92.0]),
#  'physrevb.39.7339': (['Ba0.6K0.4Bi1O3-Z'], [26.0]),
#  'physrevb.39.9074': (['La1Ba1Ca1Cu3O6.98'], [78.5]),
#  'physrevb.40.2690': (['Ba0.6Rb0.4Bi1O3'], [29.0]),
#  'physrevb.40.841': (['Bi2Sr2Ca1Cu2O8'], [84.0]),
#  'physrevb.41.2520': (['La1.96Sr0.04Cu1O4'], [9.5]),
#  'physrevb.41.9551': (['Bi2Sr2Ca1Cu2O8+z'], [83.0]),
#  'physrevb.45.4803': (['Si2Ta1'], [0.345]),
#  'physrevb.45.5628': (['Tl2Ba2Ca1Cu2O8'], [102.0]),
#  'physrevb.48.16869': (['Y1Ba2Cu4O8'], [74.0]),
#  'physrevb.49.12322': (['Hg0.66Pb0.33Ba2Ca2Cu3Oy'], [138.0]),
#  'physrevb.49.13075': (['Hg1Ba2Cu1O4+d'], [94.0]),
#  'physrevb.49.13184': (['Bi2Sr2Ca1Cu2O8+y'], [87.0]),
#  'physrevb.49.1492': (['Bi0.5Sr1.5Y1.15Ce0.85Cu2O8-z'], [34.0]),
#  'physrevb.49.1495': (['Bi2Sr2Ca2Cu3O10'], [109.0]),
#  'physrevb.49.15416': (['Hg1Ba2Ca2Cu3O8+d'], [132.0]),
#  'physrevb.49.15959': (['Bi2Sr2Ca1Cu2O8'], [82.4]),
#  'physrevb.49.3502': (['Ba0.64K0.36Bi1O3'], [28.5]),
#  'physrevb.49.3683': (['Hg1Ba2Cu1O4+d'], [97.0]),
#  'physrevb.49.6392': (['Nd1.85Ce0.15Cu1O4'], [17.2]),
#  'physrevb.49.8931': (['Tl2Mo6Se6'], [6.5]),
#  'physrevb.49.9073': (['Bi2Sr2Ca1Cu2O8'], [95.0]),
#  'physrevb.49.9097': (['La1.925Sr0.075Cu1O4+d'], [23.0]),
#  'physrevb.49.9218': (['Bi2Sr2Ca1Cu2O8+d'], [90.7]),
#  'physrevb.49.9885': (['I1Bi2.2Sr1.8Ca1Cu2O8+y'], [73.6]),
#  'physrevb.49.9924': (['Y1Ba2Cu3O7-d'], [90.0]),
#  'physrevb.50.13890': (['Ba6C60'], [7.0]),
#  'physrevb.50.15875': (['La1.85Sr0.15Cu1O4'], [36.7]),
#  'physrevb.50.16125': (['Y1Ba2Cu3Oy'], [91.0]),
#  'physrevb.50.351': (['Sc1Ni2B2C1'], [16.5]),
#  'physrevb.50.426': (['Y2Ba4Cu7O15.1'], [92.8]),
#  'physrevb.50.496': (['Bi2Sr1.9Cu2.1Ox'], [5.3]),
#  'physrevb.50.6523': (['La1Ni1Si1'], [1.26]),
#  'physrevb.51.12644': (['Ho1Ni2B2C1'], [8.4]),
#  'physrevb.51.12747': (['Tl1.89Ba2Cu1.11O6.18'], [49.0]),
#  'physrevb.51.1286': (['La2Cu1O4.035'], [35.0]),
#  'physrevb.51.1393': (['Pb0.17Hg1.22Ba2Ca1.44Cu2.79Ox'], [133.6]),
#  'physrevb.51.1397': (['Bi1.8Pb0.4Sr2Ca2Cu3O10+d'], [104.0]),
#  'physrevb.51.15478': (['Y2Ba4Cu7O14.97'], [93.1]),
#  'physrevb.51.3316': (['Y1Ba2Cu3O7-d'], [92.0]),
#  'physrevb.52.10569': (['Y1Ba2Cu3O6.95'], [93.5]),
#  'physrevb.52.1181': (['Ho1Ni2B2C1'], [7.8]),
#  'physrevb.52.15534': (['C60Sm3'], [8.0]),
#  'physrevb.52.3071': (['Nd1.85Ce0.15Cu1O4-d'], [18.2]),
#  'physrevb.52.4432': (['Rb1Cs2C60'], [33.0]),
#  'physrevb.52.483': (['K3N1H3C60'], [28.0]),
#  'physrevb.52.7647': (['Bi2Sr2Ca1Cu2O8+y'], [92.0]),
#  'physrevb.52.r3844': (['Dy1Ni2B2C1'], [6.4]),
#  'physrevb.53.12299': (['Rh1Zr2'], [11.2]),
#  'physrevb.53.12389': (['Tm2Fe3Si5'], [3.13]),
#  'physrevb.53.5170': (['Ba2Ca3Cu5O11-y'], [115.9]),
#  'physrevb.53.8238': (['La1'], [5.0]),
#  'physrevb.53.8241': (['Ce1Rh2Si2'], [0.26]),
#  'physrevb.54.6133': (['BaKBi1O3'], [31.8]),
#  'physrevb.54.r3772': (['Lu1Ni2B2C1'], [16.0]),
#  'physrevb.54.r6885': (['Bi2Sr1.8Ca1.2Cu2O8'], [79.8]),
#  'physrevb.55.11789': (['Y1Ba2Cu3O6.95'], [93.2]),
#  'physrevb.55.15300': (['Y1Ba2Cu3O6.92'], [90.0]),
#  'physrevb.55.8529': (['Bi2Sr2Ca1Cu2O8+y'], [89.9]),
#  'physrevb.55.9125': (['Bi2Sr2Ca1Cu2O8+y'], [90.0]),
#  'physrevb.55.r6145': (['Pr1.85Ce0.15Cu1O4-z'], [22.5]),
#  'physrevb.55.r8674': (['Hg1Ba2Ca2Cu3O8+y'], [110.4]),
#  'physrevb.56.5631': (['Tb1Sr2Cu2.69Mo0.31O7'], [37.0]),
#  'physrevb.56.7890': (['Sr2Ru1O4'], [0.9]),
#  'physrevb.56.8346': (['Ca3Rh4Sn13'], [8.2]),
#  'physrevb.57.613': (['Sr0.4Ca13.6Cu24O41+z'], [10.0]),
#  'physrevb.57.r14084': (['Y1Ba2Cu3O7-d'], [84.0]),
#  'physrevb.58.497': (['La1Ni1C2'], [2.7]),
#  'physrevb.58.r603': (['Pt3U1'], [0.553]),
#  'physrevb.59.11179': (['Bi2Sr2Ca1Cu2O8+X'], [78.0]),
#  'physrevb.59.11563': (['Nd1Ba2Cu3O7-Z'], [95.56]),
#  'physrevb.59.13639': (['Y0.5Yb0.5Ba2Sr0Cu3O7-Z'], [87.2]),
#  'physrevb.59.14099': (['Ru1Sr2Gd1Cu2O8'], [16.0]),
#  'physrevb.59.14753': (['La1.905Ba0.095Cu1O4'], [31.0]),
#  'physrevb.59.3827': (['La1.85Sr0.15Cu1O4'], [43.0]),
#  'physrevb.59.7266': (['Lu5Ir4Si10'], [3.9]),
#  'physrevb.59.8962': (['I1Bi1.9Pb0.1Sr2Ca1Cu2O8+Z'], [80.0]),
#  'physrevb.59.r11668': (['Y1Ba2Cu4O8'], [82.0]),
#  'physrevb.59.r11679': (['Ru1Sr2Gd1Cu2O8'], [46.0]),
#  'physrevb.60.3064': (['Ba8Ga16Ge30'], [7.5]),
#  'physrevb.60.7512': (['Ru1Sr2Gd1Cu2O8'], [37.0]),
#  'physrevb.61.11317': (['Hg1Ba2Ca2Cu3O8+Z'], [131.0]),
#  'physrevb.61.1500': (['Ca5.84Sr4.02Bi0.14Cu15.84O29'], [72.0]),
#  'physrevb.61.1584': (['Y1Ba2Cu3O7-z'], [87.2]),
#  'physrevb.61.6303': (['Eu1.5Ce0.5Sr2Cu1Ti1O10'], [22.0]),
#  'physrevb.61.778': (['Sr2.3Ca0.7Cu2Cl1.3O4+z'], [80.0]),
#  'physrevb.61.r3823': (['V1'], [5.3]),
#  'physrevb.61.r9269': (['Bi1.6Pb0.6Sr1.8Ca1Cu2OZ'], [65.0]),
#  'physrevb.63.134519': (['Lu1Ni2B2C1'], [16.2]),
#  'physrevb.63.144519': (['Ge2U1'], [0.752]),
#  'physrevb.63.172407': (['Y2Pd1Ge3'], [3.0]),
#  'physrevb.63.220503': (['B2Mg1'], [39.5]),
#  'physrevb.63.220504': (['B2Mg1'], [39.0]),
#  'physrevb.63.220505': (['B2Mg1'], [38.2]),
#  'physrevb.63.220507': (['Ce1Rh1In5'], [2.2]),
#  'physrevb.63.220508': (['B2Mg1'], [39.0]),
#  'physrevb.63.224510': (['U1'], [0.78]),
#  'physrevb.64.012507': (['B2Mg1'], [38.5]),
#  'physrevb.64.060506': (['B2Mg1'], [39.0]),
#  'physrevb.64.064508': (['Ru1Sr2Eu1Cu2O8'], [12.0]),
#  'physrevb.64.064514': (['La2Rh3Si5'], [4.4]),
#  'physrevb.64.094514': (['B2Mg1'], [37.5]),
#  'physrevb.64.094520': (['Dy1Mo6S8'], [1.6]),
#  'physrevb.64.094522': (['B2Mg1'], [39.0]),
#  'physrevb.64.100505': (['Lu1Ni2B2C1'], [14.2]),
#  'physrevb.64.132505': (['Mg1C1Ni3'], [8.0]),
#  'physrevb.64.132509': (['B2Mg1'], [39.6]),
#  'physrevb.64.144524': (['La1.89Ba0.11Cu1O4'], [17.8]),
#  'physrevb.64.172501': (['B2Mg1'], [38.0]),
#  'physrevb.64.172504': (['Ba8Si46'], [8.0]),
#  'physrevb.64.180501': (['B2Mg1'], [39.4]),
#  'physrevb.64.224420': (['La3Rh2Ge2'], [3.5]),
#  'physrevb.65.064504': (['S1'], [17.4]),
#  'physrevb.65.100506': (['Pr1Os4Sb12'], [1.85]),
#  'physrevb.65.100510': (['B2Mg1'], [38.0]),
#  'physrevb.65.134508': (['B2Mg1'], [39.2]),
#  'physrevb.65.140501': (['B2Mg1'], [38.5]),
#  'physrevb.65.180504': (['Ce1Co1In5'], [2.3]),
#  'physrevb.65.180505': (['B2Mg1'], [36.6]),
#  'physrevb.65.184514': (['Mg0.99Al0.01B2'], [37.9]),
#  'physrevb.65.214518': (['Mg1Cu1Ni3'], [7.2]),
#  'physrevb.65.224509': (['Ce1Rh1In5'], [2.12]),
#  'physrevb.65.224520': (['Sr0.9La0.1Cu1O2'], [43.0]),
#  'physrevb.66.012510': (['Y2Cu2I2'], [10.1]),
#  'physrevb.66.144503': (['Ru1Gd1.4Ce0.6Sr2Cu2O10+z'], [36.0]),
#  'physrevb.66.180502': (['B2Mg1'], [38.0]),
#  'physrevb.66.220504': (['La1Os4Sb12'], [0.74]),
#  'physrevb.67.020506': (['Ce2Rh1In8'], [2.0]),
#  'physrevb.67.024505': (['Ba0.61K0.39Bi1O3'], [31.5]),
#  'physrevb.67.024519': (['N0.72H2.16Na1K3C60'], [12.0]),
#  'physrevb.67.052501': (['Mg1C1Ni3'], [6.4]),
#  'physrevb.67.094501': (['Ge5La1'], [7.0]),
#  'physrevb.67.094502': (['Mg1C1Ni3'], [7.63]),
#  'physrevb.67.094504': (['B2Mg1'], [39.2]),
#  'physrevb.67.100509': (['Li0.48M0.3Hf1N1Cl1'], [25.5]),
#  'physrevb.67.172502': (['Ru0.9Sr2Y1Cu2.1O7.9'], [30.0]),
#  'physrevb.67.172508': (['B0.67Mg0.33'], [6.1]),
#  'physrevb.67.180508': (['Pr1Os4Sb12'], [1.85]),
#  'physrevb.67.212504': (['Ce1Te1.82'], [2.7]),
#  'physrevb.68.024523': (['Mg1C0.977Ni3'], [7.0]),
#  'physrevb.68.134503': (['Ca1Al1Si1'], [6.0]),
#  'physrevb.68.144510': (['Mg1C1Ni3'], [7.0]),
#  'physrevb.68.180502': (['Mg1C1Ni3'], [7.2]),
#  'physrevb.68.214517': (['Na0.31Co1D2.5O3.25'], [4.5]),
#  'physrevb.68.214518': (['Er1Ni1.96Fe0.04B2C0.99'], [7.3]),
#  'physrevb.69.054505': (['Ho1Ni2B2C1'], [8.04]),
#  'physrevb.69.060504': (['Pr1Os4Sb12'], [1.85]),
#  'physrevb.69.100506': (['Ca1Al1Si1'], [7.7]),
#  'physrevb.69.144514': (['B2Mg1'], [37.9]),
#  'physrevb.69.180509': (['Pr1Ru4Sb12'], [1.25]),
#  'physrevb.69.212508': (['B12Zr1'], [6.06]),
#  'physrevb.7.4290': (['Mo0.18U0.82'], [2.115]),
#  'physrevb.70.052511': (['Ge2Lu1'], [2.6]),
#  'physrevb.70.054519': (['Li1Ti2O4'], [11.4]),
#  'physrevb.70.064519': (['Ta2S2C2'], [3.61]),
#  'physrevb.70.174503': (['Mg1C1.6Ni3'], [6.9]),
#  'physrevb.70.174514': (['Hg0.7W0.3Sr2Ce1.74Eu1.26Cu2O11+z'], [34.0]),
#  'physrevb.71.020501': (['Mg1B1.88C0.12'], [32.9]),
#  'physrevb.71.045109': (['Lu2Ir3Si5'], [3.3]),
#  'physrevb.71.060502': (['C1'], [4.5]),
#  'physrevb.71.064505': (['Cu1.3K0.2Co1.5S4'], [4.54]),
#  'physrevb.71.104516': (['La1.48Nd0.4Sr0.12Cu1O4'], [10.0]),
#  'physrevb.71.132508': (['Te3Zr1'], [2.1]),
#  'physrevb.72.014534': (['Na0.1Ta1S2'], [4.83]),
#  'physrevb.72.020501': (['Zr1N1Cl0.7'], [12.8]),
#  'physrevb.72.024547': (['B12Zr1'], [5.97]),
#  'physrevb.72.054520': (['Sr2Ca12Cu24O41'], [5.18]),
#  'physrevb.72.064520': (['C3La2'], [13.5]),
#  'physrevb.72.144504': (['Ba24Si100'], [1.4]),
#  'physrevb.72.174508': (['Ru1Sr2Gd1Cu2O8'], [56.0]),
#  'physrevb.72.184503': (['Pr1Ru4Sb12'], [0.97]),
#  'physrevb.72.214523': (['Zn2Zr1'], [0.6]),
#  'physrevb.72.220505': (['B2Mg1'], [38.7]),
#  'physrevb.73.024512': (['B6Y1'], [7.15]),
#  'physrevb.73.052504': (['Mo1N1'], [4.2]),
#  'physrevb.73.094510': (['B12Zr1'], [6.0]),
#  'physrevb.73.094522': (['Y1'], [17.0]),
#  'physrevb.73.144510': (['Y0.54Pr0.46Ba2Cu3O7-z'], [38.0]),
#  'physrevb.73.184521': (['Li1Ti2O4'], [12.3]),
#  'physrevb.74.012504': (['Li0.68Nb1O2'], [5.5]),
#  'physrevb.74.134513': (['Pr1Pt2B2C1'], [6.0]),
#  'physrevb.74.174501': (['Nb2As1C1'], [2.0]),
#  'physrevb.75.054513': (['Ba8Si40Ga6'], [3.3]),
#  'physrevb.75.064517': (['Nb2Se3'], [2.4]),
#  'physrevb.75.174502': (['Pb1'], [7.186]),
#  'physrevb.76.012505': (['Sc1'], [8.2]),
#  'physrevb.76.014528': (['Al3Mg2'], [0.87]),
#  'physrevb.76.100506': (['Na0.3Co1H2.6O3.3'], [4.8]),
#  'physrevb.77.092505': (['Ca24Al28O66'], [0.195]),
#  'physrevb.77.174503': (['La1Fe1As1F0.11O0.89'], [28.2]),
#  'physrevb.77.180504': (['Th1Pt4Ge12'], [4.8]),
#  'physrevb.77.180510': (['Sm1Fe1As1F0.15O0.85'], [40.0]),
#  'physrevb.77.184512': (['Sr0.9La0.1Cu1O2'], [43.0]),
#  'physrevb.77.193106': (['Li0.9Mo6O17'], [1.92]),
#  'physrevb.78.012507': (['La1Fe1As1F0.1O0.9'], [23.7]),
#  'physrevb.78.014502': (['Mo3Sb7'], [2.1]),
#  'physrevb.78.014507': (['Ba0.55K0.45Fe2As2'], [29.5]),
#  'physrevb.78.024509': (['Bi2Pd3Se2'], [0.96]),
#  'physrevb.78.024514': (['Lu2Fe3Si5'], [6.0]),
#  'physrevb.78.060506': (['C6Ca1'], [11.6]),
#  'physrevb.78.064510': (['Pr1Os4Sb12'], [1.87]),
#  'physrevb.78.064516': (['Th1Pt4Ge12'], [4.8]),
#  'physrevb.78.092406': (['Eu0.5K0.5Fe2As2'], [32.0]),
#  'physrevb.78.092503': (['La0.85Sr0.15Fe1As1O1-z'], [26.0]),
#  'physrevb.78.100503': (['Y1Ba2Cu4O8'], [81.6]),
#  'physrevb.78.100507': (['La1Fe1As1F0.1O0.9'], [22.8]),
#  'physrevb.78.104527': (['Ba0.55K0.45Fe2As2'], [30.2]),
#  'physrevb.78.134504': (['B12Lu1'], [0.42]),
#  'physrevb.78.134508': (['Nd1Fe1As1F0.18O0.82'], [50.0]),
#  'physrevb.78.172504': (['Sr1Ni2As2'], [0.66]),
#  'physrevb.78.172505': (['Mo3Sb7'], [2.2]),
#  'physrevb.78.174523': (['Nd1Fe1As1F0.3O0.7'], [46.0]),
#  'physrevb.78.184512': (['Sm1Fe1P1O1'], [3.0]),
#  'physrevb.78.220505': (['Ba0.55K0.45Fe2As2'], [32.0]),
#  'physrevb.79.014514': (['Ba0.64K0.36Fe2As2'], [26.2]),
#  'physrevb.79.014519': (['Fe1Se0.72'], [8.0]),
#  'physrevb.79.020508': (['Nd1Fe1As1F0.2O0.8'], [32.6]),
#  'physrevb.79.024514': (['Bi2Sr1.6La0.4Cu1O6+z'], [32.0]),
#  'physrevb.79.054517': (['Ba0.6K0.4Fe2As2'], [32.0]),
#  'physrevb.79.054520': (['Th1Pt4Ge12'], [4.62]),
#  'physrevb.79.094505': (['Ba0.6K0.4Fe2As2'], [34.6]),
#  'physrevb.79.094507': (['Ba1Fe1.852Co0.148As2'], [23.0]),
#  'physrevb.79.094508': (['Ba1Ni2As2'], [1.5]),
#  'physrevb.79.104501': (['Pr0.75Sr0.25Fe1As1O1'], [16.3]),
#  'physrevb.79.132506': (['Ba1Ni2P2'], [2.51]),
#  'physrevb.79.134507': (['Sr1Ni2P2'], [1.415]),
#  'physrevb.79.140505': (['B105'], [1.5]),
#  'physrevb.79.140509': (['Fe1.03Te0.7Se0.3'], [12.4]),
#  'physrevb.79.144509': (['B3Ru7'], [3.3]),
#  'physrevb.79.172506': (['Ba1Fe2As2'], [35.0]),
#  'physrevb.79.172507': (['Ce1Pt1Si2'], [0.14]),
#  'physrevb.79.174501': (['Ba0.6K0.4Fe2As2'], [36.5]),
#  'physrevb.79.174505': (['La1Fe0.96Ni0.04As1O1'], [6.5]),
#  'physrevb.79.174511': (['Pr1Os4Sb12'], [1.85]),
#  'physrevb.79.224522': (['Sr1Pd2Ge2'], [3.09]),
#  'physrevb.80.024518': (['Fe1Se1'], [8.8]),
#  'physrevb.80.024519': (['Ca1Fe2As2'], [11.6]),
#  'physrevb.80.052501': (['Sr1Fe2As2'], [25.0]),
#  'physrevb.80.064504': (['Ba1Pt1Si3'], [2.0]),
#  'physrevb.80.064506': (['Fe1Se1'], [13.4]),
#  'physrevb.80.094501': (['Ba1Fe1.852Co0.148As2'], [22.5]),
#  'physrevb.80.100503': (['Sr2Ca12Cu24O41'], [9.7]),
#  'physrevb.80.134523': (['Fe1.06Te0.5Se0.5'], [14.0]),
#  'physrevb.80.140513': (['Ce1Cu2Si2'], [0.46]),
#  'physrevb.80.144524': (['Ca1Fe1.94Ni0.06As2'], [15.0]),
#  'physrevb.80.172501': (['U1Ru2Si2'], [1.51]),
#  'physrevb.80.180507': (['Fe1Se0.25Te0.75'], [14.0]),
#  'physrevb.80.220509': (['La1Fe1P1O1'], [7.4]),
#  'physrevb.80.224522': (['Ho1Ni2B2C'], [8.6]),
#  'physrevb.81.020509': (['Fe1.11Te0.6Se0.4'], [14.0]),
#  'physrevb.81.020510': (['Ca1Fe1.92Co0.08As2'], [20.4]),
#  'physrevb.81.060501': (['Ba1Fe1.85Co0.15As2'], [21.4]),
#  'physrevb.81.060509': (['Ba1Fe1.8Co0.2As2'], [20.0]),
#  'physrevb.81.092506': (['Fe1.08Te1Ox'], [12.0]),
#  'physrevb.81.092507': (['Cu0.06Ti1Se2'], [2.5]),
#  'physrevb.81.094520': (['Ba1Fe1.73Co0.27As2'], [8.1]),
#  'physrevb.81.104522': (['Ba8Si46'], [8.1]),
#  'physrevb.81.140507': (['Ce1Ir1Ge3'], [1.61]),
#  'physrevb.81.144414': (['Eu1Pt1Si3'], [3.7]),
#  'physrevb.81.180507': (['Ce1Pt2In7'], [2.1]),
#  'physrevb.81.184509': (['Bi1.98Sr2.06Y0.68Cu2O8+z'], [8.0]),
#  'physrevb.81.184522': (['Fe1.14Te0.91S0.09'], [8.5]),
#  'physrevb.81.205119': (['Fe1Se0.99'], [6.99]),
#  'physrevb.81.220501': (['Ba1Fe2As1.34P0.66'], [30.0]),
#  'physrevb.81.224511': (['Ba1Fe2As2'], [13.0]),
#  'physrevb.82.014518': (['Nb1S2'], [6.05]),
#  'physrevb.82.024503': (['Pb1.16Ti2Se5.16'], [2.3]),
#  'physrevb.82.064511': (['Al2C1Mo3'], [9.0]),
#  'physrevb.82.064512': (['Al2C1Mo3'], [9.1]),
#  'physrevb.82.094502': (['Ba1Fe2As1.3P0.7'], [30.5]),
#  'physrevb.82.094506': (['B1I3'], [1.86]),
#  'physrevb.82.094517': (['Sn3Y1'], [7.3]),
#  'physrevb.82.140507': (['Sr2V1Fe1As1O3'], [33.0]),
#  'physrevb.82.144118': (['Ba1Fe2As2'], [22.0]),
#  'physrevb.82.144518': (['Sr1Fe1.84Pt0.16As2'], [16.0]),
#  'physrevb.82.144527': (['Rb1Fe2As2'], [2.52]),
#  'physrevb.82.144532': (['B2Os1'], [2.2]),
#  'physrevb.82.174509': (['Ba1Fe1.85Co0.15As2'], [25.0]),
#  'physrevb.82.180512': (['Sr0.6La0.4Fe2As2'], [22.0]),
#  'physrevb.83.054509': (['Bi2Sr1.6La0.4Cu1O6+z'], [28.0]),
#  'physrevb.83.060502': (['Li1Fe1As1'], [17.8]),
#  'physrevb.83.060512': (['Rb0.88Fe1.81Se2'], [32.1]),
#  'physrevb.83.064504': (['Ce2Pd1In8'], [0.7]),
#  'physrevb.83.064522': (['La1Rh1Si3'], [2.16]),
#  'physrevb.83.100501': (['Eu1Fe2As2'], [30.0]),
#  'physrevb.83.100502': (['Li1Fe1As1'], [17.5]),
#  'physrevb.83.100503': (['Eu1Fe1As1.64P0.36'], [28.0]),
#  'physrevb.83.100513': (['Sm1Fe1As1F0.15O0.85'], [49.5]),
#  'physrevb.83.100514': (['K0.8Fe1.76Se2'], [32.2]),
#  'physrevb.83.104508': (['K0.8Fe2Se2'], [33.0]),
#  'physrevb.83.115131': (['La3Ni2B2N2.7'], [12.5]),
#  'physrevb.83.134521': (['Fe1Te0.57Se0.43'], [15.0]),
#  'physrevb.83.140501': (['Bi3Ni1'], [3.85]),
#  'physrevb.83.140504': (['Bi2Te3'], [9.5]),
#  'physrevb.83.144510': (['Ce1Co1In5'], [2.325]),
#  'physrevb.83.144511': (['K0.8Fe2Se2'], [32.0]),
#  'physrevb.83.144525': (['Nb0.18Re0.82'], [8.75]),
#  'physrevb.83.174503': (['K0.65Fe1.41Se2'], [32.0]),
#  'physrevb.83.174506': (['Li1Fe1As1'], [17.5]),
#  'physrevb.83.174510': (['Tl0.47Rb0.34Fe1.63Se2'], [32.0]),
#  'physrevb.83.174520': (['La1Sb2'], [1.7]),
#  'physrevb.83.214513': (['Eu1Fe2As2'], [29.0]),
#  'physrevb.83.220512': (['Ca1'], [29.0]),
#  'physrevb.83.224512': (['Li1Fe1As1'], [16.9]),
#  'physrevb.84.024502': (['Eu1Fe2As2'], [25.0]),
#  'physrevb.84.024509': (['Ba1Fe1.922Rh0.078As2'], [14.0]),
#  'physrevb.84.054507': (['Li1Fe1As1'], [18.0]),
#  'physrevb.84.054531': (['Nb1S2'], [6.05]),
#  'physrevb.84.054541': (['Lu2Fe3Si5'], [2.78]),
#  'physrevb.84.064518': (['Bi1Pd1'], [3.8]),
#  'physrevb.84.064525': (['Ba0.65Na0.35Fe2As2'], [29.4]),
#  'physrevb.84.104502': (['Li1Fe1As1'], [17.4]),
#  'physrevb.84.140507': (['Ce2Pd1In8'], [0.68]),
#  'physrevb.84.174502': (['Fe1Se0.42Te0.58'], [14.8]),
#  'physrevb.84.214527': (['La1Ru3Si2'], [7.9]),
#  'physrevb.84.220504': (['Y1Pt1Bi1'], [0.77]),
#  'physrevb.85.014520': (['Sr1Pd2Ge2'], [2.9]),
#  'physrevb.85.024526': (['U1Co1Ge1'], [0.6]),
#  'physrevb.85.024538': (['Sr1Ni2Ge2'], [0.92]),
#  'physrevb.85.054507': (['K0.8Fe1.7S1Se1'], [26.3]),
#  'physrevb.85.054517': (['La1Ni2P2'], [2.1]),
#  'physrevb.85.064504': (['Fe1.08Te0.55Se0.45Ox'], [14.5]),
#  'physrevb.85.064513': (['Tl0.58Rb0.42Fe1.72Se2'], [33.5]),
#  'physrevb.85.180504': (['Ca10Pt3.97Fe9.03As18'], [11.0]),
#  'physrevb.85.180505': (['Li1Fe1As1'], [15.0]),
#  'physrevb.85.184501': (['Ca0.67Sr0.33Fe2As2'], [22.0]),
#  'physrevb.85.184513': (['Te3Zr1'], [2.1]),
#  'physrevb.85.205105': (['Ce1Cu2Si2'], [0.8]),
#  'physrevb.85.214526': (['Yb1Sb2'], [1.3]),
#  'physrevb.85.224504': (['Ba0.55K0.45Fe1.95Co0.05As2'], [32.5]),
#  'physrevb.86.020501': (['Ce1Fe1As0.7P0.3O1'], [4.0]),
#  'physrevb.86.054502': (['Rh3Bi14'], [2.94]),
#  'physrevb.86.064504': (['Ca3Ir4Sn13'], [7.25]),
#  'physrevb.86.064516': (['Li1Fe1As1'], [17.0]),
#  'physrevb.86.144525': (['Sr1Fe2As1.4P0.6'], [25.0]),
#  'physrevb.86.220509': (['Fe1Te0.6Se0.4'], [13.6]),
#  'physrevb.86.220510': (['Bi4S3O4'], [8.6]),
#  'physrevb.86.224514': (['K1Fe2As2'], [3.4]),
#  'physrevb.87.020504': (['Sr0.5La0.5F1Bi1S2'], [2.8]),
#  'physrevb.87.024508': (['Te3Zr1'], [4.0]),
#  'physrevb.87.045124': (['K1Ni2S2'], [0.46]),
#  'physrevb.87.054504': (['Li1Fe1P1'], [4.86]),
#  'physrevb.87.060510': (['Ba1Ti2Sb2O1'], [0.95]),
#  'physrevb.87.064502': (['Pr1Pt4Ge12'], [7.8]),
#  'physrevb.87.094515': (['Sr1Pd2Ge2'], [2.7]),
#  'physrevb.87.104515': (['Mo3Sb7'], [2.35]),
#  'physrevb.87.134512': (['Fe1Se1'], [9.9]),
#  'physrevb.87.134513': (['K1Fe2As2'], [3.8]),
#  'physrevb.87.140507': (['Sn0.6In0.4Te1'], [4.7]),
#  'physrevb.87.144502': (['Cs1Fe2As2'], [1.81]),
#  'physrevb.87.174510': (['Ir3Te8'], [1.8]),
#  'physrevb.87.180508': (['Pr4Fe2As2Te0.88O4'], [25.1]),
#  'physrevb.87.184504': (['Lu1Pt1Bi1'], [1.0]),
#  'physrevb.87.214504': (['La1Sb2'], [1.2]),
#  'physrevb.87.214509': (['Cs1Fe2As2'], [1.88]),
#  'physrevb.87.224507': (['Sr1Pt2As2'], [4.6]),
#  'physrevb.88.014517': (['K1Fe2As2'], [3.4]),
#  'physrevb.88.024423': (['La3Pd4Si4'], [1.98]),
#  'physrevb.88.140501': (['Ba0.75Na0.25Ti2Sb2O1'], [4.5]),
#  'physrevb.88.144511': (['La1Pd0.85Bi2'], [4.0]),
#  'physrevb.88.180509': (['La0.5Bi1S2F0.5O0.5'], [10.0]),
#  'physrevb.88.184508': (['Bi3Ni1'], [4.0]),
#  'physrevb.88.224510': (['Eu1Fe2As2'], [31.0]),
#  'physrevb.88.224515': (['Bi4S3O4'], [4.8]),
#  'physrevb.89.020505': (['Pb1Ta1Se2'], [3.7]),
#  'physrevb.89.020507': (['Li1Fe3Se2O2'], [42.0]),
#  'physrevb.89.024518': (['Sm4Fe2As2Te0.72F1.2O2.8'], [37.0]),
#  'physrevb.89.054512': (['Ca10Bi9.88'], [2.2]),
#  'physrevb.89.094520': (['Sr3Ir4Sn13'], [5.0]),
#  'physrevb.89.100501': (['Ir0.95Pd0.05Te2'], [2.5]),
#  'physrevb.89.140504': (['Sr1Pt1As1'], [2.4]),
#  'physrevb.89.174515': (['La1F0.5Bi1S2O0.5'], [10.8]),
#  'physrevb.89.205136': (['Ca10Pt0.78Fe9.22As18'], [9.96]),
#  'physrevb.89.224504': (['Ca3Ir4Ge4'], [1.7]),
#  'physrevb.90.014513': (['La1Ir1Si3'], [1.45]),
#  'physrevb.90.020502': (['K0.5Na0.24Fe1.52Se2'], [20.0]),
#  'physrevb.90.035115': (['Sr3Ir4Sn13'], [5.0]),
#  'physrevb.90.064518': (['Eu1Bi1S2F1'], [0.3]),
#  'physrevb.90.144508': (['Ba2Ti2Fe2As4O1'], [21.5]),
#  'physrevb.90.220504': (['C1.36Pb5Bi12Se23'], [2.9]),
#  'physrevb.90.220508': (['La1Ni1C2'], [2.8]),
#  'physrevb.90.220510': (['Eu3Bi2S4F4'], [1.43]),
#  'physrevb.90.224410': (['Ce1Bi1S2F0.7O0.3'], [4.5]),
#  'physrevb.90.224513': (['Ca10Ir4Fe10As18'], [19.2]),
#  'physrevb.91.014513': (['Ba1Pt2Sb2'], [1.85]),
#  'physrevb.91.020507': (['K2Cr3As3'], [6.1]),
#  'physrevb.91.024509': (['Pd2Hf1Al1'], [3.55]),
#  'physrevb.91.060508': (['K1Fe2As2'], [4.2]),
#  'physrevb.91.060510': (['Sr1Pt2As2'], [5.2]),
#  'physrevb.91.064509': (['La1Fe1As1H0.44O0.56'], [21.0]),
#  'physrevb.91.094427': (['Eu1Fe1.72Ir0.28As2'], [21.5]),
#  'physrevb.91.100504': (['Nb2Pd1S5'], [6.05]),
#  'physrevb.91.104506': (['Ta4Pd3Te16'], [4.3]),
#  'physrevb.91.104511': (['Bi3S3O2'], [5.75]),
#  'physrevb.91.125107': (['Li0.8Fe1.2H1Se1'], [34.0]),
#  'physrevb.91.134508': (['Nb0.18Re0.82'], [8.5]),
#  'physrevb.91.174513': (['Bi2Rh3.5S2'], [2.1]),
#  'physrevb.91.214517': (['Au2Pb1'], [1.3]),
#  'physrevb.91.220505': (['K2Cr3As3'], [6.1]),
#  'physrevb.92.020506': (['Sr0.1Bi2Se3'], [2.94]),
#  'physrevb.92.024511': (['Th1Pt3B1'], [0.75]),
#  'physrevb.92.134517': (['Sr0.3M1Fe2Se2'], [36.3]),
#  'physrevb.92.161114': (['Ce3Pt1In11'], [0.32]),
#  'physrevb.93.054508': (['Li1Fe1As1'], [18.0]),
#  'physrevb.93.054520': (['Pb1Ta1Se2'], [3.8]),
#  'physrevb.93.060506': (['Pb1Ta1Se2'], [3.9]),
#  'physrevb.93.064504': (['Sr1Pt1As1'], [2.45]),
#  'physrevb.93.094511': (['Bi2Te1'], [8.6]),
#  'physrevb.93.104508': (['M0.37Cs0.268Fe1Se1'], [33.5]),
#  'physrevb.93.104516': (['Ba0.85K0.15Fe2As2'], [14.0]),
#  'physrevb.93.115119': (['Ba1Fe2As1.34P0.66'], [25.0]),
#  'physrevb.93.144502': (['Bi2Pd1'], [4.93]),
#  'physrevb.93.214503': (['Rb1Eu1Fe4As4'], [36.5]),
#  'physrevb.93.220504': (['Bi2Pd1'], [4.84]),
#  'physrevb.93.224512': (['Li1.84H1Fe1.14Se1O1'], [40.5]),
#  'physrevb.93.224516': (['Cs1Fe2As2'], [2.11]),
#  'physrevb.93.241112': (['La3Co4Sn13'], [2.7]),
#  'physrevb.94.024518': (['Hf1Re6'], [6.4]),
#  'physrevb.94.035130': (['Y1Pt1Bi1'], [0.97]),
#  'physrevb.94.054514': (['Ce1Cu2Si2'], [0.6]),
#  'physrevb.94.054515': (['Hf1Re6'], [5.96]),
#  'physrevb.94.054517': (['Hf1Te5'], [4.8]),
#  'physrevb.94.054523': (['La1Pt4Ge12'], [8.0]),
#  'physrevb.94.064501': (['Ca1K1Fe4As4'], [35.0]),
#  'physrevb.94.104507': (['Ba8Si46'], [7.31]),
#  'physrevb.94.144515': (['Re6Zr1'], [6.7]),
#  'physrevb.94.180509': (['Y1Sr2Mo0.25Cu2.75O7.54'], [78.0]),
#  'physrevb.95.014502': (['K2Cr3As3'], [6.2]),
#  'physrevb.95.024510': (['Bi1'], [3.9]),
#  'physrevb.95.035148': (['Ir1Te2'], [2.5]),
#  'physrevb.95.060505': (['Ba1Fe1.915Ni0.085As2'], [18.0]),
#  'physrevb.95.064514': (['Ge1Sb2Te4'], [8.1]),
#  'physrevb.95.094510': (['Ca8.5La1.5Pt3Fe10As18'], [35.2]),
#  'physrevb.95.140505': (['Ca1K1Fe4As4'], [34.3]),
#  'physrevb.95.174521': (['Ta1Ir2Ge2'], [3.9]),
#  'physrevb.96.060509': (['Pd1Se2'], [13.1]),
#  'physrevb.96.064512': (['Li0.36M1Fe2Se2'], [44.56]),
#  'physrevb.96.064521': (['Re6Zr1'], [6.75]),
#  'physrevb.96.064528': (['Pb1Ta1Se2'], [4.02]),
#  'physrevb.96.094523': (['Ba1Fe1.864Rh0.136As2'], [23.3]),
#  'physrevb.96.140501': (['Ca1K1Fe4As4'], [35.0]),
#  'physrevb.96.144502': (['Th1As1Fe1N1'], [30.0]),
#  'physrevb.96.165123': (['Se1Sn1'], [3.25]),
#  'physrevb.96.224433': (['Sm0.04La0.96Ni1C2'], [1.01]),
#  'physrevb.97.014501': (['Au1Be1'], [3.3]),
#  'physrevb.97.014514': (['Tl1Ni2Se2'], [3.7]),
#  'physrevb.97.014523': (['Pd1Te2'], [1.78]),
#  'physrevb.97.020502': (['Re24Ti5'], [6.8]),
#  'physrevb.97.020508': (['Li0.36M1Fe2As2'], [44.3]),
#  'physrevb.97.024501': (['Sr1Au1Si3'], [1.54]),
#  'physrevb.97.054506': (['B2Ru1'], [1.5]),
#  'physrevb.97.054515': (['Pd1Te2'], [1.75]),
#  'physrevb.97.060506': (['Cs1Ca2Fe4As4F2'], [28.31]),
#  'physrevb.97.060509': (['K1Ca2Fe4As4F2'], [33.36]),
#  'physrevb.97.064514': (['Ce1Rh1Ge3'], [1.33]),
#  'physrevb.97.100504': (['La1Fe1Si1H1'], [9.7]),
#  'physrevb.97.104509': (['La1Bi1S2F0.5O0.5'], [3.7]),
#  'physrevb.97.134508': (['Ba1Pd2As2'], [3.5]),
#  'physrevb.97.224506': (['Re6Zr1'], [6.8]),
#  'physrevb.97.224511': (['Tb1Pd1Bi1'], [1.7]),
#  'physrevb.98.014502': (['Ta1Rh2B2'], [6.0]),
#  'physrevb.98.020503': (['Na1Sn2As2'], [1.18]),
#  'physrevb.98.024520': (['As1Cr1'], [1.85]),
#  'physrevb.98.094504': (['Nd1Fe1As1F0.1O0.9'], [45.4]),
#  'physrevb.98.094519': (['Ir0.8Rh0.2Te2'], [2.6]),
#  'physrevb.98.104503': (['Rb1Eu1Fe4As4'], [36.8]),
#  'physrevb.98.104506': (['Re3Ta1'], [4.65]),
#  'physrevb.98.134512': (['Cr0.8Ru0.2'], [1.35]),
#  'physrevb.98.214505': (['La1Pt1Ge1'], [3.05]),
#  'physrevb.98.224505': (['Ba1Fe1.9Pt0.1As2'], [23.0]),
#  'physrevb.99.054503': (['Ga41Mo1'], [10.0]),
#  'physrevb.99.100501': (['Ce1Ni1C2'], [3.5]),
#  'physrevb.99.134509': (['Au1Be1'], [3.2]),
#  'physrevb.99.144511': (['H1Pt1'], [6.7]),
#  'physrevb.99.144519': (['Al6Re1'], [0.74]),
#  'physrevb.99.174513': (['Zr1Ir1Si1'], [1.7]),
#  'physrevb.99.184509': (['P1W1'], [0.834]),
#  'physrevb.99.184513': (['Mo3P1'], [5.7])}

# %%
len(processed_database_output)
# Out:
# 511

# %%
len(processed_model_output)
# Out:
# 511

# %%
correct_num_materials = 0
for key in processed_database_output.keys():
    dbase_output = set(set(processed_database_output[key][0]))
    print(dbase_output)
    chemform_dbase = [standard_chem_formula(chemparse.parse_formula(entry)) for entry in dbase_output]
    model_output = set(set(processed_model_output[key][0]))
    out = []
    for entry in model_output:
        try:
            out.append(standard_chem_formula(chemparse.parse_formula(entry)))
        except:
            out.append('blah')
    print(key)
    print(chemform_dbase)
    print(out)
    print(set(chemform_dbase).intersection(set(out)))
    print("-----------")
    if len(set(chemform_dbase).intersection(set(out))) > 0: correct_num_materials += 1
# Out:
# {'Ga1'}
# physrevb.10.4572
# ['Ga']
# ['Ga']
# {'Ga'}
# -----------
# {'Eu1Fe2As2'}
# physrevb.100.014503
# ['AsEuFe']
# ['AsEuFe']
# {'AsEuFe'}
# -----------
# {'Pd1S2'}
# physrevb.100.014507
# ['PdS']
# ['PdS']
# {'PdS'}
# -----------
# {'Rb1'}
# physrevb.100.041109
# ['Rb']
# ['Rb']
# {'Rb'}
# -----------
# {'Au2Pb1'}
# physrevb.100.060103
# ['AuPb']
# ['AuPb']
# {'AuPb'}
# -----------
# {'Rb1Cr3As3'}
# physrevb.100.094511
# ['AsCrRb']
# ['AsCrRb']
# {'AsCrRb'}
# -----------
# {'W3Al2C1'}
# physrevb.100.094522
# ['AlCW']
# ['AlCW']
# {'AlCW'}
# -----------
# {'Ta1Os1Si1'}
# physrevb.100.134503
# ['OsSiTa']
# ['OsSiTa']
# {'OsSiTa'}
# -----------
# {'K0.18W1O3'}
# physrevb.23.2219
# ['KOW']
# ['KOW']
# {'KOW'}
# -----------
# {'K1Hg1C4'}
# physrevb.26.6315
# ['CHgK']
# ['CHgK']
# {'CHgK'}
# -----------
# {'La1Ir2Si2'}
# physrevb.28.1389
# ['IrLaSi']
# ['IrLaSi']
# {'IrLaSi'}
# -----------
# {'Ce1Cu2Si2'}
# physrevb.30.1182
# ['CeCuSi']
# ['CeCuSi']
# {'CeCuSi'}
# -----------
# {'Pt3U1'}
# physrevb.30.1583
# ['PtU']
# ['PtU']
# {'PtU'}
# -----------
# {'Pt3U1'}
# physrevb.30.2986
# ['PtU']
# ['PtU']
# {'PtU'}
# -----------
# {'Ce1Ru3Si2'}
# physrevb.30.444
# ['CeRuSi']
# ['CeRuSi']
# {'CeRuSi'}
# -----------
# {'Co35.38Zr64.62'}
# physrevb.30.5135
# ['CoZr']
# ['CoZr']
# {'CoZr'}
# -----------
# {'Pt3U1'}
# physrevb.31.1654
# ['PtU']
# ['PtU']
# {'PtU'}
# -----------
# {'Pd2Yb1Sn1'}
# physrevb.32.135
# ['PdSnYb']
# ['PdSnYb']
# {'PdSnYb'}
# -----------
# {'Lu5Ir4Si10'}
# physrevb.34.4590
# ['IrLuSi']
# ['IrLuSi']
# {'IrLuSi'}
# -----------
# {'Ga1'}
# physrevb.34.4920
# ['Ga']
# ['Ga']
# {'Ga'}
# -----------
# {'La1.8Sr0.2Cu1O4'}
# physrevb.36.3906
# ['CuLaOSr']
# ['CuLaOSr']
# {'CuLaOSr'}
# -----------
# {'Y1.2Ba0.8Cu1O4'}
# physrevb.36.3910
# ['BaCuOY']
# ['BaCuOY']
# {'BaCuOY'}
# -----------
# {'Y1Ba2Cu3O7+Y'}
# physrevb.36.3920
# ['BaCuOY']
# ['BaCuOY']
# {'BaCuOY'}
# -----------
# {'La1.85Sr0.15Cu1O4'}
# physrevb.36.4003
# ['CuLaOSr']
# ['CuLaOSr']
# {'CuLaOSr'}
# -----------
# {'Y1Ba2Cu3O7'}
# physrevb.36.4014
# ['BaCuOY']
# ['BaCuOY']
# {'BaCuOY'}
# -----------
# {'Gd1Ba2Cu2.82Fe0.18O9-Z'}
# physrevb.36.4018
# ['BaCuFeGdOZ']
# ['BaCuFeGdOZ']
# {'BaCuFeGdOZ'}
# -----------
# {'Y1Ba2Cu3O7-Z'}
# physrevb.36.8329
# ['BaCuOYZ']
# ['BaCuOYZ']
# {'BaCuOYZ'}
# -----------
# {'La1Fe4P12'}
# physrevb.36.8660
# ['FeLaP']
# ['FeLaP']
# {'FeLaP'}
# -----------
# {'Er1Ba2Cu3O7-Z'}
# physrevb.36.8791
# ['BaCuErOZ']
# ['BaCuErOZ']
# {'BaCuErOZ'}
# -----------
# {'Bi2Sr2Ca1Cu2O8'}
# physrevb.38.11955
# ['BiCaCuOSr']
# ['BiCaCuOSr']
# {'BiCaCuOSr'}
# -----------
# {'Tl2Ba2Cu1O6'}
# physrevb.38.225
# ['BaCuOTl']
# ['BaCuOTl']
# {'BaCuOTl'}
# -----------
# {'Ho1Ba2Cu3O6.9'}
# physrevb.38.2455
# ['BaCuHoO']
# ['BaCuHoO']
# {'BaCuHoO'}
# -----------
# {'La2Cu1O4+Z'}
# physrevb.39.11445
# ['CuLaOZ']
# ['CuLaOZ']
# {'CuLaOZ'}
# -----------
# {'Y1Ba2Cu3O7'}
# physrevb.39.6571
# ['BaCuOY']
# ['BaCuOY']
# {'BaCuOY'}
# -----------
# {'Ba0.6K0.4Bi1O3-Z'}
# physrevb.39.7339
# ['BaBiKOZ']
# ['BaBiKOZ']
# {'BaBiKOZ'}
# -----------
# {'La1Ba1Ca1Cu3O6.98'}
# physrevb.39.9074
# ['BaCaCuLaO']
# ['BaCaCuLaO']
# {'BaCaCuLaO'}
# -----------
# {'Ba0.6Rb0.4Bi1O3'}
# physrevb.40.2690
# ['BaBiORb']
# ['BaBiORb']
# {'BaBiORb'}
# -----------
# {'Bi2Sr2Ca1Cu2O8'}
# physrevb.40.841
# ['BiCaCuOSr']
# ['BiCaCuOSr']
# {'BiCaCuOSr'}
# -----------
# {'La1.96Sr0.04Cu1O4'}
# physrevb.41.2520
# ['CuLaOSr']
# ['CuLaOSr']
# {'CuLaOSr'}
# -----------
# {'Bi2Sr2Ca1Cu2O8+z'}
# physrevb.41.9551
# ['zBiCaCuOSr']
# ['zBiCaCuOSr']
# {'zBiCaCuOSr'}
# -----------
# {'Si2Ta1'}
# physrevb.45.4803
# ['SiTa']
# ['SiTa']
# {'SiTa'}
# -----------
# {'Tl2Ba2Ca1Cu2O8'}
# physrevb.45.5628
# ['BaCaCuOTl']
# ['BaCaCuOTl']
# {'BaCaCuOTl'}
# -----------
# {'Y1Ba2Cu4O8'}
# physrevb.48.16869
# ['BaCuOY']
# ['BaCuOY']
# {'BaCuOY'}
# -----------
# {'Hg0.66Pb0.33Ba2Ca2Cu3Oy'}
# physrevb.49.12322
# ['BaCaCuHgOyPb']
# ['BaCaCuHgOyPb']
# {'BaCaCuHgOyPb'}
# -----------
# {'Hg1Ba2Cu1O4+d'}
# physrevb.49.13075
# ['dBaCuHgO']
# ['dBaCuHgO']
# {'dBaCuHgO'}
# -----------
# {'Bi2Sr2Ca1Cu2O8+y'}
# physrevb.49.13184
# ['yBiCaCuOSr']
# ['yBiCaCuOSr']
# {'yBiCaCuOSr'}
# -----------
# {'Bi0.5Sr1.5Y1.15Ce0.85Cu2O8-z'}
# physrevb.49.1492
# ['zBiCeCuOSrY']
# ['zBiCeCuOSrY']
# {'zBiCeCuOSrY'}
# -----------
# {'Bi2Sr2Ca2Cu3O10'}
# physrevb.49.1495
# ['BiCaCuOSr']
# ['BiCaCuOSr']
# {'BiCaCuOSr'}
# -----------
# {'Hg1Ba2Ca2Cu3O8+d'}
# physrevb.49.15416
# ['dBaCaCuHgO']
# ['dBaCaCuHgO']
# {'dBaCaCuHgO'}
# -----------
# {'Bi2Sr2Ca1Cu2O8'}
# physrevb.49.15959
# ['BiCaCuOSr']
# ['BiCaCuOSr']
# {'BiCaCuOSr'}
# -----------
# {'Ba0.64K0.36Bi1O3'}
# physrevb.49.3502
# ['BaBiKO']
# ['BaBiKO']
# {'BaBiKO'}
# -----------
# {'Hg1Ba2Cu1O4+d'}
# physrevb.49.3683
# ['dBaCuHgO']
# ['dBaCuHgO']
# {'dBaCuHgO'}
# -----------
# {'Nd1.85Ce0.15Cu1O4'}
# physrevb.49.6392
# ['CeCuNdO']
# ['CeCuNdO']
# {'CeCuNdO'}
# -----------
# {'Tl2Mo6Se6'}
# physrevb.49.8931
# ['MoSeTl']
# ['MoSeTl']
# {'MoSeTl'}
# -----------
# {'Bi2Sr2Ca1Cu2O8'}
# physrevb.49.9073
# ['BiCaCuOSr']
# ['BiCaCuOSr']
# {'BiCaCuOSr'}
# -----------
# {'La1.925Sr0.075Cu1O4+d'}
# physrevb.49.9097
# ['dCuLaOSr']
# ['dCuLaOSr']
# {'dCuLaOSr'}
# -----------
# {'Bi2Sr2Ca1Cu2O8+d'}
# physrevb.49.9218
# ['dBiCaCuOSr']
# ['dBiCaCuOSr']
# {'dBiCaCuOSr'}
# -----------
# {'I1Bi2.2Sr1.8Ca1Cu2O8+y'}
# physrevb.49.9885
# ['yBiCaCuIOSr']
# ['yBiCaCuIOSr']
# {'yBiCaCuIOSr'}
# -----------
# {'Y1Ba2Cu3O7-d'}
# physrevb.49.9924
# ['dBaCuOY']
# ['dBaCuOY']
# {'dBaCuOY'}
# -----------
# {'Ba6C60'}
# physrevb.50.13890
# ['BaC']
# ['BaC']
# {'BaC'}
# -----------
# {'La1.85Sr0.15Cu1O4'}
# physrevb.50.15875
# ['CuLaOSr']
# ['CuLaOSr']
# {'CuLaOSr'}
# -----------
# {'Y1Ba2Cu3Oy'}
# physrevb.50.16125
# ['BaCuOyY']
# ['BaCuOyY']
# {'BaCuOyY'}
# -----------
# {'Sc1Ni2B2C1'}
# physrevb.50.351
# ['BCNiSc']
# ['BCNiSc']
# {'BCNiSc'}
# -----------
# {'Y2Ba4Cu7O15.1'}
# physrevb.50.426
# ['BaCuOY']
# ['BaCuOY']
# {'BaCuOY'}
# -----------
# {'Bi2Sr1.9Cu2.1Ox'}
# physrevb.50.496
# ['BiCuOxSr']
# ['BiCuOxSr']
# {'BiCuOxSr'}
# -----------
# {'La1Ni1Si1'}
# physrevb.50.6523
# ['LaNiSi']
# ['LaNiSi']
# {'LaNiSi'}
# -----------
# {'Ho1Ni2B2C1'}
# physrevb.51.12644
# ['BCHoNi']
# ['BCHoNi']
# {'BCHoNi'}
# -----------
# {'Tl1.89Ba2Cu1.11O6.18'}
# physrevb.51.12747
# ['BaCuOTl']
# ['BaCuOTl']
# {'BaCuOTl'}
# -----------
# {'La2Cu1O4.035'}
# physrevb.51.1286
# ['CuLaO']
# ['CuLaO']
# {'CuLaO'}
# -----------
# {'Pb0.17Hg1.22Ba2Ca1.44Cu2.79Ox'}
# physrevb.51.1393
# ['BaCaCuHgOxPb']
# ['BaCaCuHgOxPb']
# {'BaCaCuHgOxPb'}
# -----------
# {'Bi1.8Pb0.4Sr2Ca2Cu3O10+d'}
# physrevb.51.1397
# ['dBiCaCuOPbSr']
# ['dBiCaCuOPbSr']
# {'dBiCaCuOPbSr'}
# -----------
# {'Y2Ba4Cu7O14.97'}
# physrevb.51.15478
# ['BaCuOY']
# ['BaCuOY']
# {'BaCuOY'}
# -----------
# {'Y1Ba2Cu3O7-d'}
# physrevb.51.3316
# ['dBaCuOY']
# ['dBaCuOY']
# {'dBaCuOY'}
# -----------
# {'Y1Ba2Cu3O6.95'}
# physrevb.52.10569
# ['BaCuOY']
# ['BaCuOY']
# {'BaCuOY'}
# -----------
# {'Ho1Ni2B2C1'}
# physrevb.52.1181
# ['BCHoNi']
# ['BCHoNi']
# {'BCHoNi'}
# -----------
# {'C60Sm3'}
# physrevb.52.15534
# ['CSm']
# ['CSm']
# {'CSm'}
# -----------
# {'Nd1.85Ce0.15Cu1O4-d'}
# physrevb.52.3071
# ['dCeCuNdO']
# ['dCeCuNdO']
# {'dCeCuNdO'}
# -----------
# {'Rb1Cs2C60'}
# physrevb.52.4432
# ['CCsRb']
# ['CCsRb']
# {'CCsRb'}
# -----------
# {'K3N1H3C60'}
# physrevb.52.483
# ['CHKN']
# ['CHKN']
# {'CHKN'}
# -----------
# {'Bi2Sr2Ca1Cu2O8+y'}
# physrevb.52.7647
# ['yBiCaCuOSr']
# ['yBiCaCuOSr']
# {'yBiCaCuOSr'}
# -----------
# {'Dy1Ni2B2C1'}
# physrevb.52.r3844
# ['BCDyNi']
# ['BCDyNi']
# {'BCDyNi'}
# -----------
# {'Rh1Zr2'}
# physrevb.53.12299
# ['RhZr']
# ['RhZr']
# {'RhZr'}
# -----------
# {'Tm2Fe3Si5'}
# physrevb.53.12389
# ['FeSiTm']
# ['FeSiTm']
# {'FeSiTm'}
# -----------
# {'Ba2Ca3Cu5O11-y'}
# physrevb.53.5170
# ['yBaCaCuO']
# ['yBaCaCuO']
# {'yBaCaCuO'}
# -----------
# {'La1'}
# physrevb.53.8238
# ['La']
# ['La']
# {'La'}
# -----------
# {'Ce1Rh2Si2'}
# physrevb.53.8241
# ['CeRhSi']
# ['CeRhSi']
# {'CeRhSi'}
# -----------
# {'BaKBi1O3'}
# physrevb.54.6133
# ['BaBiKO']
# ['BaBiKO']
# {'BaBiKO'}
# -----------
# {'Lu1Ni2B2C1'}
# physrevb.54.r3772
# ['BCLuNi']
# ['BCLuNi']
# {'BCLuNi'}
# -----------
# {'Bi2Sr1.8Ca1.2Cu2O8'}
# physrevb.54.r6885
# ['BiCaCuOSr']
# ['BiCaCuOSr']
# {'BiCaCuOSr'}
# -----------
# {'Y1Ba2Cu3O6.95'}
# physrevb.55.11789
# ['BaCuOY']
# ['BaCuOY']
# {'BaCuOY'}
# -----------
# {'Y1Ba2Cu3O6.92'}
# physrevb.55.15300
# ['BaCuOY']
# ['BaCuOY']
# {'BaCuOY'}
# -----------
# {'Bi2Sr2Ca1Cu2O8+y'}
# physrevb.55.8529
# ['yBiCaCuOSr']
# ['yBiCaCuOSr']
# {'yBiCaCuOSr'}
# -----------
# {'Bi2Sr2Ca1Cu2O8+y'}
# physrevb.55.9125
# ['yBiCaCuOSr']
# ['yBiCaCuOSr']
# {'yBiCaCuOSr'}
# -----------
# {'Pr1.85Ce0.15Cu1O4-z'}
# physrevb.55.r6145
# ['zCeCuOPr']
# ['zCeCuOPr']
# {'zCeCuOPr'}
# -----------
# {'Hg1Ba2Ca2Cu3O8+y'}
# physrevb.55.r8674
# ['yBaCaCuHgO']
# ['yBaCaCuHgO']
# {'yBaCaCuHgO'}
# -----------
# {'Tb1Sr2Cu2.69Mo0.31O7'}
# physrevb.56.5631
# ['CuMoOSrTb']
# ['CuMoOSrTb']
# {'CuMoOSrTb'}
# -----------
# {'Sr2Ru1O4'}
# physrevb.56.7890
# ['ORuSr']
# ['ORuSr']
# {'ORuSr'}
# -----------
# {'Ca3Rh4Sn13'}
# physrevb.56.8346
# ['CaRhSn']
# ['CaRhSn']
# {'CaRhSn'}
# -----------
# {'Sr0.4Ca13.6Cu24O41+z'}
# physrevb.57.613
# ['zCaCuOSr']
# ['zCaCuOSr']
# {'zCaCuOSr'}
# -----------
# {'Y1Ba2Cu3O7-d'}
# physrevb.57.r14084
# ['dBaCuOY']
# ['dBaCuOY']
# {'dBaCuOY'}
# -----------
# {'La1Ni1C2'}
# physrevb.58.497
# ['CLaNi']
# ['CLaNi']
# {'CLaNi'}
# -----------
# {'Pt3U1'}
# physrevb.58.r603
# ['PtU']
# ['PtU']
# {'PtU'}
# -----------
# {'Bi2Sr2Ca1Cu2O8+X'}
# physrevb.59.11179
# ['BiCaCuOSrX']
# ['BiCaCuOSrX']
# {'BiCaCuOSrX'}
# -----------
# {'Nd1Ba2Cu3O7-Z'}
# physrevb.59.11563
# ['BaCuNdOZ']
# ['BaCuNdOZ']
# {'BaCuNdOZ'}
# -----------
# {'Y0.5Yb0.5Ba2Sr0Cu3O7-Z'}
# physrevb.59.13639
# ['BaCuOSrYYbZ']
# ['BaCuOSrYYbZ']
# {'BaCuOSrYYbZ'}
# -----------
# {'Ru1Sr2Gd1Cu2O8'}
# physrevb.59.14099
# ['CuGdORuSr']
# ['CuGdORuSr']
# {'CuGdORuSr'}
# -----------
# {'La1.905Ba0.095Cu1O4'}
# physrevb.59.14753
# ['BaCuLaO']
# ['BaCuLaO']
# {'BaCuLaO'}
# -----------
# {'La1.85Sr0.15Cu1O4'}
# physrevb.59.3827
# ['CuLaOSr']
# ['CuLaOSr']
# {'CuLaOSr'}
# -----------
# {'Lu5Ir4Si10'}
# physrevb.59.7266
# ['IrLuSi']
# ['IrLuSi']
# {'IrLuSi'}
# -----------
# {'I1Bi1.9Pb0.1Sr2Ca1Cu2O8+Z'}
# physrevb.59.8962
# ['BiCaCuIOPbSrZ']
# ['BiCaCuIOPbSrZ']
# {'BiCaCuIOPbSrZ'}
# -----------
# {'Y1Ba2Cu4O8'}
# physrevb.59.r11668
# ['BaCuOY']
# ['BaCuOY']
# {'BaCuOY'}
# -----------
# {'Ru1Sr2Gd1Cu2O8'}
# physrevb.59.r11679
# ['CuGdORuSr']
# ['CuGdORuSr']
# {'CuGdORuSr'}
# -----------
# {'Ba8Ga16Ge30'}
# physrevb.60.3064
# ['BaGaGe']
# ['BaGaGe']
# {'BaGaGe'}
# -----------
# {'Ru1Sr2Gd1Cu2O8'}
# physrevb.60.7512
# ['CuGdORuSr']
# ['CuGdORuSr']
# {'CuGdORuSr'}
# -----------
# {'Hg1Ba2Ca2Cu3O8+Z'}
# physrevb.61.11317
# ['BaCaCuHgOZ']
# ['BaCaCuHgOZ']
# {'BaCaCuHgOZ'}
# -----------
# {'Ca5.84Sr4.02Bi0.14Cu15.84O29'}
# physrevb.61.1500
# ['BiCaCuOSr']
# ['BiCaCuOSr']
# {'BiCaCuOSr'}
# -----------
# {'Y1Ba2Cu3O7-z'}
# physrevb.61.1584
# ['zBaCuOY']
# ['zBaCuOY']
# {'zBaCuOY'}
# -----------
# {'Eu1.5Ce0.5Sr2Cu1Ti1O10'}
# physrevb.61.6303
# ['CeCuEuOSrTi']
# ['CeCuEuOSrTi']
# {'CeCuEuOSrTi'}
# -----------
# {'Sr2.3Ca0.7Cu2Cl1.3O4+z'}
# physrevb.61.778
# ['zCaClCuOSr']
# ['zCaClCuOSr']
# {'zCaClCuOSr'}
# -----------
# {'V1'}
# physrevb.61.r3823
# ['V']
# ['V']
# {'V'}
# -----------
# {'Bi1.6Pb0.6Sr1.8Ca1Cu2OZ'}
# physrevb.61.r9269
# ['BiCaCuOPbSrZ']
# ['BiCaCuOPbSrZ']
# {'BiCaCuOPbSrZ'}
# -----------
# {'Lu1Ni2B2C1'}
# physrevb.63.134519
# ['BCLuNi']
# ['BCLuNi']
# {'BCLuNi'}
# -----------
# {'Ge2U1'}
# physrevb.63.144519
# ['GeU']
# ['GeU']
# {'GeU'}
# -----------
# {'Y2Pd1Ge3'}
# physrevb.63.172407
# ['GePdY']
# ['GePdY']
# {'GePdY'}
# -----------
# {'B2Mg1'}
# physrevb.63.220503
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'B2Mg1'}
# physrevb.63.220504
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'B2Mg1'}
# physrevb.63.220505
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'Ce1Rh1In5'}
# physrevb.63.220507
# ['CeInRh']
# ['CeInRh']
# {'CeInRh'}
# -----------
# {'B2Mg1'}
# physrevb.63.220508
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'U1'}
# physrevb.63.224510
# ['U']
# ['U']
# {'U'}
# -----------
# {'B2Mg1'}
# physrevb.64.012507
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'B2Mg1'}
# physrevb.64.060506
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'Ru1Sr2Eu1Cu2O8'}
# physrevb.64.064508
# ['CuEuORuSr']
# ['CuEuORuSr']
# {'CuEuORuSr'}
# -----------
# {'La2Rh3Si5'}
# physrevb.64.064514
# ['LaRhSi']
# ['LaRhSi']
# {'LaRhSi'}
# -----------
# {'B2Mg1'}
# physrevb.64.094514
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'Dy1Mo6S8'}
# physrevb.64.094520
# ['DyMoS']
# ['DyMoS']
# {'DyMoS'}
# -----------
# {'B2Mg1'}
# physrevb.64.094522
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'Lu1Ni2B2C1'}
# physrevb.64.100505
# ['BCLuNi']
# ['BCLuNi']
# {'BCLuNi'}
# -----------
# {'Mg1C1Ni3'}
# physrevb.64.132505
# ['CMgNi']
# ['CMgNi']
# {'CMgNi'}
# -----------
# {'B2Mg1'}
# physrevb.64.132509
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'La1.89Ba0.11Cu1O4'}
# physrevb.64.144524
# ['BaCuLaO']
# ['BaCuLaO']
# {'BaCuLaO'}
# -----------
# {'B2Mg1'}
# physrevb.64.172501
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'Ba8Si46'}
# physrevb.64.172504
# ['BaSi']
# ['BaSi']
# {'BaSi'}
# -----------
# {'B2Mg1'}
# physrevb.64.180501
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'La3Rh2Ge2'}
# physrevb.64.224420
# ['GeLaRh']
# ['GeLaRh']
# {'GeLaRh'}
# -----------
# {'S1'}
# physrevb.65.064504
# ['S']
# ['S']
# {'S'}
# -----------
# {'Pr1Os4Sb12'}
# physrevb.65.100506
# ['OsPrSb']
# ['OsPrSb']
# {'OsPrSb'}
# -----------
# {'B2Mg1'}
# physrevb.65.100510
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'B2Mg1'}
# physrevb.65.134508
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'B2Mg1'}
# physrevb.65.140501
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'Ce1Co1In5'}
# physrevb.65.180504
# ['CeCoIn']
# ['CeCoIn']
# {'CeCoIn'}
# -----------
# {'B2Mg1'}
# physrevb.65.180505
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'Mg0.99Al0.01B2'}
# physrevb.65.184514
# ['AlBMg']
# ['AlBMg']
# {'AlBMg'}
# -----------
# {'Mg1Cu1Ni3'}
# physrevb.65.214518
# ['CuMgNi']
# ['CuMgNi']
# {'CuMgNi'}
# -----------
# {'Ce1Rh1In5'}
# physrevb.65.224509
# ['CeInRh']
# ['CeInRh']
# {'CeInRh'}
# -----------
# {'Sr0.9La0.1Cu1O2'}
# physrevb.65.224520
# ['CuLaOSr']
# ['CuLaOSr']
# {'CuLaOSr'}
# -----------
# {'Y2Cu2I2'}
# physrevb.66.012510
# ['CuIY']
# ['CuIY']
# {'CuIY'}
# -----------
# {'Ru1Gd1.4Ce0.6Sr2Cu2O10+z'}
# physrevb.66.144503
# ['zCeCuGdORuSr']
# ['zCeCuGdORuSr']
# {'zCeCuGdORuSr'}
# -----------
# {'B2Mg1'}
# physrevb.66.180502
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'La1Os4Sb12'}
# physrevb.66.220504
# ['LaOsSb']
# ['LaOsSb']
# {'LaOsSb'}
# -----------
# {'Ce2Rh1In8'}
# physrevb.67.020506
# ['CeInRh']
# ['CeInRh']
# {'CeInRh'}
# -----------
# {'Ba0.61K0.39Bi1O3'}
# physrevb.67.024505
# ['BaBiKO']
# ['BaBiKO']
# {'BaBiKO'}
# -----------
# {'N0.72H2.16Na1K3C60'}
# physrevb.67.024519
# ['CHKNNa']
# ['CHKNNa']
# {'CHKNNa'}
# -----------
# {'Mg1C1Ni3'}
# physrevb.67.052501
# ['CMgNi']
# ['CMgNi']
# {'CMgNi'}
# -----------
# {'Ge5La1'}
# physrevb.67.094501
# ['GeLa']
# ['GeLa']
# {'GeLa'}
# -----------
# {'Mg1C1Ni3'}
# physrevb.67.094502
# ['CMgNi']
# ['CMgNi']
# {'CMgNi'}
# -----------
# {'B2Mg1'}
# physrevb.67.094504
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'Li0.48M0.3Hf1N1Cl1'}
# physrevb.67.100509
# ['ClHfLiMN']
# ['ClHfLiMN']
# {'ClHfLiMN'}
# -----------
# {'Ru0.9Sr2Y1Cu2.1O7.9'}
# physrevb.67.172502
# ['CuORuSrY']
# ['CuORuSrY']
# {'CuORuSrY'}
# -----------
# {'B0.67Mg0.33'}
# physrevb.67.172508
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'Pr1Os4Sb12'}
# physrevb.67.180508
# ['OsPrSb']
# ['OsPrSb']
# {'OsPrSb'}
# -----------
# {'Ce1Te1.82'}
# physrevb.67.212504
# ['CeTe']
# ['CeTe']
# {'CeTe'}
# -----------
# {'Mg1C0.977Ni3'}
# physrevb.68.024523
# ['CMgNi']
# ['CMgNi']
# {'CMgNi'}
# -----------
# {'Ca1Al1Si1'}
# physrevb.68.134503
# ['AlCaSi']
# ['AlCaSi']
# {'AlCaSi'}
# -----------
# {'Mg1C1Ni3'}
# physrevb.68.144510
# ['CMgNi']
# ['CMgNi']
# {'CMgNi'}
# -----------
# {'Mg1C1Ni3'}
# physrevb.68.180502
# ['CMgNi']
# ['CMgNi']
# {'CMgNi'}
# -----------
# {'Na0.31Co1D2.5O3.25'}
# physrevb.68.214517
# ['CoDNaO']
# ['CoDNaO']
# {'CoDNaO'}
# -----------
# {'Er1Ni1.96Fe0.04B2C0.99'}
# physrevb.68.214518
# ['BCErFeNi']
# ['BCErFeNi']
# {'BCErFeNi'}
# -----------
# {'Ho1Ni2B2C1'}
# physrevb.69.054505
# ['BCHoNi']
# ['BCHoNi']
# {'BCHoNi'}
# -----------
# {'Pr1Os4Sb12'}
# physrevb.69.060504
# ['OsPrSb']
# ['OsPrSb']
# {'OsPrSb'}
# -----------
# {'Ca1Al1Si1'}
# physrevb.69.100506
# ['AlCaSi']
# ['AlCaSi']
# {'AlCaSi'}
# -----------
# {'B2Mg1'}
# physrevb.69.144514
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'Pr1Ru4Sb12'}
# physrevb.69.180509
# ['PrRuSb']
# ['PrRuSb']
# {'PrRuSb'}
# -----------
# {'B12Zr1'}
# physrevb.69.212508
# ['BZr']
# ['BZr']
# {'BZr'}
# -----------
# {'Mo0.18U0.82'}
# physrevb.7.4290
# ['MoU']
# ['MoU']
# {'MoU'}
# -----------
# {'Ge2Lu1'}
# physrevb.70.052511
# ['GeLu']
# ['GeLu']
# {'GeLu'}
# -----------
# {'Li1Ti2O4'}
# physrevb.70.054519
# ['LiOTi']
# ['LiOTi']
# {'LiOTi'}
# -----------
# {'Ta2S2C2'}
# physrevb.70.064519
# ['CSTa']
# ['CSTa']
# {'CSTa'}
# -----------
# {'Mg1C1.6Ni3'}
# physrevb.70.174503
# ['CMgNi']
# ['CMgNi']
# {'CMgNi'}
# -----------
# {'Hg0.7W0.3Sr2Ce1.74Eu1.26Cu2O11+z'}
# physrevb.70.174514
# ['zCeCuEuHgOSrW']
# ['zCeCuEuHgOSrW']
# {'zCeCuEuHgOSrW'}
# -----------
# {'Mg1B1.88C0.12'}
# physrevb.71.020501
# ['BCMg']
# ['BCMg']
# {'BCMg'}
# -----------
# {'Lu2Ir3Si5'}
# physrevb.71.045109
# ['IrLuSi']
# ['IrLuSi']
# {'IrLuSi'}
# -----------
# {'C1'}
# physrevb.71.060502
# ['C']
# ['C']
# {'C'}
# -----------
# {'Cu1.3K0.2Co1.5S4'}
# physrevb.71.064505
# ['CoCuKS']
# ['CoCuKS']
# {'CoCuKS'}
# -----------
# {'La1.48Nd0.4Sr0.12Cu1O4'}
# physrevb.71.104516
# ['CuLaNdOSr']
# ['CuLaNdOSr']
# {'CuLaNdOSr'}
# -----------
# {'Te3Zr1'}
# physrevb.71.132508
# ['TeZr']
# ['TeZr']
# {'TeZr'}
# -----------
# {'Na0.1Ta1S2'}
# physrevb.72.014534
# ['NaSTa']
# ['NaSTa']
# {'NaSTa'}
# -----------
# {'Zr1N1Cl0.7'}
# physrevb.72.020501
# ['ClNZr']
# ['ClNZr']
# {'ClNZr'}
# -----------
# {'B12Zr1'}
# physrevb.72.024547
# ['BZr']
# ['BZr']
# {'BZr'}
# -----------
# {'Sr2Ca12Cu24O41'}
# physrevb.72.054520
# ['CaCuOSr']
# ['CaCuOSr']
# {'CaCuOSr'}
# -----------
# {'C3La2'}
# physrevb.72.064520
# ['CLa']
# ['CLa']
# {'CLa'}
# -----------
# {'Ba24Si100'}
# physrevb.72.144504
# ['BaSi']
# ['BaSi']
# {'BaSi'}
# -----------
# {'Ru1Sr2Gd1Cu2O8'}
# physrevb.72.174508
# ['CuGdORuSr']
# ['CuGdORuSr']
# {'CuGdORuSr'}
# -----------
# {'Pr1Ru4Sb12'}
# physrevb.72.184503
# ['PrRuSb']
# ['PrRuSb']
# {'PrRuSb'}
# -----------
# {'Zn2Zr1'}
# physrevb.72.214523
# ['ZnZr']
# ['ZnZr']
# {'ZnZr'}
# -----------
# {'B2Mg1'}
# physrevb.72.220505
# ['BMg']
# ['BMg']
# {'BMg'}
# -----------
# {'B6Y1'}
# physrevb.73.024512
# ['BY']
# ['BY']
# {'BY'}
# -----------
# {'Mo1N1'}
# physrevb.73.052504
# ['MoN']
# ['MoN']
# {'MoN'}
# -----------
# {'B12Zr1'}
# physrevb.73.094510
# ['BZr']
# ['BZr']
# {'BZr'}
# -----------
# {'Y1'}
# physrevb.73.094522
# ['Y']
# ['Y']
# {'Y'}
# -----------
# {'Y0.54Pr0.46Ba2Cu3O7-z'}
# physrevb.73.144510
# ['zBaCuOPrY']
# ['zBaCuOPrY']
# {'zBaCuOPrY'}
# -----------
# {'Li1Ti2O4'}
# physrevb.73.184521
# ['LiOTi']
# ['LiOTi']
# {'LiOTi'}
# -----------
# {'Li0.68Nb1O2'}
# physrevb.74.012504
# ['LiNbO']
# ['LiNbO']
# {'LiNbO'}
# -----------
# {'Pr1Pt2B2C1'}
# physrevb.74.134513
# ['BCPrPt']
# ['BCPrPt']
# {'BCPrPt'}
# -----------
# {'Nb2As1C1'}
# physrevb.74.174501
# ['AsCNb']
# ['AsCNb']
# {'AsCNb'}
# -----------
# {'Ba8Si40Ga6'}
# physrevb.75.054513
# ['BaGaSi']
# ['BaGaSi']
# {'BaGaSi'}
# -----------
# {'Nb2Se3'}
# physrevb.75.064517
# ['NbSe']
# ['NbSe']
# {'NbSe'}
# -----------
# {'Pb1'}
# physrevb.75.174502
# ['Pb']
# ['Pb']
# {'Pb'}
# -----------
# {'Sc1'}
# physrevb.76.012505
# ['Sc']
# ['Sc']
# {'Sc'}
# -----------
# {'Al3Mg2'}
# physrevb.76.014528
# ['AlMg']
# ['AlMg']
# {'AlMg'}
# -----------
# {'Na0.3Co1H2.6O3.3'}
# physrevb.76.100506
# ['CoHNaO']
# ['CoHNaO']
# {'CoHNaO'}
# -----------
# {'Ca24Al28O66'}
# physrevb.77.092505
# ['AlCaO']
# ['AlCaO']
# {'AlCaO'}
# -----------
# {'La1Fe1As1F0.11O0.89'}
# physrevb.77.174503
# ['AsFFeLaO']
# ['AsFFeLaO']
# {'AsFFeLaO'}
# -----------
# {'Th1Pt4Ge12'}
# physrevb.77.180504
# ['GePtTh']
# ['GePtTh']
# {'GePtTh'}
# -----------
# {'Sm1Fe1As1F0.15O0.85'}
# physrevb.77.180510
# ['AsFFeOSm']
# ['AsFFeOSm']
# {'AsFFeOSm'}
# -----------
# {'Sr0.9La0.1Cu1O2'}
# physrevb.77.184512
# ['CuLaOSr']
# ['CuLaOSr']
# {'CuLaOSr'}
# -----------
# {'Li0.9Mo6O17'}
# physrevb.77.193106
# ['LiMoO']
# ['LiMoO']
# {'LiMoO'}
# -----------
# {'La1Fe1As1F0.1O0.9'}
# physrevb.78.012507
# ['AsFFeLaO']
# ['AsFFeLaO']
# {'AsFFeLaO'}
# -----------
# {'Mo3Sb7'}
# physrevb.78.014502
# ['MoSb']
# ['MoSb']
# {'MoSb'}
# -----------
# {'Ba0.55K0.45Fe2As2'}
# physrevb.78.014507
# ['AsBaFeK']
# ['AsBaFeK']
# {'AsBaFeK'}
# -----------
# {'Bi2Pd3Se2'}
# physrevb.78.024509
# ['BiPdSe']
# ['BiPdSe']
# {'BiPdSe'}
# -----------
# {'Lu2Fe3Si5'}
# physrevb.78.024514
# ['FeLuSi']
# ['FeLuSi']
# {'FeLuSi'}
# -----------
# {'C6Ca1'}
# physrevb.78.060506
# ['CCa']
# ['CCa']
# {'CCa'}
# -----------
# {'Pr1Os4Sb12'}
# physrevb.78.064510
# ['OsPrSb']
# ['OsPrSb']
# {'OsPrSb'}
# -----------
# {'Th1Pt4Ge12'}
# physrevb.78.064516
# ['GePtTh']
# ['GePtTh']
# {'GePtTh'}
# -----------
# {'Eu0.5K0.5Fe2As2'}
# physrevb.78.092406
# ['AsEuFeK']
# ['AsEuFeK']
# {'AsEuFeK'}
# -----------
# {'La0.85Sr0.15Fe1As1O1-z'}
# physrevb.78.092503
# ['zAsFeLaOSr']
# ['zAsFeLaOSr']
# {'zAsFeLaOSr'}
# -----------
# {'Y1Ba2Cu4O8'}
# physrevb.78.100503
# ['BaCuOY']
# ['BaCuOY']
# {'BaCuOY'}
# -----------
# {'La1Fe1As1F0.1O0.9'}
# physrevb.78.100507
# ['AsFFeLaO']
# ['AsFFeLaO']
# {'AsFFeLaO'}
# -----------
# {'Ba0.55K0.45Fe2As2'}
# physrevb.78.104527
# ['AsBaFeK']
# ['AsBaFeK']
# {'AsBaFeK'}
# -----------
# {'B12Lu1'}
# physrevb.78.134504
# ['BLu']
# ['BLu']
# {'BLu'}
# -----------
# {'Nd1Fe1As1F0.18O0.82'}
# physrevb.78.134508
# ['AsFFeNdO']
# ['AsFFeNdO']
# {'AsFFeNdO'}
# -----------
# {'Sr1Ni2As2'}
# physrevb.78.172504
# ['AsNiSr']
# ['AsNiSr']
# {'AsNiSr'}
# -----------
# {'Mo3Sb7'}
# physrevb.78.172505
# ['MoSb']
# ['MoSb']
# {'MoSb'}
# -----------
# {'Nd1Fe1As1F0.3O0.7'}
# physrevb.78.174523
# ['AsFFeNdO']
# ['AsFFeNdO']
# {'AsFFeNdO'}
# -----------
# {'Sm1Fe1P1O1'}
# physrevb.78.184512
# ['FeOPSm']
# ['FeOPSm']
# {'FeOPSm'}
# -----------
# {'Ba0.55K0.45Fe2As2'}
# physrevb.78.220505
# ['AsBaFeK']
# ['AsBaFeK']
# {'AsBaFeK'}
# -----------
# {'Ba0.64K0.36Fe2As2'}
# physrevb.79.014514
# ['AsBaFeK']
# ['AsBaFeK']
# {'AsBaFeK'}
# -----------
# {'Fe1Se0.72'}
# physrevb.79.014519
# ['FeSe']
# ['FeSe']
# {'FeSe'}
# -----------
# {'Nd1Fe1As1F0.2O0.8'}
# physrevb.79.020508
# ['AsFFeNdO']
# ['AsFFeNdO']
# {'AsFFeNdO'}
# -----------
# {'Bi2Sr1.6La0.4Cu1O6+z'}
# physrevb.79.024514
# ['zBiCuLaOSr']
# ['zBiCuLaOSr']
# {'zBiCuLaOSr'}
# -----------
# {'Ba0.6K0.4Fe2As2'}
# physrevb.79.054517
# ['AsBaFeK']
# ['AsBaFeK']
# {'AsBaFeK'}
# -----------
# {'Th1Pt4Ge12'}
# physrevb.79.054520
# ['GePtTh']
# ['GePtTh']
# {'GePtTh'}
# -----------
# {'Ba0.6K0.4Fe2As2'}
# physrevb.79.094505
# ['AsBaFeK']
# ['AsBaFeK']
# {'AsBaFeK'}
# -----------
# {'Ba1Fe1.852Co0.148As2'}
# physrevb.79.094507
# ['AsBaCoFe']
# ['AsBaCoFe']
# {'AsBaCoFe'}
# -----------
# {'Ba1Ni2As2'}
# physrevb.79.094508
# ['AsBaNi']
# ['AsBaNi']
# {'AsBaNi'}
# -----------
# {'Pr0.75Sr0.25Fe1As1O1'}
# physrevb.79.104501
# ['AsFeOPrSr']
# ['AsFeOPrSr']
# {'AsFeOPrSr'}
# -----------
# {'Ba1Ni2P2'}
# physrevb.79.132506
# ['BaNiP']
# ['BaNiP']
# {'BaNiP'}
# -----------
# {'Sr1Ni2P2'}
# physrevb.79.134507
# ['NiPSr']
# ['NiPSr']
# {'NiPSr'}
# -----------
# {'B105'}
# physrevb.79.140505
# ['B']
# ['B']
# {'B'}
# -----------
# {'Fe1.03Te0.7Se0.3'}
# physrevb.79.140509
# ['FeSeTe']
# ['FeSeTe']
# {'FeSeTe'}
# -----------
# {'B3Ru7'}
# physrevb.79.144509
# ['BRu']
# ['BRu']
# {'BRu'}
# -----------
# {'Ba1Fe2As2'}
# physrevb.79.172506
# ['AsBaFe']
# ['AsBaFe']
# {'AsBaFe'}
# -----------
# {'Ce1Pt1Si2'}
# physrevb.79.172507
# ['CePtSi']
# ['CePtSi']
# {'CePtSi'}
# -----------
# {'Ba0.6K0.4Fe2As2'}
# physrevb.79.174501
# ['AsBaFeK']
# ['AsBaFeK']
# {'AsBaFeK'}
# -----------
# {'La1Fe0.96Ni0.04As1O1'}
# physrevb.79.174505
# ['AsFeLaNiO']
# ['AsFeLaNiO']
# {'AsFeLaNiO'}
# -----------
# {'Pr1Os4Sb12'}
# physrevb.79.174511
# ['OsPrSb']
# ['OsPrSb']
# {'OsPrSb'}
# -----------
# {'Sr1Pd2Ge2'}
# physrevb.79.224522
# ['GePdSr']
# ['GePdSr']
# {'GePdSr'}
# -----------
# {'Fe1Se1'}
# physrevb.80.024518
# ['FeSe']
# ['FeSe']
# {'FeSe'}
# -----------
# {'Ca1Fe2As2'}
# physrevb.80.024519
# ['AsCaFe']
# ['AsCaFe']
# {'AsCaFe'}
# -----------
# {'Sr1Fe2As2'}
# physrevb.80.052501
# ['AsFeSr']
# ['AsFeSr']
# {'AsFeSr'}
# -----------
# {'Ba1Pt1Si3'}
# physrevb.80.064504
# ['BaPtSi']
# ['BaPtSi']
# {'BaPtSi'}
# -----------
# {'Fe1Se1'}
# physrevb.80.064506
# ['FeSe']
# ['FeSe']
# {'FeSe'}
# -----------
# {'Ba1Fe1.852Co0.148As2'}
# physrevb.80.094501
# ['AsBaCoFe']
# ['AsBaCoFe']
# {'AsBaCoFe'}
# -----------
# {'Sr2Ca12Cu24O41'}
# physrevb.80.100503
# ['CaCuOSr']
# ['CaCuOSr']
# {'CaCuOSr'}
# -----------
# {'Fe1.06Te0.5Se0.5'}
# physrevb.80.134523
# ['FeSeTe']
# ['FeSeTe']
# {'FeSeTe'}
# -----------
# {'Ce1Cu2Si2'}
# physrevb.80.140513
# ['CeCuSi']
# ['CeCuSi']
# {'CeCuSi'}
# -----------
# {'Ca1Fe1.94Ni0.06As2'}
# physrevb.80.144524
# ['AsCaFeNi']
# ['AsCaFeNi']
# {'AsCaFeNi'}
# -----------
# {'U1Ru2Si2'}
# physrevb.80.172501
# ['RuSiU']
# ['RuSiU']
# {'RuSiU'}
# -----------
# {'Fe1Se0.25Te0.75'}
# physrevb.80.180507
# ['FeSeTe']
# ['FeSeTe']
# {'FeSeTe'}
# -----------
# {'La1Fe1P1O1'}
# physrevb.80.220509
# ['FeLaOP']
# ['FeLaOP']
# {'FeLaOP'}
# -----------
# {'Ho1Ni2B2C'}
# physrevb.80.224522
# ['BCHoNi']
# ['BCHoNi']
# {'BCHoNi'}
# -----------
# {'Fe1.11Te0.6Se0.4'}
# physrevb.81.020509
# ['FeSeTe']
# ['FeSeTe']
# {'FeSeTe'}
# -----------
# {'Ca1Fe1.92Co0.08As2'}
# physrevb.81.020510
# ['AsCaCoFe']
# ['AsCaCoFe']
# {'AsCaCoFe'}
# -----------
# {'Ba1Fe1.85Co0.15As2'}
# physrevb.81.060501
# ['AsBaCoFe']
# ['AsBaCoFe']
# {'AsBaCoFe'}
# -----------
# {'Ba1Fe1.8Co0.2As2'}
# physrevb.81.060509
# ['AsBaCoFe']
# ['AsBaCoFe']
# {'AsBaCoFe'}
# -----------
# {'Fe1.08Te1Ox'}
# physrevb.81.092506
# ['FeOxTe']
# ['FeOxTe']
# {'FeOxTe'}
# -----------
# {'Cu0.06Ti1Se2'}
# physrevb.81.092507
# ['CuSeTi']
# ['CuSeTi']
# {'CuSeTi'}
# -----------
# {'Ba1Fe1.73Co0.27As2'}
# physrevb.81.094520
# ['AsBaCoFe']
# ['AsBaCoFe']
# {'AsBaCoFe'}
# -----------
# {'Ba8Si46'}
# physrevb.81.104522
# ['BaSi']
# ['BaSi']
# {'BaSi'}
# -----------
# {'Ce1Ir1Ge3'}
# physrevb.81.140507
# ['CeGeIr']
# ['CeGeIr']
# {'CeGeIr'}
# -----------
# {'Eu1Pt1Si3'}
# physrevb.81.144414
# ['EuPtSi']
# ['EuPtSi']
# {'EuPtSi'}
# -----------
# {'Ce1Pt2In7'}
# physrevb.81.180507
# ['CeInPt']
# ['CeInPt']
# {'CeInPt'}
# -----------
# {'Bi1.98Sr2.06Y0.68Cu2O8+z'}
# physrevb.81.184509
# ['zBiCuOSrY']
# ['zBiCuOSrY']
# {'zBiCuOSrY'}
# -----------
# {'Fe1.14Te0.91S0.09'}
# physrevb.81.184522
# ['FeSTe']
# ['FeSTe']
# {'FeSTe'}
# -----------
# {'Fe1Se0.99'}
# physrevb.81.205119
# ['FeSe']
# ['FeSe']
# {'FeSe'}
# -----------
# {'Ba1Fe2As1.34P0.66'}
# physrevb.81.220501
# ['AsBaFeP']
# ['AsBaFeP']
# {'AsBaFeP'}
# -----------
# {'Ba1Fe2As2'}
# physrevb.81.224511
# ['AsBaFe']
# ['AsBaFe']
# {'AsBaFe'}
# -----------
# {'Nb1S2'}
# physrevb.82.014518
# ['NbS']
# ['NbS']
# {'NbS'}
# -----------
# {'Pb1.16Ti2Se5.16'}
# physrevb.82.024503
# ['PbSeTi']
# ['PbSeTi']
# {'PbSeTi'}
# -----------
# {'Al2C1Mo3'}
# physrevb.82.064511
# ['AlCMo']
# ['AlCMo']
# {'AlCMo'}
# -----------
# {'Al2C1Mo3'}
# physrevb.82.064512
# ['AlCMo']
# ['AlCMo']
# {'AlCMo'}
# -----------
# {'Ba1Fe2As1.3P0.7'}
# physrevb.82.094502
# ['AsBaFeP']
# ['AsBaFeP']
# {'AsBaFeP'}
# -----------
# {'B1I3'}
# physrevb.82.094506
# ['BI']
# ['BI']
# {'BI'}
# -----------
# {'Sn3Y1'}
# physrevb.82.094517
# ['SnY']
# ['SnY']
# {'SnY'}
# -----------
# {'Sr2V1Fe1As1O3'}
# physrevb.82.140507
# ['AsFeOSrV']
# ['AsFeOSrV']
# {'AsFeOSrV'}
# -----------
# {'Ba1Fe2As2'}
# physrevb.82.144118
# ['AsBaFe']
# ['AsBaFe']
# {'AsBaFe'}
# -----------
# {'Sr1Fe1.84Pt0.16As2'}
# physrevb.82.144518
# ['AsFePtSr']
# ['AsFePtSr']
# {'AsFePtSr'}
# -----------
# {'Rb1Fe2As2'}
# physrevb.82.144527
# ['AsFeRb']
# ['AsFeRb']
# {'AsFeRb'}
# -----------
# {'B2Os1'}
# physrevb.82.144532
# ['BOs']
# ['BOs']
# {'BOs'}
# -----------
# {'Ba1Fe1.85Co0.15As2'}
# physrevb.82.174509
# ['AsBaCoFe']
# ['AsBaCoFe']
# {'AsBaCoFe'}
# -----------
# {'Sr0.6La0.4Fe2As2'}
# physrevb.82.180512
# ['AsFeLaSr']
# ['AsFeLaSr']
# {'AsFeLaSr'}
# -----------
# {'Bi2Sr1.6La0.4Cu1O6+z'}
# physrevb.83.054509
# ['zBiCuLaOSr']
# ['zBiCuLaOSr']
# {'zBiCuLaOSr'}
# -----------
# {'Li1Fe1As1'}
# physrevb.83.060502
# ['AsFeLi']
# ['AsFeLi']
# {'AsFeLi'}
# -----------
# {'Rb0.88Fe1.81Se2'}
# physrevb.83.060512
# ['FeRbSe']
# ['FeRbSe']
# {'FeRbSe'}
# -----------
# {'Ce2Pd1In8'}
# physrevb.83.064504
# ['CeInPd']
# ['CeInPd']
# {'CeInPd'}
# -----------
# {'La1Rh1Si3'}
# physrevb.83.064522
# ['LaRhSi']
# ['LaRhSi']
# {'LaRhSi'}
# -----------
# {'Eu1Fe2As2'}
# physrevb.83.100501
# ['AsEuFe']
# ['AsEuFe']
# {'AsEuFe'}
# -----------
# {'Li1Fe1As1'}
# physrevb.83.100502
# ['AsFeLi']
# ['AsFeLi']
# {'AsFeLi'}
# -----------
# {'Eu1Fe1As1.64P0.36'}
# physrevb.83.100503
# ['AsEuFeP']
# ['AsEuFeP']
# {'AsEuFeP'}
# -----------
# {'Sm1Fe1As1F0.15O0.85'}
# physrevb.83.100513
# ['AsFFeOSm']
# ['AsFFeOSm']
# {'AsFFeOSm'}
# -----------
# {'K0.8Fe1.76Se2'}
# physrevb.83.100514
# ['FeKSe']
# ['FeKSe']
# {'FeKSe'}
# -----------
# {'K0.8Fe2Se2'}
# physrevb.83.104508
# ['FeKSe']
# ['FeKSe']
# {'FeKSe'}
# -----------
# {'La3Ni2B2N2.7'}
# physrevb.83.115131
# ['BLaNNi']
# ['BLaNNi']
# {'BLaNNi'}
# -----------
# {'Fe1Te0.57Se0.43'}
# physrevb.83.134521
# ['FeSeTe']
# ['FeSeTe']
# {'FeSeTe'}
# -----------
# {'Bi3Ni1'}
# physrevb.83.140501
# ['BiNi']
# ['BiNi']
# {'BiNi'}
# -----------
# {'Bi2Te3'}
# physrevb.83.140504
# ['BiTe']
# ['BiTe']
# {'BiTe'}
# -----------
# {'Ce1Co1In5'}
# physrevb.83.144510
# ['CeCoIn']
# ['CeCoIn']
# {'CeCoIn'}
# -----------
# {'K0.8Fe2Se2'}
# physrevb.83.144511
# ['FeKSe']
# ['FeKSe']
# {'FeKSe'}
# -----------
# {'Nb0.18Re0.82'}
# physrevb.83.144525
# ['NbRe']
# ['NbRe']
# {'NbRe'}
# -----------
# {'K0.65Fe1.41Se2'}
# physrevb.83.174503
# ['FeKSe']
# ['FeKSe']
# {'FeKSe'}
# -----------
# {'Li1Fe1As1'}
# physrevb.83.174506
# ['AsFeLi']
# ['AsFeLi']
# {'AsFeLi'}
# -----------
# {'Tl0.47Rb0.34Fe1.63Se2'}
# physrevb.83.174510
# ['FeRbSeTl']
# ['FeRbSeTl']
# {'FeRbSeTl'}
# -----------
# {'La1Sb2'}
# physrevb.83.174520
# ['LaSb']
# ['LaSb']
# {'LaSb'}
# -----------
# {'Eu1Fe2As2'}
# physrevb.83.214513
# ['AsEuFe']
# ['AsEuFe']
# {'AsEuFe'}
# -----------
# {'Ca1'}
# physrevb.83.220512
# ['Ca']
# ['Ca']
# {'Ca'}
# -----------
# {'Li1Fe1As1'}
# physrevb.83.224512
# ['AsFeLi']
# ['AsFeLi']
# {'AsFeLi'}
# -----------
# {'Eu1Fe2As2'}
# physrevb.84.024502
# ['AsEuFe']
# ['AsEuFe']
# {'AsEuFe'}
# -----------
# {'Ba1Fe1.922Rh0.078As2'}
# physrevb.84.024509
# ['AsBaFeRh']
# ['AsBaFeRh']
# {'AsBaFeRh'}
# -----------
# {'Li1Fe1As1'}
# physrevb.84.054507
# ['AsFeLi']
# ['AsFeLi']
# {'AsFeLi'}
# -----------
# {'Nb1S2'}
# physrevb.84.054531
# ['NbS']
# ['NbS']
# {'NbS'}
# -----------
# {'Lu2Fe3Si5'}
# physrevb.84.054541
# ['FeLuSi']
# ['FeLuSi']
# {'FeLuSi'}
# -----------
# {'Bi1Pd1'}
# physrevb.84.064518
# ['BiPd']
# ['BiPd']
# {'BiPd'}
# -----------
# {'Ba0.65Na0.35Fe2As2'}
# physrevb.84.064525
# ['AsBaFeNa']
# ['AsBaFeNa']
# {'AsBaFeNa'}
# -----------
# {'Li1Fe1As1'}
# physrevb.84.104502
# ['AsFeLi']
# ['AsFeLi']
# {'AsFeLi'}
# -----------
# {'Ce2Pd1In8'}
# physrevb.84.140507
# ['CeInPd']
# ['CeInPd']
# {'CeInPd'}
# -----------
# {'Fe1Se0.42Te0.58'}
# physrevb.84.174502
# ['FeSeTe']
# ['FeSeTe']
# {'FeSeTe'}
# -----------
# {'La1Ru3Si2'}
# physrevb.84.214527
# ['LaRuSi']
# ['LaRuSi']
# {'LaRuSi'}
# -----------
# {'Y1Pt1Bi1'}
# physrevb.84.220504
# ['BiPtY']
# ['BiPtY']
# {'BiPtY'}
# -----------
# {'Sr1Pd2Ge2'}
# physrevb.85.014520
# ['GePdSr']
# ['GePdSr']
# {'GePdSr'}
# -----------
# {'U1Co1Ge1'}
# physrevb.85.024526
# ['CoGeU']
# ['CoGeU']
# {'CoGeU'}
# -----------
# {'Sr1Ni2Ge2'}
# physrevb.85.024538
# ['GeNiSr']
# ['GeNiSr']
# {'GeNiSr'}
# -----------
# {'K0.8Fe1.7S1Se1'}
# physrevb.85.054507
# ['FeKSSe']
# ['FeKSSe']
# {'FeKSSe'}
# -----------
# {'La1Ni2P2'}
# physrevb.85.054517
# ['LaNiP']
# ['LaNiP']
# {'LaNiP'}
# -----------
# {'Fe1.08Te0.55Se0.45Ox'}
# physrevb.85.064504
# ['FeOxSeTe']
# ['FeOxSeTe']
# {'FeOxSeTe'}
# -----------
# {'Tl0.58Rb0.42Fe1.72Se2'}
# physrevb.85.064513
# ['FeRbSeTl']
# ['FeRbSeTl']
# {'FeRbSeTl'}
# -----------
# {'Ca10Pt3.97Fe9.03As18'}
# physrevb.85.180504
# ['AsCaFePt']
# ['AsCaFePt']
# {'AsCaFePt'}
# -----------
# {'Li1Fe1As1'}
# physrevb.85.180505
# ['AsFeLi']
# ['AsFeLi']
# {'AsFeLi'}
# -----------
# {'Ca0.67Sr0.33Fe2As2'}
# physrevb.85.184501
# ['AsCaFeSr']
# ['AsCaFeSr']
# {'AsCaFeSr'}
# -----------
# {'Te3Zr1'}
# physrevb.85.184513
# ['TeZr']
# ['TeZr']
# {'TeZr'}
# -----------
# {'Ce1Cu2Si2'}
# physrevb.85.205105
# ['CeCuSi']
# ['CeCuSi']
# {'CeCuSi'}
# -----------
# {'Yb1Sb2'}
# physrevb.85.214526
# ['SbYb']
# ['SbYb']
# {'SbYb'}
# -----------
# {'Ba0.55K0.45Fe1.95Co0.05As2'}
# physrevb.85.224504
# ['AsBaCoFeK']
# ['AsBaCoFeK']
# {'AsBaCoFeK'}
# -----------
# {'Ce1Fe1As0.7P0.3O1'}
# physrevb.86.020501
# ['AsCeFeOP']
# ['AsCeFeOP']
# {'AsCeFeOP'}
# -----------
# {'Rh3Bi14'}
# physrevb.86.054502
# ['BiRh']
# ['BiRh']
# {'BiRh'}
# -----------
# {'Ca3Ir4Sn13'}
# physrevb.86.064504
# ['CaIrSn']
# ['CaIrSn']
# {'CaIrSn'}
# -----------
# {'Li1Fe1As1'}
# physrevb.86.064516
# ['AsFeLi']
# ['AsFeLi']
# {'AsFeLi'}
# -----------
# {'Sr1Fe2As1.4P0.6'}
# physrevb.86.144525
# ['AsFePSr']
# ['AsFePSr']
# {'AsFePSr'}
# -----------
# {'Fe1Te0.6Se0.4'}
# physrevb.86.220509
# ['FeSeTe']
# ['FeSeTe']
# {'FeSeTe'}
# -----------
# {'Bi4S3O4'}
# physrevb.86.220510
# ['BiOS']
# ['BiOS']
# {'BiOS'}
# -----------
# {'K1Fe2As2'}
# physrevb.86.224514
# ['AsFeK']
# ['AsFeK']
# {'AsFeK'}
# -----------
# {'Sr0.5La0.5F1Bi1S2'}
# physrevb.87.020504
# ['BiFLaSSr']
# ['BiFLaSSr']
# {'BiFLaSSr'}
# -----------
# {'Te3Zr1'}
# physrevb.87.024508
# ['TeZr']
# ['TeZr']
# {'TeZr'}
# -----------
# {'K1Ni2S2'}
# physrevb.87.045124
# ['KNiS']
# ['KNiS']
# {'KNiS'}
# -----------
# {'Li1Fe1P1'}
# physrevb.87.054504
# ['FeLiP']
# ['FeLiP']
# {'FeLiP'}
# -----------
# {'Ba1Ti2Sb2O1'}
# physrevb.87.060510
# ['BaOSbTi']
# ['BaOSbTi']
# {'BaOSbTi'}
# -----------
# {'Pr1Pt4Ge12'}
# physrevb.87.064502
# ['GePrPt']
# ['GePrPt']
# {'GePrPt'}
# -----------
# {'Sr1Pd2Ge2'}
# physrevb.87.094515
# ['GePdSr']
# ['GePdSr']
# {'GePdSr'}
# -----------
# {'Mo3Sb7'}
# physrevb.87.104515
# ['MoSb']
# ['MoSb']
# {'MoSb'}
# -----------
# {'Fe1Se1'}
# physrevb.87.134512
# ['FeSe']
# ['FeSe']
# {'FeSe'}
# -----------
# {'K1Fe2As2'}
# physrevb.87.134513
# ['AsFeK']
# ['AsFeK']
# {'AsFeK'}
# -----------
# {'Sn0.6In0.4Te1'}
# physrevb.87.140507
# ['InSnTe']
# ['InSnTe']
# {'InSnTe'}
# -----------
# {'Cs1Fe2As2'}
# physrevb.87.144502
# ['AsCsFe']
# ['AsCsFe']
# {'AsCsFe'}
# -----------
# {'Ir3Te8'}
# physrevb.87.174510
# ['IrTe']
# ['IrTe']
# {'IrTe'}
# -----------
# {'Pr4Fe2As2Te0.88O4'}
# physrevb.87.180508
# ['AsFeOPrTe']
# ['AsFeOPrTe']
# {'AsFeOPrTe'}
# -----------
# {'Lu1Pt1Bi1'}
# physrevb.87.184504
# ['BiLuPt']
# ['BiLuPt']
# {'BiLuPt'}
# -----------
# {'La1Sb2'}
# physrevb.87.214504
# ['LaSb']
# ['LaSb']
# {'LaSb'}
# -----------
# {'Cs1Fe2As2'}
# physrevb.87.214509
# ['AsCsFe']
# ['AsCsFe']
# {'AsCsFe'}
# -----------
# {'Sr1Pt2As2'}
# physrevb.87.224507
# ['AsPtSr']
# ['AsPtSr']
# {'AsPtSr'}
# -----------
# {'K1Fe2As2'}
# physrevb.88.014517
# ['AsFeK']
# ['AsFeK']
# {'AsFeK'}
# -----------
# {'La3Pd4Si4'}
# physrevb.88.024423
# ['LaPdSi']
# ['LaPdSi']
# {'LaPdSi'}
# -----------
# {'Ba0.75Na0.25Ti2Sb2O1'}
# physrevb.88.140501
# ['BaNaOSbTi']
# ['BaNaOSbTi']
# {'BaNaOSbTi'}
# -----------
# {'La1Pd0.85Bi2'}
# physrevb.88.144511
# ['BiLaPd']
# ['BiLaPd']
# {'BiLaPd'}
# -----------
# {'La0.5Bi1S2F0.5O0.5'}
# physrevb.88.180509
# ['BiFLaOS']
# ['BiFLaOS']
# {'BiFLaOS'}
# -----------
# {'Bi3Ni1'}
# physrevb.88.184508
# ['BiNi']
# ['BiNi']
# {'BiNi'}
# -----------
# {'Eu1Fe2As2'}
# physrevb.88.224510
# ['AsEuFe']
# ['AsEuFe']
# {'AsEuFe'}
# -----------
# {'Bi4S3O4'}
# physrevb.88.224515
# ['BiOS']
# ['BiOS']
# {'BiOS'}
# -----------
# {'Pb1Ta1Se2'}
# physrevb.89.020505
# ['PbSeTa']
# ['PbSeTa']
# {'PbSeTa'}
# -----------
# {'Li1Fe3Se2O2'}
# physrevb.89.020507
# ['FeLiOSe']
# ['FeLiOSe']
# {'FeLiOSe'}
# -----------
# {'Sm4Fe2As2Te0.72F1.2O2.8'}
# physrevb.89.024518
# ['AsFFeOSmTe']
# ['AsFFeOSmTe']
# {'AsFFeOSmTe'}
# -----------
# {'Ca10Bi9.88'}
# physrevb.89.054512
# ['BiCa']
# ['BiCa']
# {'BiCa'}
# -----------
# {'Sr3Ir4Sn13'}
# physrevb.89.094520
# ['IrSnSr']
# ['IrSnSr']
# {'IrSnSr'}
# -----------
# {'Ir0.95Pd0.05Te2'}
# physrevb.89.100501
# ['IrPdTe']
# ['IrPdTe']
# {'IrPdTe'}
# -----------
# {'Sr1Pt1As1'}
# physrevb.89.140504
# ['AsPtSr']
# ['AsPtSr']
# {'AsPtSr'}
# -----------
# {'La1F0.5Bi1S2O0.5'}
# physrevb.89.174515
# ['BiFLaOS']
# ['BiFLaOS']
# {'BiFLaOS'}
# -----------
# {'Ca10Pt0.78Fe9.22As18'}
# physrevb.89.205136
# ['AsCaFePt']
# ['AsCaFePt']
# {'AsCaFePt'}
# -----------
# {'Ca3Ir4Ge4'}
# physrevb.89.224504
# ['CaGeIr']
# ['CaGeIr']
# {'CaGeIr'}
# -----------
# {'La1Ir1Si3'}
# physrevb.90.014513
# ['IrLaSi']
# ['IrLaSi']
# {'IrLaSi'}
# -----------
# {'K0.5Na0.24Fe1.52Se2'}
# physrevb.90.020502
# ['FeKNaSe']
# ['FeKNaSe']
# {'FeKNaSe'}
# -----------
# {'Sr3Ir4Sn13'}
# physrevb.90.035115
# ['IrSnSr']
# ['IrSnSr']
# {'IrSnSr'}
# -----------
# {'Eu1Bi1S2F1'}
# physrevb.90.064518
# ['BiEuFS']
# ['BiEuFS']
# {'BiEuFS'}
# -----------
# {'Ba2Ti2Fe2As4O1'}
# physrevb.90.144508
# ['AsBaFeOTi']
# ['AsBaFeOTi']
# {'AsBaFeOTi'}
# -----------
# {'C1.36Pb5Bi12Se23'}
# physrevb.90.220504
# ['BiCPbSe']
# ['BiCPbSe']
# {'BiCPbSe'}
# -----------
# {'La1Ni1C2'}
# physrevb.90.220508
# ['CLaNi']
# ['CLaNi']
# {'CLaNi'}
# -----------
# {'Eu3Bi2S4F4'}
# physrevb.90.220510
# ['BiEuFS']
# ['BiEuFS']
# {'BiEuFS'}
# -----------
# {'Ce1Bi1S2F0.7O0.3'}
# physrevb.90.224410
# ['BiCeFOS']
# ['BiCeFOS']
# {'BiCeFOS'}
# -----------
# {'Ca10Ir4Fe10As18'}
# physrevb.90.224513
# ['AsCaFeIr']
# ['AsCaFeIr']
# {'AsCaFeIr'}
# -----------
# {'Ba1Pt2Sb2'}
# physrevb.91.014513
# ['BaPtSb']
# ['BaPtSb']
# {'BaPtSb'}
# -----------
# {'K2Cr3As3'}
# physrevb.91.020507
# ['AsCrK']
# ['AsCrK']
# {'AsCrK'}
# -----------
# {'Pd2Hf1Al1'}
# physrevb.91.024509
# ['AlHfPd']
# ['AlHfPd']
# {'AlHfPd'}
# -----------
# {'K1Fe2As2'}
# physrevb.91.060508
# ['AsFeK']
# ['AsFeK']
# {'AsFeK'}
# -----------
# {'Sr1Pt2As2'}
# physrevb.91.060510
# ['AsPtSr']
# ['AsPtSr']
# {'AsPtSr'}
# -----------
# {'La1Fe1As1H0.44O0.56'}
# physrevb.91.064509
# ['AsFeHLaO']
# ['AsFeHLaO']
# {'AsFeHLaO'}
# -----------
# {'Eu1Fe1.72Ir0.28As2'}
# physrevb.91.094427
# ['AsEuFeIr']
# ['AsEuFeIr']
# {'AsEuFeIr'}
# -----------
# {'Nb2Pd1S5'}
# physrevb.91.100504
# ['NbPdS']
# ['NbPdS']
# {'NbPdS'}
# -----------
# {'Ta4Pd3Te16'}
# physrevb.91.104506
# ['PdTaTe']
# ['PdTaTe']
# {'PdTaTe'}
# -----------
# {'Bi3S3O2'}
# physrevb.91.104511
# ['BiOS']
# ['BiOS']
# {'BiOS'}
# -----------
# {'Li0.8Fe1.2H1Se1'}
# physrevb.91.125107
# ['FeHLiSe']
# ['FeHLiSe']
# {'FeHLiSe'}
# -----------
# {'Nb0.18Re0.82'}
# physrevb.91.134508
# ['NbRe']
# ['NbRe']
# {'NbRe'}
# -----------
# {'Bi2Rh3.5S2'}
# physrevb.91.174513
# ['BiRhS']
# ['BiRhS']
# {'BiRhS'}
# -----------
# {'Au2Pb1'}
# physrevb.91.214517
# ['AuPb']
# ['AuPb']
# {'AuPb'}
# -----------
# {'K2Cr3As3'}
# physrevb.91.220505
# ['AsCrK']
# ['AsCrK']
# {'AsCrK'}
# -----------
# {'Sr0.1Bi2Se3'}
# physrevb.92.020506
# ['BiSeSr']
# ['BiSeSr']
# {'BiSeSr'}
# -----------
# {'Th1Pt3B1'}
# physrevb.92.024511
# ['BPtTh']
# ['BPtTh']
# {'BPtTh'}
# -----------
# {'Sr0.3M1Fe2Se2'}
# physrevb.92.134517
# ['FeMSeSr']
# ['FeMSeSr']
# {'FeMSeSr'}
# -----------
# {'Ce3Pt1In11'}
# physrevb.92.161114
# ['CeInPt']
# ['CeInPt']
# {'CeInPt'}
# -----------
# {'Li1Fe1As1'}
# physrevb.93.054508
# ['AsFeLi']
# ['AsFeLi']
# {'AsFeLi'}
# -----------
# {'Pb1Ta1Se2'}
# physrevb.93.054520
# ['PbSeTa']
# ['PbSeTa']
# {'PbSeTa'}
# -----------
# {'Pb1Ta1Se2'}
# physrevb.93.060506
# ['PbSeTa']
# ['PbSeTa']
# {'PbSeTa'}
# -----------
# {'Sr1Pt1As1'}
# physrevb.93.064504
# ['AsPtSr']
# ['AsPtSr']
# {'AsPtSr'}
# -----------
# {'Bi2Te1'}
# physrevb.93.094511
# ['BiTe']
# ['BiTe']
# {'BiTe'}
# -----------
# {'M0.37Cs0.268Fe1Se1'}
# physrevb.93.104508
# ['CsFeMSe']
# ['CsFeMSe']
# {'CsFeMSe'}
# -----------
# {'Ba0.85K0.15Fe2As2'}
# physrevb.93.104516
# ['AsBaFeK']
# ['AsBaFeK']
# {'AsBaFeK'}
# -----------
# {'Ba1Fe2As1.34P0.66'}
# physrevb.93.115119
# ['AsBaFeP']
# ['AsBaFeP']
# {'AsBaFeP'}
# -----------
# {'Bi2Pd1'}
# physrevb.93.144502
# ['BiPd']
# ['BiPd']
# {'BiPd'}
# -----------
# {'Rb1Eu1Fe4As4'}
# physrevb.93.214503
# ['AsEuFeRb']
# ['AsEuFeRb']
# {'AsEuFeRb'}
# -----------
# {'Bi2Pd1'}
# physrevb.93.220504
# ['BiPd']
# ['BiPd']
# {'BiPd'}
# -----------
# {'Li1.84H1Fe1.14Se1O1'}
# physrevb.93.224512
# ['FeHLiOSe']
# ['FeHLiOSe']
# {'FeHLiOSe'}
# -----------
# {'Cs1Fe2As2'}
# physrevb.93.224516
# ['AsCsFe']
# ['AsCsFe']
# {'AsCsFe'}
# -----------
# {'La3Co4Sn13'}
# physrevb.93.241112
# ['CoLaSn']
# ['CoLaSn']
# {'CoLaSn'}
# -----------
# {'Hf1Re6'}
# physrevb.94.024518
# ['HfRe']
# ['HfRe']
# {'HfRe'}
# -----------
# {'Y1Pt1Bi1'}
# physrevb.94.035130
# ['BiPtY']
# ['BiPtY']
# {'BiPtY'}
# -----------
# {'Ce1Cu2Si2'}
# physrevb.94.054514
# ['CeCuSi']
# ['CeCuSi']
# {'CeCuSi'}
# -----------
# {'Hf1Re6'}
# physrevb.94.054515
# ['HfRe']
# ['HfRe']
# {'HfRe'}
# -----------
# {'Hf1Te5'}
# physrevb.94.054517
# ['HfTe']
# ['HfTe']
# {'HfTe'}
# -----------
# {'La1Pt4Ge12'}
# physrevb.94.054523
# ['GeLaPt']
# ['GeLaPt']
# {'GeLaPt'}
# -----------
# {'Ca1K1Fe4As4'}
# physrevb.94.064501
# ['AsCaFeK']
# ['AsCaFeK']
# {'AsCaFeK'}
# -----------
# {'Ba8Si46'}
# physrevb.94.104507
# ['BaSi']
# ['BaSi']
# {'BaSi'}
# -----------
# {'Re6Zr1'}
# physrevb.94.144515
# ['ReZr']
# ['ReZr']
# {'ReZr'}
# -----------
# {'Y1Sr2Mo0.25Cu2.75O7.54'}
# physrevb.94.180509
# ['CuMoOSrY']
# ['CuMoOSrY']
# {'CuMoOSrY'}
# -----------
# {'K2Cr3As3'}
# physrevb.95.014502
# ['AsCrK']
# ['AsCrK']
# {'AsCrK'}
# -----------
# {'Bi1'}
# physrevb.95.024510
# ['Bi']
# ['Bi']
# {'Bi'}
# -----------
# {'Ir1Te2'}
# physrevb.95.035148
# ['IrTe']
# ['IrTe']
# {'IrTe'}
# -----------
# {'Ba1Fe1.915Ni0.085As2'}
# physrevb.95.060505
# ['AsBaFeNi']
# ['AsBaFeNi']
# {'AsBaFeNi'}
# -----------
# {'Ge1Sb2Te4'}
# physrevb.95.064514
# ['GeSbTe']
# ['GeSbTe']
# {'GeSbTe'}
# -----------
# {'Ca8.5La1.5Pt3Fe10As18'}
# physrevb.95.094510
# ['AsCaFeLaPt']
# ['AsCaFeLaPt']
# {'AsCaFeLaPt'}
# -----------
# {'Ca1K1Fe4As4'}
# physrevb.95.140505
# ['AsCaFeK']
# ['AsCaFeK']
# {'AsCaFeK'}
# -----------
# {'Ta1Ir2Ge2'}
# physrevb.95.174521
# ['GeIrTa']
# ['GeIrTa']
# {'GeIrTa'}
# -----------
# {'Pd1Se2'}
# physrevb.96.060509
# ['PdSe']
# ['PdSe']
# {'PdSe'}
# -----------
# {'Li0.36M1Fe2Se2'}
# physrevb.96.064512
# ['FeLiMSe']
# ['FeLiMSe']
# {'FeLiMSe'}
# -----------
# {'Re6Zr1'}
# physrevb.96.064521
# ['ReZr']
# ['ReZr']
# {'ReZr'}
# -----------
# {'Pb1Ta1Se2'}
# physrevb.96.064528
# ['PbSeTa']
# ['PbSeTa']
# {'PbSeTa'}
# -----------
# {'Ba1Fe1.864Rh0.136As2'}
# physrevb.96.094523
# ['AsBaFeRh']
# ['AsBaFeRh']
# {'AsBaFeRh'}
# -----------
# {'Ca1K1Fe4As4'}
# physrevb.96.140501
# ['AsCaFeK']
# ['AsCaFeK']
# {'AsCaFeK'}
# -----------
# {'Th1As1Fe1N1'}
# physrevb.96.144502
# ['AsFeNTh']
# ['AsFeNTh']
# {'AsFeNTh'}
# -----------
# {'Se1Sn1'}
# physrevb.96.165123
# ['SeSn']
# ['SeSn']
# {'SeSn'}
# -----------
# {'Sm0.04La0.96Ni1C2'}
# physrevb.96.224433
# ['CLaNiSm']
# ['CLaNiSm']
# {'CLaNiSm'}
# -----------
# {'Au1Be1'}
# physrevb.97.014501
# ['AuBe']
# ['AuBe']
# {'AuBe'}
# -----------
# {'Tl1Ni2Se2'}
# physrevb.97.014514
# ['NiSeTl']
# ['NiSeTl']
# {'NiSeTl'}
# -----------
# {'Pd1Te2'}
# physrevb.97.014523
# ['PdTe']
# ['PdTe']
# {'PdTe'}
# -----------
# {'Re24Ti5'}
# physrevb.97.020502
# ['ReTi']
# ['ReTi']
# {'ReTi'}
# -----------
# {'Li0.36M1Fe2As2'}
# physrevb.97.020508
# ['AsFeLiM']
# ['AsFeLiM']
# {'AsFeLiM'}
# -----------
# {'Sr1Au1Si3'}
# physrevb.97.024501
# ['AuSiSr']
# ['AuSiSr']
# {'AuSiSr'}
# -----------
# {'B2Ru1'}
# physrevb.97.054506
# ['BRu']
# ['BRu']
# {'BRu'}
# -----------
# {'Pd1Te2'}
# physrevb.97.054515
# ['PdTe']
# ['PdTe']
# {'PdTe'}
# -----------
# {'Cs1Ca2Fe4As4F2'}
# physrevb.97.060506
# ['AsCaCsFFe']
# ['AsCaCsFFe']
# {'AsCaCsFFe'}
# -----------
# {'K1Ca2Fe4As4F2'}
# physrevb.97.060509
# ['AsCaFFeK']
# ['AsCaFFeK']
# {'AsCaFFeK'}
# -----------
# {'Ce1Rh1Ge3'}
# physrevb.97.064514
# ['CeGeRh']
# ['CeGeRh']
# {'CeGeRh'}
# -----------
# {'La1Fe1Si1H1'}
# physrevb.97.100504
# ['FeHLaSi']
# ['FeHLaSi']
# {'FeHLaSi'}
# -----------
# {'La1Bi1S2F0.5O0.5'}
# physrevb.97.104509
# ['BiFLaOS']
# ['BiFLaOS']
# {'BiFLaOS'}
# -----------
# {'Ba1Pd2As2'}
# physrevb.97.134508
# ['AsBaPd']
# ['AsBaPd']
# {'AsBaPd'}
# -----------
# {'Re6Zr1'}
# physrevb.97.224506
# ['ReZr']
# ['ReZr']
# {'ReZr'}
# -----------
# {'Tb1Pd1Bi1'}
# physrevb.97.224511
# ['BiPdTb']
# ['BiPdTb']
# {'BiPdTb'}
# -----------
# {'Ta1Rh2B2'}
# physrevb.98.014502
# ['BRhTa']
# ['BRhTa']
# {'BRhTa'}
# -----------
# {'Na1Sn2As2'}
# physrevb.98.020503
# ['AsNaSn']
# ['AsNaSn']
# {'AsNaSn'}
# -----------
# {'As1Cr1'}
# physrevb.98.024520
# ['AsCr']
# ['AsCr']
# {'AsCr'}
# -----------
# {'Nd1Fe1As1F0.1O0.9'}
# physrevb.98.094504
# ['AsFFeNdO']
# ['AsFFeNdO']
# {'AsFFeNdO'}
# -----------
# {'Ir0.8Rh0.2Te2'}
# physrevb.98.094519
# ['IrRhTe']
# ['IrRhTe']
# {'IrRhTe'}
# -----------
# {'Rb1Eu1Fe4As4'}
# physrevb.98.104503
# ['AsEuFeRb']
# ['AsEuFeRb']
# {'AsEuFeRb'}
# -----------
# {'Re3Ta1'}
# physrevb.98.104506
# ['ReTa']
# ['ReTa']
# {'ReTa'}
# -----------
# {'Cr0.8Ru0.2'}
# physrevb.98.134512
# ['CrRu']
# ['CrRu']
# {'CrRu'}
# -----------
# {'La1Pt1Ge1'}
# physrevb.98.214505
# ['GeLaPt']
# ['GeLaPt']
# {'GeLaPt'}
# -----------
# {'Ba1Fe1.9Pt0.1As2'}
# physrevb.98.224505
# ['AsBaFePt']
# ['AsBaFePt']
# {'AsBaFePt'}
# -----------
# {'Ga41Mo1'}
# physrevb.99.054503
# ['GaMo']
# ['GaMo']
# {'GaMo'}
# -----------
# {'Ce1Ni1C2'}
# physrevb.99.100501
# ['CCeNi']
# ['CCeNi']
# {'CCeNi'}
# -----------
# {'Au1Be1'}
# physrevb.99.134509
# ['AuBe']
# ['AuBe']
# {'AuBe'}
# -----------
# {'H1Pt1'}
# physrevb.99.144511
# ['HPt']
# ['HPt']
# {'HPt'}
# -----------
# {'Al6Re1'}
# physrevb.99.144519
# ['AlRe']
# ['AlRe']
# {'AlRe'}
# -----------
# {'Zr1Ir1Si1'}
# physrevb.99.174513
# ['IrSiZr']
# ['IrSiZr']
# {'IrSiZr'}
# -----------
# {'P1W1'}
# physrevb.99.184509
# ['PW']
# ['PW']
# {'PW'}
# -----------
# {'Mo3P1'}
# physrevb.99.184513
# ['MoP']
# ['MoP']
# {'MoP'}
# -----------

# %%
correct_num_materials / len(processed_database_output)
# Out:
# 1.0

# %%
correct_num_materials = 0
for key in processed_database_output.keys():
    dbase_output = processed_database_output[key][1][0]
    model_output = processed_model_output[key][1][0]
   
    if abs(dbase_output - model_output) < 0.01: correct_num_materials += 1
    else: print(key, dbase_output, model_output, sep='\t')
# Out:
# physrevb.100.014507	2.0	8.0
# physrevb.100.041109	2.1	2.0
# physrevb.100.060103	3.61	4.0
# physrevb.100.134503	5.51	5.8
# physrevb.23.2219	3.9	1.2
# physrevb.26.6315	1.42	1.7
# physrevb.30.1182	0.7	2.0
# physrevb.30.1583	0.52	0.54
# physrevb.30.444	1.25	1.0
# physrevb.31.1654	0.48	17.6
# physrevb.32.135	2.36	2.46
# physrevb.34.4590	3.77	79.0
# physrevb.34.4920	8.2	0.7
# physrevb.36.3906	35.7	39.0
# physrevb.36.3910	75.0	34.0
# physrevb.36.4018	42.0	31.0
# physrevb.36.8791	86.0	0.87
# physrevb.39.11445	35.0	37.0
# physrevb.39.7339	26.0	30.0
# physrevb.41.9551	83.0	30.0
# physrevb.48.16869	74.0	120.0
# physrevb.49.12322	138.0	133.0
# physrevb.49.13184	87.0	110.0
# physrevb.49.1495	109.0	110.3
# physrevb.49.15959	82.4	3.0
# physrevb.49.3502	28.5	32.0
# physrevb.49.6392	17.2	16.0
# physrevb.49.9073	95.0	38.0
# physrevb.50.15875	36.7	36.0
# physrevb.50.16125	91.0	91.5
# physrevb.50.351	16.5	14.6
# physrevb.50.426	92.8	15.1
# physrevb.50.496	5.3	7.5
# physrevb.50.6523	1.26	1.23
# physrevb.51.1286	35.0	222.0
# physrevb.51.3316	92.0	92.5
# physrevb.52.10569	93.5	92.0
# physrevb.52.1181	7.8	5.2
# physrevb.52.15534	8.0	2.0
# physrevb.52.3071	18.2	24.0
# physrevb.52.r3844	6.4	6.2
# physrevb.53.12299	11.2	11.0
# physrevb.53.12389	3.13	1.15
# physrevb.53.8238	5.0	520.0
# physrevb.53.8241	0.26	0.35
# physrevb.54.r6885	79.8	79.5
# physrevb.55.8529	89.9	115.0
# physrevb.55.r6145	22.5	21.0
# physrevb.56.5631	37.0	32.0
# physrevb.56.7890	0.9	1.0
# physrevb.57.613	10.0	13.0
# physrevb.58.r603	0.553	-100.0
# physrevb.59.11179	78.0	79.0
# physrevb.59.11563	95.56	95.65
# physrevb.59.13639	87.2	89.0
# physrevb.59.3827	43.0	43.7
# physrevb.59.7266	3.9	83.0
# physrevb.60.7512	37.0	0.46
# physrevb.61.1500	72.0	75.0
# physrevb.61.1584	87.2	74.0
# physrevb.63.134519	16.2	16.0
# physrevb.63.144519	0.752	0.8
# physrevb.63.220503	39.5	39.2
# physrevb.63.220505	38.2	40.0
# physrevb.64.012507	38.5	39.0
# physrevb.64.064508	12.0	32.0
# physrevb.64.094514	37.5	39.0
# physrevb.64.094522	39.0	40.0
# physrevb.64.100505	14.2	15.0
# physrevb.64.132509	39.6	39.0
# physrevb.64.144524	17.8	10.2
# physrevb.64.172501	38.0	40.0
# physrevb.65.064504	17.4	10.0
# physrevb.65.134508	39.2	39.0
# physrevb.65.180505	36.6	40.0
# physrevb.65.184514	37.9	39.0
# physrevb.65.224509	2.12	2.0
# physrevb.66.012510	10.1	10.0
# physrevb.66.144503	36.0	42.0
# physrevb.66.180502	38.0	39.0
# physrevb.66.220504	0.74	3.0
# physrevb.67.024505	31.5	2.0
# physrevb.67.052501	6.4	7.0
# physrevb.67.094502	7.63	7.6
# physrevb.67.094504	39.2	39.0
# physrevb.67.172508	6.1	4.4
# physrevb.69.054505	8.04	5.5
# physrevb.69.144514	37.9	39.0
# physrevb.7.4290	2.115	15.6
# physrevb.70.174503	6.9	8.0
# physrevb.70.174514	34.0	33.0
# physrevb.71.045109	3.3	3.5
# physrevb.71.060502	4.5	4.0
# physrevb.71.064505	4.54	4.4
# physrevb.71.104516	10.0	41.0
# physrevb.71.132508	2.1	2.0
# physrevb.72.014534	4.83	4.4
# physrevb.72.024547	5.97	6.0
# physrevb.72.054520	5.18	5.0
# physrevb.72.064520	13.5	13.0
# physrevb.72.174508	56.0	30.0
# physrevb.73.024512	7.15	7.2
# physrevb.73.094522	17.0	3.0
# physrevb.73.184521	12.3	12.0
# physrevb.74.012504	5.5	5.0
# physrevb.75.064517	2.4	2.0
# physrevb.75.174502	7.186	7.0
# physrevb.77.180504	4.8	4.62
# physrevb.77.180510	40.0	3.7
# physrevb.77.184512	43.0	1.6
# physrevb.78.014507	29.5	30.0
# physrevb.78.060506	11.6	3.0
# physrevb.78.064510	1.87	1.55
# physrevb.78.064516	4.8	4.75
# physrevb.78.100503	81.6	108.0
# physrevb.78.100507	22.8	55.0
# physrevb.78.104527	30.2	38.0
# physrevb.78.134504	0.42	0.44
# physrevb.78.172504	0.66	0.62
# physrevb.78.172505	2.2	2.0
# physrevb.78.174523	46.0	47.0
# physrevb.79.020508	32.6	35.0
# physrevb.79.094508	1.5	0.69
# physrevb.79.134507	1.415	1.4
# physrevb.79.140509	12.4	65.0
# physrevb.79.224522	3.09	3.04
# physrevb.80.024519	11.6	11.5
# physrevb.80.064504	2.0	2.25
# physrevb.80.064506	13.4	8.0
# physrevb.80.100503	9.7	3.0
# physrevb.80.172501	1.51	17.0
# physrevb.80.224522	8.6	8.5
# physrevb.81.092506	12.0	8.0
# physrevb.81.104522	8.1	2.3
# physrevb.81.140507	1.61	1.5
# physrevb.81.144414	3.7	16.0
# physrevb.81.184509	8.0	-100.0
# physrevb.81.184522	8.5	28.0
# physrevb.81.205119	6.99	30.0
# physrevb.81.224511	13.0	3.0
# physrevb.82.064512	9.1	9.2
# physrevb.82.094506	1.86	23.0
# physrevb.82.094517	7.3	7.0
# physrevb.82.144118	22.0	10.0
# physrevb.82.144532	2.2	2.1
# physrevb.82.180512	22.0	26.0
# physrevb.83.060502	17.8	5.0
# physrevb.83.100502	17.5	18.0
# physrevb.83.100514	32.2	32.0
# physrevb.83.115131	12.5	13.0
# physrevb.83.134521	15.0	3.92
# physrevb.83.140501	3.85	4.06
# physrevb.83.140504	9.5	3.0
# physrevb.83.144510	2.325	3.0
# physrevb.83.174503	32.0	31.8
# physrevb.83.174506	17.5	18.0
# physrevb.83.174520	1.7	2.5
# physrevb.83.214513	29.0	30.0
# physrevb.83.220512	29.0	3.0
# physrevb.83.224512	16.9	14.7
# physrevb.84.024502	25.0	20.0
# physrevb.84.054541	2.78	6.0
# physrevb.84.104502	17.4	18.0
# physrevb.84.214527	7.9	7.8
# physrevb.85.014520	2.9	2.7
# physrevb.85.024526	0.6	2.8
# physrevb.85.054517	2.1	0.7
# physrevb.85.184501	22.0	22.2
# physrevb.85.184513	2.1	2.0
# physrevb.85.205105	0.8	4.5
# physrevb.86.064504	7.25	7.0
# physrevb.86.064516	17.0	18.0
# physrevb.86.220509	13.6	12.0
# physrevb.86.224514	3.4	3.8
# physrevb.87.064502	7.8	8.0
# physrevb.87.134512	9.9	8.0
# physrevb.87.140507	4.7	3.5
# physrevb.87.180508	25.1	25.0
# physrevb.87.214509	1.88	1.8
# physrevb.87.224507	4.6	5.0
# physrevb.88.024423	1.98	2.0
# physrevb.88.140501	4.5	58.0
# physrevb.88.144511	4.0	2.1
# physrevb.88.224510	31.0	26.0
# physrevb.88.224515	4.8	4.5
# physrevb.89.020505	3.7	3.72
# physrevb.89.020507	42.0	43.0
# physrevb.89.024518	37.0	45.0
# physrevb.89.100501	2.5	3.0
# physrevb.89.174515	10.8	11.0
# physrevb.89.205136	9.96	10.0
# physrevb.89.224504	1.7	1.8
# physrevb.90.014513	1.45	0.72
# physrevb.90.220508	2.8	3.0
# physrevb.90.220510	1.43	1.5
# physrevb.90.224513	19.2	16.0
# physrevb.91.014513	1.85	1.82
# physrevb.91.024509	3.55	3.53
# physrevb.91.060508	4.2	3.0
# physrevb.91.064509	21.0	49.0
# physrevb.91.094427	21.5	22.5
# physrevb.91.100504	6.05	6.6
# physrevb.91.104511	5.75	4.03
# physrevb.91.134508	8.5	8.8
# physrevb.91.174513	2.1	1.7
# physrevb.91.214517	1.3	100.0
# physrevb.92.020506	2.94	2.9
# physrevb.93.060506	3.9	3.7
# physrevb.93.104508	33.5	33.0
# physrevb.93.104516	14.0	13.5
# physrevb.93.115119	25.0	29.0
# physrevb.93.144502	4.93	5.0
# physrevb.93.224512	40.5	40.0
# physrevb.93.224516	2.11	13.0
# physrevb.93.241112	2.7	152.0
# physrevb.94.024518	6.4	6.2
# physrevb.94.054523	8.0	8.3
# physrevb.94.104507	7.31	-100.0
# physrevb.94.180509	78.0	84.0
# physrevb.95.024510	3.9	3.92
# physrevb.95.060505	18.0	3.25
# physrevb.95.064514	8.1	6.0
# physrevb.95.094510	35.2	32.8
# physrevb.95.140505	34.3	-100.0
# physrevb.95.174521	3.9	3.5
# physrevb.96.064528	4.02	3.0
# physrevb.96.094523	23.3	22.3
# physrevb.96.165123	3.25	3.2
# physrevb.96.224433	1.01	2.7
# physrevb.97.014514	3.7	3.05
# physrevb.97.014523	1.78	0.38
# physrevb.97.020502	6.8	6.0
# physrevb.97.020508	44.3	55.0
# physrevb.97.054515	1.75	1.7
# physrevb.97.064514	1.33	1.3
# physrevb.97.100504	9.7	11.0
# physrevb.97.104509	3.7	3.0
# physrevb.97.134508	3.5	3.85
# physrevb.98.014502	6.0	-100.0
# physrevb.98.020503	1.18	1.3
# physrevb.98.024520	1.85	2.0
# physrevb.98.094519	2.6	2.45
# physrevb.98.104506	4.65	4.68
# physrevb.99.144511	6.7	7.0
# physrevb.99.184509	0.834	0.8
# physrevb.99.184513	5.7	5.5

# %%
correct_num_materials / len(processed_database_output)
# Out:
# 0.5185909980430529

# %%
len(processed_database_output)
# Out:
# 510
